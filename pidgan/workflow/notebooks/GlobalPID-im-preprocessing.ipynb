# %% [markdown]
# # Preprocessing steps for _GlobalPID_ models (for isMuon=True)

# %%
import os
from IPython.display import Markdown

PARTICLE = os.environ.get("PARTICLE", "muon")
LOCAL = os.environ.get("LOCAL", "yes").lower() in ['y', 'yes', 'true', '1']
SAMPLE = os.environ.get("SAMPLE", "2016MU")

Markdown(f"""
 * PARTICLE: `{PARTICLE}`
 * LOCAL: `{LOCAL}`
 * SAMPLE: `{SAMPLE}`
""")
# Out:
#  * LOCAL: `True`
#  * SAMPLE: `2016MU`

# %% [markdown]
# ### Technologies and libraries
#
# On top of the standard Python echosystem we are using:
#  * `uproot` to convert data from `ROOT TTrees` to `pandas DataFrames`
#  * `dask DataFrame` to enable processing datasets larger than the available RAM. Dask takes care of flushing from disk to RAM the data, converting from ROOT to pandas data format on demand.
#  * `Arrow Feather` data format to cache in local storage the training dataset
#      * Note that custom wrappers to Dask and TensorFlow, as defined in `feather_io.py` are needed

# %%
import uproot
import numpy as np
import pandas as pd
import dask.dataframe as ddf

from os import environ

# %% [markdown]
# ### Loading data

# %%
from glob import glob

if LOCAL:
    if SAMPLE == "2016MU":
        file_pattern = "/tmp/LamarrTraining-j109*.root"
        default_file_list = glob(file_pattern)[:3]
else:
    # file_pattern = "/workarea/cloud-storage/anderlinil/LamarrBenderTrain/j109/*.root"
    default_file_list = []
    
file_list = os.environ.get("INPUT_FILES", " ".join(default_file_list)).split(" ")

print (f"Found {len(file_list)} data files")
# Out:
# Found 3 data files

# %% [markdown]
# #### Conversion from `ROOT TTree` to `Pandas DataFrame`

# %% [markdown]
# ## `isMuon` passed

# %%
selections = [
  "probe_Brunel_P > 3000",
  "probe_Brunel_P < 200000", 
  "probe_Brunel_ETA > 1.5", 
  "probe_Brunel_ETA < 5.5", 
  "probe_Brunel_isMuon == 1", 
  "probe_Brunel_RichDLLe  > -150",
  "probe_Brunel_RichDLLmu > -150",
  "probe_Brunel_RichDLLk  > -150",
  "probe_Brunel_RichDLLp  > -150",
  "probe_Brunel_RichDLLe  <  150",
  "probe_Brunel_RichDLLmu <  150",
  "probe_Brunel_RichDLLk  <  150",
  "probe_Brunel_RichDLLp  <  150",
  "probe_Brunel_MuonMuLL > -9",
  "probe_Brunel_MuonBgLL > -9", 
  "probe_Brunel_MuonMuLL <  1", 
  "probe_Brunel_MuonBgLL <  1", 
  "probe_Brunel_PIDe  > -25", 
  "probe_Brunel_PIDmu > -150", 
  "probe_Brunel_PIDK  > -150", 
  "probe_Brunel_PIDp  > -150",
  "probe_Brunel_MC15TuneV1_ProbNNe  >= 0", 
  "probe_Brunel_MC15TuneV1_ProbNNmu >= 0", 
  "probe_Brunel_MC15TuneV1_ProbNNpi >= 0", 
  "probe_Brunel_MC15TuneV1_ProbNNk  >= 0", 
  "probe_Brunel_MC15TuneV1_ProbNNp  >= 0", 
  "nTracks_Brunel > 0",
  "nTracks_Brunel < 1000", 
  "probe_Brunel_MuonUnbiased == 1",
]

cuts = " and ".join([f"({s})" for s in selections])

# %%
from functools import partial

opened_files = [uproot.open(f) for f in file_list]

sim = (
    ddf.from_map(
        lambda f: pd.DataFrame(f[f"PidTupler/pid_{PARTICLE}"].arrays(library='np')),
        opened_files,
    ).query(cuts)
)

# %% [markdown]
# #### List of features

# %%
from IPython.display import HTML

HTML ("<UL>" + "\n".join(f"<LI> <PRE>{var}</PRE> " for var in sim.columns) + "</UL>")
# Out:
# <UL><LI> <PRE>mc_key</PRE>
# <LI> <PRE>evtNumber</PRE>
# <LI> <PRE>runNumber</PRE>
# <LI> <PRE>nTracks_Brunel</PRE>
# <LI> <PRE>probe_Brunel_P</PRE>
# <LI> <PRE>probe_Brunel_ETA</PRE>
# <LI> <PRE>probe_Brunel_trackcharge</PRE>
# <LI> <PRE>probe_Brunel_RichDLLe</PRE>
# <LI> <PRE>probe_Brunel_RichDLLmu</PRE>
# <LI> <PRE>probe_Brunel_RichDLLk</PRE>
# <LI> <PRE>probe_Brunel_RichDLLp</PRE>
# <LI> <PRE>probe_Brunel_MuonMuLL</PRE>
# <LI> <PRE>probe_Brunel_MuonBgLL</PRE>
# <LI> <PRE>probe_Brunel_isMuon</PRE>
# <LI> <PRE>probe_Brunel_MuonUnbiased</PRE>
# <LI> <PRE>probe_Brunel_PIDe</PRE>
# <LI> <PRE>probe_Brunel_PIDK</PRE>
# <LI> <PRE>probe_Brunel_PIDp</PRE>
# <LI> <PRE>probe_Brunel_PIDmu</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNe</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNpi</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNk</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNp</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNmu</PRE> </UL>

# %% [markdown]
# ### Features

# %%
sim["p_GeV"] = sim.probe_Brunel_P/1e3
# sim["log10_p"] = np.log10(sim.probe_Brunel_P)
sim["eta"] = sim.probe_Brunel_ETA
sim = sim.map_partitions(lambda df: df.assign(nTracks_f = df.nTracks_Brunel + np.random.uniform(-0.5, 0.5, len(df))))
sim["charge"] = sim.probe_Brunel_trackcharge
sim["RichDLLe"] = sim.probe_Brunel_RichDLLe
sim["RichDLLmu"] = sim.probe_Brunel_RichDLLmu
sim["RichDLLk"] = sim.probe_Brunel_RichDLLk
sim["RichDLLp"] = sim.probe_Brunel_RichDLLp
sim["MuonMuLL"] = sim.probe_Brunel_MuonMuLL
sim["MuonBgLL"] = sim.probe_Brunel_MuonBgLL

sim["PIDe"] = sim.probe_Brunel_PIDe
sim["PIDK"] = sim.probe_Brunel_PIDK
sim["PIDp"] = sim.probe_Brunel_PIDp
sim["ProbNNe"] = sim.probe_Brunel_MC15TuneV1_ProbNNe
sim["ProbNNpi"] = sim.probe_Brunel_MC15TuneV1_ProbNNpi
sim["ProbNNk"] = sim.probe_Brunel_MC15TuneV1_ProbNNk
sim["ProbNNp"] = sim.probe_Brunel_MC15TuneV1_ProbNNp
sim["PIDmu"] = sim.probe_Brunel_PIDmu
sim["ProbNNmu"] = sim.probe_Brunel_MC15TuneV1_ProbNNmu

# %%
real_conditions_im = ["p_GeV", "eta", "nTracks_f", "RichDLLe", "RichDLLmu", "RichDLLk", "RichDLLp", "MuonMuLL", "MuonBgLL"]
flag_conditions_im = ["charge"]

conditions = real_conditions_im + flag_conditions_im
target = ["PIDe", "PIDK", "PIDp", "ProbNNe", "ProbNNpi", "ProbNNk", "ProbNNp", "PIDmu", "ProbNNmu"]

# %%
from IPython.display import HTML

def list_vars(title, var_list):
    display(HTML (f"<P><B>{title}</B><UL>" + "\n".join(f"<LI> <PRE>{var}</PRE> " for var in var_list) + "</UL><HR>"))

list_vars("Input features (real)", real_conditions_im)
list_vars("Input features (boolean)", flag_conditions_im)
list_vars("Output features (real)", target)
# Out:
# <P><B>Input features (real)</B><UL><LI> <PRE>p_GeV</PRE>
# <LI> <PRE>eta</PRE>
# <LI> <PRE>nTracks_f</PRE>
# <LI> <PRE>RichDLLe</PRE>
# <LI> <PRE>RichDLLmu</PRE>
# <LI> <PRE>RichDLLk</PRE>
# <LI> <PRE>RichDLLp</PRE>
# <LI> <PRE>MuonMuLL</PRE>
# <LI> <PRE>MuonBgLL</PRE> </UL><HR>
# <P><B>Input features (boolean)</B><UL><LI> <PRE>charge</PRE> </UL><HR>
# <P><B>Output features (real)</B><UL><LI> <PRE>PIDe</PRE>
# <LI> <PRE>PIDK</PRE>
# <LI> <PRE>PIDp</PRE>
# <LI> <PRE>ProbNNe</PRE>
# <LI> <PRE>ProbNNpi</PRE>
# <LI> <PRE>ProbNNk</PRE>
# <LI> <PRE>ProbNNp</PRE>
# <LI> <PRE>PIDmu</PRE>
# <LI> <PRE>ProbNNmu</PRE> </UL><HR>

# %%
dfs = dict()
npartitions=min(len(file_list), 10)

dfs = sim[conditions + target].head(500_000, npartitions=npartitions)
print(f"Number of {PARTICLE}s:", len(dfs))
# Out:
# Number of muons: 285085
# Number of pions: 31975
# Number of kaons: 93043
# Number of protons: 37174

# %% [markdown]
# #### Histograms

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(24, 15), dpi=100)

plt.subplot(3, 3, 1)
plt.xlabel("r$p$ [GeV/$c$]", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(dfs["p_GeV"], bins=np.linspace(1.0, 51.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 3, 2)
plt.xlabel(r"$\eta$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(dfs["eta"], bins=np.linspace(1.5, 5.5, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 3, 3)
plt.xlabel(r"$\mathtt{nTracks}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["nTracks_f"], bins=np.linspace(0.0, 500.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 3, 4)
plt.xlabel(r"$\mathtt{RichDLLe}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["RichDLLe"], bins=np.linspace(-100.0, 50.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.subplot(3, 3, 5)
plt.xlabel(r"$\mathtt{RichDLLmu}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["RichDLLmu"], bins=np.linspace(-50.0, 50.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.subplot(3, 3, 6)
plt.xlabel(r"$\mathtt{RichDLLk}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["RichDLLk"], bins=np.linspace(-150.0, 100.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 3, 7)
plt.xlabel(r"$\mathtt{RichDLLp}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["RichDLLp"], bins=np.linspace(-150.0, 100.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 3, 8)
plt.xlabel(r"$\mathtt{MuonMuLL}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["MuonMuLL"], bins=np.linspace(-4.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.subplot(3, 3, 9)
plt.xlabel(r"$\mathtt{MuonBgLL}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["MuonBgLL"], bins=np.linspace(-8.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.show()

# %%
plt.figure(figsize=(32, 15), dpi=100)

plt.subplot(3, 4, 1)
plt.xlabel(r"$\mathtt{PIDe}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDe"], bins=np.linspace(-20.0, 10.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 4, 2)
plt.xlabel(r"$\mathtt{PIDK}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDK"], bins=np.linspace(-125.0, 75.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 4, 3)
plt.xlabel(r"$\mathtt{PIDp}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDp"], bins=np.linspace(-125.0, 75.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 4, 4)
plt.xlabel(r"$\mathtt{PIDpK}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDp"] - dfs["PIDK"], bins=np.linspace(-100.0, 50.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(3, 4, 5)
plt.xlabel(r"$\mathtt{ProbNNe}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["ProbNNe"], bins=np.linspace(0.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(3, 4, 6)
plt.xlabel(r"$\mathtt{ProbNNpi}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["ProbNNpi"], bins=np.linspace(0.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 4, 7)
plt.xlabel(r"$\mathtt{ProbNNk}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["ProbNNk"], bins=np.linspace(0.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(3, 4, 8)
plt.xlabel(r"$\mathtt{ProbNNp}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["ProbNNp"], bins=np.linspace(0.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
plt.yscale(r"log")

plt.subplot(3, 4, 9)
plt.xlabel(r"$\mathtt{PIDmu}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDmu"], bins=np.linspace(-15.0, 25.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)

plt.subplot(3, 4, 10)
plt.xlabel(r"$\mathtt{ProbNNmu}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["ProbNNmu"], bins=np.linspace(0.0, 1.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
plt.yscale(r"log")

plt.subplot(3, 4, 11)
plt.xlabel(r"$\mathtt{PIDmue}$", fontsize=12)
plt.ylabel(r"Candidates", fontsize=12)
plt.hist(dfs["PIDmu"] - dfs["PIDe"], bins=np.linspace(-20.0, 30.0, 101), histtype="step", lw=2, label=PARTICLE)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.show()

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
from preprocessing_utils import makeProbNNTransformer

n_features = len(real_conditions_im)
n_flags = len(flag_conditions_im)
n_target = len(target)

prep_step_x = dict()
prep_step_x = ColumnTransformer(
    [
        ('quantile', QuantileTransformer(output_distribution='normal'), np.arange(n_features - 2)),
        ('standard', StandardScaler(), n_features - 2 + np.arange(2)),
        ('flags', "passthrough", n_features + np.arange(n_flags)),
    ]
).fit(dfs[conditions].values)

prep_step_y = dict()
prep_step_y = ColumnTransformer(
    [
        ('standard', StandardScaler(), [0, 1, 2, 7]),
        #('probs', MinMaxScaler(feature_range=(-1.0, 1.0)), [3, 4, 5, 6, 8]),
        ('probs', makeProbNNTransformer(), [3, 4, 5, 6, 8]),
    ]
).fit(dfs[target].values)

# %%
from preprocessing_utils import store_as_pickle

display(
    store_as_pickle(
        prep_step_x,
        f"PREPROCESSING_X",
        f"/tmp/lb-pidsim-train/models/GlobalPID-im_{PARTICLE}_models/tX_{SAMPLE}.pkl",
    )
)
display(
    store_as_pickle(
        prep_step_y,
        f"PREPROCESSING_Y",
        f"/tmp/lb-pidsim-train/models/GlobalPID-im_{PARTICLE}_models/tY_{SAMPLE}.pkl",
    )
)
# Out:
# 2025-08-16 07:53:09.751894: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755330789.927251   14835 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755330789.971662   14835 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755330790.418668   14835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755330790.418711   14835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755330790.418713   14835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755330790.418715   14835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-16 07:53:10.466640: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_muon_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_muon_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_pion_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_pion_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_kaon_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_kaon_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_proton_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/tmp/lb-pidsim-train/models/GlobalPID-im_proton_models/tY_2016MU.pkl</PRE>

# %% [markdown]
# ### Train, test and validation
#
# The dataset is split in:
#  * *train* (50%) used for training the model
#  * *test* (40%) used for measuring the performance of the model
#  * *validation* (10%) used in combination with the train dataset to check for overtraining effects
#
# Split data is stored on disk in chunks of 100 MB (before compression).

# %%
DATA_PATH = os.environ.get("DATA_PATH", "/tmp/lb-pidsim-train/data")
os.makedirs(DATA_PATH, exist_ok=True)

# %%
from preprocessing_utils import split_and_store, peek_from_dataset
from math import ceil
from IPython.display import Markdown

display(Markdown(f"# {PARTICLE.capitalize()}"))

entries = split_and_store(
    sim[conditions + target],
    [
        (0.5, os.environ.get(f"TRAIN", f"{DATA_PATH}/GlobalPID-im-{PARTICLE}-{SAMPLE}-train")),
        (0.4, os.environ.get(f"TEST", f"{DATA_PATH}/GlobalPID-im-{PARTICLE}-{SAMPLE}-test")),
        (0.1, os.environ.get(f"VALIDATION", f"{DATA_PATH}/GlobalPID-im-{PARTICLE}-{SAMPLE}-validation"))
    ],
    chunksize="80MB",
    features=conditions,
    labels=target,
    preprocessorX=prep_step_x,
    preprocessorY=prep_step_y,
)
    
display(pd.DataFrame(entries, index=["Train", "Test", "Validation"]))

X, y = peek_from_dataset(      
    f"TRAIN", 
    f"{DATA_PATH}/GlobalPID-im-{PARTICLE}-{SAMPLE}-train",
)
 
## X Variables
plt.figure(figsize=(32, 10), dpi=100)

for i, x_var in enumerate(conditions):
    plt.subplot(2, ceil(len(conditions)/2), i+1)
    plt.xlabel(x_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(X[:, i].numpy()[:100000], bins=100)

plt.show()

## Y variables
reord_target = ["PIDe", "PIDK", "PIDp", "PIDmu", "ProbNNe", "ProbNNpi", "ProbNNk", "ProbNNp"]

plt.figure(figsize=(32, 15), dpi=100)


for i, y_var in enumerate(reord_target):
    plt.subplot(3, 4, i+1)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y[:, i].numpy()[:100000], bins=100)

plt.subplot(3, 4, 9)
plt.xlabel("PIDpK", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y[:, 2].numpy()[:100000] - y[:, 1].numpy()[:100000], bins=100)

plt.subplot(3, 4, 10)
plt.xlabel("PIDmue", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y[:, 3].numpy()[:100000] - y[:, 0].numpy()[:100000], bins=100)

plt.show()
