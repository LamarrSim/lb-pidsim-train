# %% [markdown]
# # Preprocessing steps for _RICH_ models

# %%
LOCAL = True
SAMPLE = "2016MU"

# %% [markdown]
# ## Technologies and libraries
#
# On top of the standard Python echosystem we are using:
#  * `uproot` to convert data from `ROOT TTrees` to `pandas DataFrames`
#  * `dask DataFrame` to enable processing datasets larger than the available RAM. Dask takes care of flushing from disk to RAM the data, converting from ROOT to pandas data format on demand.
#  * `Arrow Feather` data format to cache in local storage the training dataset
#      * Note that custom wrappers to Dask and TensorFlow, as defined in `feather_io.py` are needed

# %%
import numpy as np
import pandas as pd
import dask.dataframe as ddf
import uproot
from os import environ

# %% [markdown]
# ## Loading data

# %%
from glob import glob

if LOCAL:
    if SAMPLE == "2016MU":
        file_pattern = "/afs/cern.ch/user/l/landerli/gangadir/workspace/landerli/LocalXML/109/*/output/*.root"
    else:
        pass
else:
    # file_pattern = "/workarea/cloud-storage/anderlinil/LamarrBenderTrain/j109/*.root"
    pass

default_file_list = glob(file_pattern)
file_list = environ.get("INPUT_FILES", " ".join(default_file_list)).split(" ")

print (f"Found {len(file_list)} files from {file_pattern}")
# Out:
# Found 236 files from /afs/cern.ch/user/l/landerli/gangadir/workspace/landerli/LocalXML/109/*/output/*.root

# %% [markdown]
# ### Conversion from `ROOT TTree` to `Pandas DataFrame`

# %%
def read_root(filename, tree=None):
    if tree is None:
        return uproot.open(filename)
    
    return pd.DataFrame(uproot.open(filename)[tree].arrays(library='np'))

# %%
selections = [
    "probe_Brunel_P > 3000",
    "probe_Brunel_P < 200000", 
    "probe_Brunel_ETA > 1.5",
    "probe_Brunel_ETA < 5.5", 
    "probe_Brunel_RichDLLe  > -150",
    "probe_Brunel_RichDLLmu > -150",
    "probe_Brunel_RichDLLk  > -150",
    "probe_Brunel_RichDLLp  > -150",
    "probe_Brunel_RichDLLe  <  150",
    "probe_Brunel_RichDLLmu <  150",
    "probe_Brunel_RichDLLk  <  150",
    "probe_Brunel_RichDLLp  <  150",
    "nTracks_Brunel > 0",
    "nTracks_Brunel < 1000", 
]

cuts = " and ".join([s for s in selections])

# %%
from functools import partial

sim = dict()
particles = ["muon", "pion", "kaon", "proton"]

for part in particles:
    sim[part] = (
        ddf.from_map(
            partial(read_root, tree=f"PidTupler/pid_{part}"),
            file_list,
        ).query(cuts)
    )

# %% [markdown]
# ### List of features

# %%
from IPython.display import HTML

HTML ("<UL>" + "\n".join(f"<LI> <PRE>{var}</PRE> " for var in sim["muon"].columns) + "</UL>")
# Out:
# <UL><LI> <PRE>mc_key</PRE>
# <LI> <PRE>evtNumber</PRE>
# <LI> <PRE>runNumber</PRE>
# <LI> <PRE>nTracks_Brunel</PRE>
# <LI> <PRE>probe_Brunel_P</PRE>
# <LI> <PRE>probe_Brunel_ETA</PRE>
# <LI> <PRE>probe_Brunel_trackcharge</PRE>
# <LI> <PRE>probe_Brunel_RichDLLe</PRE>
# <LI> <PRE>probe_Brunel_RichDLLmu</PRE>
# <LI> <PRE>probe_Brunel_RichDLLk</PRE>
# <LI> <PRE>probe_Brunel_RichDLLp</PRE>
# <LI> <PRE>probe_Brunel_MuonMuLL</PRE>
# <LI> <PRE>probe_Brunel_MuonBgLL</PRE>
# <LI> <PRE>probe_Brunel_isMuon</PRE>
# <LI> <PRE>probe_Brunel_MuonUnbiased</PRE>
# <LI> <PRE>probe_Brunel_PIDe</PRE>
# <LI> <PRE>probe_Brunel_PIDK</PRE>
# <LI> <PRE>probe_Brunel_PIDp</PRE>
# <LI> <PRE>probe_Brunel_PIDmu</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNe</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNpi</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNk</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNp</PRE>
# <LI> <PRE>probe_Brunel_MC15TuneV1_ProbNNmu</PRE> </UL>

# %% [markdown]
# ## Features

# %%
for part in particles:
    sim[part]["p_GeV"] = sim[part].probe_Brunel_P/1e3
    # sim[part]["log10_p"] = np.log10(sim[part].probe_Brunel_P)
    sim[part]["eta"] = sim[part].probe_Brunel_ETA
    sim[part] = sim[part].map_partitions(lambda df: df.assign(nTracks_f = df.nTracks_Brunel + np.random.uniform(-0.5, 0.5, len(df))))
    sim[part]["charge"] = sim[part].probe_Brunel_trackcharge
    
    sim[part]["RichDLLe"] = sim[part].probe_Brunel_RichDLLe
    sim[part]["RichDLLmu"] = sim[part].probe_Brunel_RichDLLmu
    sim[part]["RichDLLk"] = sim[part].probe_Brunel_RichDLLk
    sim[part]["RichDLLp"] = sim[part].probe_Brunel_RichDLLp

# %%
real_conditions = ["p_GeV", "eta", "nTracks_f"]
flag_conditions = ["charge"]

conditions = real_conditions + flag_conditions
target = ["RichDLLe", "RichDLLmu", "RichDLLk", "RichDLLp"]

# %%
from IPython.display import HTML

def list_vars(title, var_list):
    display(HTML (f"<P><B>{title}</B><UL>" + "\n".join(f"<LI> <PRE>{var}</PRE> " for var in var_list) + "</UL><HR>"))

list_vars("Input features (real)", real_conditions)
list_vars("Input features (boolean)", flag_conditions)
list_vars("Output features (real)", target)
# Out:
# <P><B>Input features (real)</B><UL><LI> <PRE>p_GeV</PRE>
# <LI> <PRE>eta</PRE>
# <LI> <PRE>nTracks_f</PRE> </UL><HR>
# <P><B>Input features (boolean)</B><UL><LI> <PRE>charge</PRE> </UL><HR>
# <P><B>Output features (real)</B><UL><LI> <PRE>RichDLLe</PRE>
# <LI> <PRE>RichDLLmu</PRE>
# <LI> <PRE>RichDLLk</PRE>
# <LI> <PRE>RichDLLp</PRE> </UL><HR>

# %%
dfs = dict()

for part in particles:
    dfs[part] = sim[part][conditions + target].head(500_000, npartitions=10)
    print(f"Number of {part}s:", len(dfs[part]))
# Out:
# Number of muons: 500000
# Number of pions: 500000
# Number of kaons: 500000
# Number of protons: 500000

# %% [markdown]
# ### Histograms

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(24, 5), dpi=100)

plt.subplot(1, 3, 1)
plt.xlabel("$p$ [GeV/$c$]", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["p_GeV"], bins=np.linspace(1.0, 101.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)

plt.subplot(1, 3, 2)
plt.xlabel("$\eta$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["eta"], bins=np.linspace(1.5, 5.5, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)

plt.subplot(1, 3, 3)
plt.xlabel("$\mathtt{nTracks}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["nTracks_f"], bins=np.linspace(0.0, 500.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)

plt.show()

# %%
plt.figure(figsize=(24, 10), dpi=100)

plt.subplot(2, 3, 1)
plt.xlabel("$\mathtt{RichDLLe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLe"], bins=np.linspace(-150.0, 100.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(2, 3, 2)
plt.xlabel("$\mathtt{RichDLLmu}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLmu"], bins=np.linspace(-100.0, 150.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(2, 3, 3)
plt.xlabel("$\mathtt{RichDLLmue}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLmu"] - dfs[part]["RichDLLe"], bins=np.linspace(-50.0, 150.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)
plt.yscale("log")

plt.subplot(2, 3, 4)
plt.xlabel("$\mathtt{RichDLLk}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLk"], bins=np.linspace(-150.0, 100.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)

plt.subplot(2, 3, 5)
plt.xlabel("$\mathtt{RichDLLp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLp"], bins=np.linspace(-150.0, 100.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)

plt.subplot(2, 3, 6)
plt.xlabel("$\mathtt{RichDLLpk}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
for part in particles:
    plt.hist(dfs[part]["RichDLLp"] - dfs[part]["RichDLLk"], bins=np.linspace(-100.0, 100.0, 101), histtype="step", lw=2, label=part)
plt.legend(fontsize=10)
plt.yscale("log")

plt.show()

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import QuantileTransformer, StandardScaler

n_features = len(real_conditions)
n_flags = len(flag_conditions)
n_target = len(target)

prep_step_x = dict()
for part in particles:
    prep_step_x[part] = ColumnTransformer(
        [
            ('features', QuantileTransformer(output_distribution='normal'), np.arange(n_features)),
            ('flags', "passthrough", n_features + np.arange(n_flags)),
        ]
    ).fit(dfs[part][conditions].values)

prep_step_y = dict()
for part in particles:
    prep_step_y[part] = StandardScaler().fit(dfs[part][target].values)

# %%
from preprocessing_utils import store_as_pickle

for part in particles:
    display(
        store_as_pickle(
            prep_step_x[part],
            f"RICH_{part.upper()}_PREPROCESSING_X",
            f"/home/mabarbet/PythonFastSim/models/Rich_{part}_models/tX_{SAMPLE}.pkl",
        )
    )
    display(
        store_as_pickle(
            prep_step_y[part],
            f"RICH_{part.upper()}_PREPROCESSING_Y",
            f"/home/mabarbet/PythonFastSim/models/Rich_{part}_models/tY_{SAMPLE}.pkl",
        )
    )
# Out:
# 2023-12-27 14:45:15.292684: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 14:45:15.292726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 14:45:15.294358: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 14:45:15.303815: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-27 14:45:16.187111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_muon_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_muon_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_pion_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_pion_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_kaon_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_kaon_models/tY_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_proton_models/tX_2016MU.pkl</PRE>
# <B>Preprocessing step stored in: </B><PRE>/home/mabarbet/PythonFastSim/models/Rich_proton_models/tY_2016MU.pkl</PRE>

# %% [markdown]
# ## Train, test and validation
#
# The dataset is split in:
#  * *train* (50%) used for training the model
#  * *test* (40%) used for measuring the performance of the model
#  * *validation* (10%) used in combination with the train dataset to check for overtraining effects
#
# Split data is stored on disk in chunks of 100 MB (before compression).

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %% [markdown]
# ### Muons

# %%
from preprocessing_utils import split_and_store

entries = split_and_store(
    sim["muon"][conditions + target],
    [
        (0.5, environ.get("RICH_MUON_TRAIN", f"{DATA_PATH}/Rich-muon-{SAMPLE}-train")),
        (0.4, environ.get("RICH_MUON_TEST", f"{DATA_PATH}/Rich-muon-{SAMPLE}-test")),
        (0.1, environ.get("RICH_MUON_VALIDATION", f"{DATA_PATH}/Rich-muon-{SAMPLE}-validation"))
    ],
    chunksize="100MB",
    features=conditions,
    labels=target,
    preprocessorX=prep_step_x["muon"],
    preprocessorY=prep_step_y["muon"],
)
    
pd.DataFrame(entries, index=["Train", "Test", "Validation"])
# Out:
# Processing /home/mabarbet/PythonFastSim/data/Rich-muon-2016MU-train
# Processing /home/mabarbet/PythonFastSim/data/Rich-muon-2016MU-test
# Processing /home/mabarbet/PythonFastSim/data/Rich-muon-2016MU-validation
#                    0
# Train       14307431
# Test        11441544
# Validation   2860668

# %%
from feather_io import FeatherReader    

reader_train =  FeatherReader(environ.get("RICH_MUON_TRAIN", f"{DATA_PATH}/Rich-muon-{SAMPLE}-train"), max_files=3)
ds_train_mu = reader_train.as_tf_dataset()

# %%
X_mu, y_mu = next(iter(ds_train_mu.batch(2_000_000)))
X_mu.shape, y_mu.shape
# Out:
# (TensorShape([2000000, 4]), TensorShape([2000000, 4]))

# %%
plt.figure(figsize=(32, 5), dpi=100)

for i, x_var in enumerate(conditions):
    plt.subplot(1, 4, i+1)
    plt.xlabel(x_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(X_mu[:, i].numpy()[:100000], bins=100)

plt.show()

# %%
plt.figure(figsize=(24, 10), dpi=100)

for i, y_var in enumerate(["RichDLLe", "RichDLLmu"]):
    plt.subplot(2, 3, i+1)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_mu[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 3)
plt.xlabel("RichDLLmue", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_mu[:, 1].numpy()[:100000] - y_mu[:, 0].numpy()[:100000], bins=100)

for i, y_var in enumerate(["RichDLLk", "RichDLLp"], 2):
    plt.subplot(2, 3, i+2)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_mu[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 6)
plt.xlabel("RichDLLpk", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_mu[:, 3].numpy()[:100000] - y_mu[:, 2].numpy()[:100000], bins=100)

plt.show()

# %%
np.savez_compressed(
    file=f"{DATA_PATH}/Rich-muon-{SAMPLE}-trainset.npz",
    x=X_mu.numpy(),
    x_vars=conditions,
    y=y_mu.numpy(),
    y_vars=target,
    w=None,
    w_var=None,
)

# %% [markdown]
# ### Pions

# %%
entries = split_and_store(
    sim["pion"][conditions + target],
    [
        (0.5, environ.get("RICH_PION_TRAIN", f"{DATA_PATH}/Rich-pion-{SAMPLE}-train")),
        (0.4, environ.get("RICH_PION_TEST", f"{DATA_PATH}/Rich-pion-{SAMPLE}-test")),
        (0.1, environ.get("RICH_PION_VALIDATION", f"{DATA_PATH}/Rich-pion-{SAMPLE}-validation"))
    ],
    chunksize="100MB",
    features=conditions,
    labels=target,
    preprocessorX=prep_step_x["pion"],
    preprocessorY=prep_step_y["pion"],
)
    
pd.DataFrame(entries, index=["Train", "Test", "Validation"])
# Out:
# Processing /home/mabarbet/PythonFastSim/data/Rich-pion-2016MU-train
# Processing /home/mabarbet/PythonFastSim/data/Rich-pion-2016MU-test
# Processing /home/mabarbet/PythonFastSim/data/Rich-pion-2016MU-validation
#                    0
# Train       55007370
# Test        43989476
# Validation  11001442

# %%
reader_train =  FeatherReader(environ.get("RICH_PION_TRAIN", f"{DATA_PATH}/Rich-pion-{SAMPLE}-train"), max_files=3)
ds_train_pi = reader_train.as_tf_dataset()

# %%
X_pi, y_pi = next(iter(ds_train_pi.batch(2_000_000)))
X_pi.shape, y_pi.shape
# Out:
# (TensorShape([2000000, 4]), TensorShape([2000000, 4]))

# %%
plt.figure(figsize=(32, 5), dpi=100)

for i, x_var in enumerate(conditions):
    plt.subplot(1, 4, i+1)
    plt.xlabel(x_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(X_pi[:, i].numpy()[:100000], bins=100)

plt.show()

# %%
plt.figure(figsize=(24, 10), dpi=100)

for i, y_var in enumerate(["RichDLLe", "RichDLLmu"]):
    plt.subplot(2, 3, i+1)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_pi[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 3)
plt.xlabel("RichDLLmue", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_pi[:, 1].numpy()[:100000] - y_pi[:, 0].numpy()[:100000], bins=100)

for i, y_var in enumerate(["RichDLLk", "RichDLLp"], 2):
    plt.subplot(2, 3, i+2)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_pi[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 6)
plt.xlabel("RichDLLpk", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_pi[:, 3].numpy()[:100000] - y_pi[:, 2].numpy()[:100000], bins=100)

plt.show()

# %%
np.savez_compressed(
    file=f"{DATA_PATH}/Rich-pion-{SAMPLE}-trainset.npz",
    x=X_pi.numpy(),
    x_vars=conditions,
    y=y_pi.numpy(),
    y_vars=target,
    w=None,
    w_var=None,
)

# %% [markdown]
# ### Kaons

# %%
entries = split_and_store(
    sim["kaon"][conditions + target],
    [
        (0.5, environ.get("RICH_KAON_TRAIN", f"{DATA_PATH}/Rich-kaon-{SAMPLE}-train")),
        (0.4, environ.get("RICH_KAON_TEST", f"{DATA_PATH}/Rich-kaon-{SAMPLE}-test")),
        (0.1, environ.get("RICH_KAON_VALIDATION", f"{DATA_PATH}/Rich-kaon-{SAMPLE}-validation"))
    ],
    chunksize="100MB",
    features=conditions,
    labels=target,
    preprocessorX=prep_step_x["kaon"],
    preprocessorY=prep_step_y["kaon"],
)
    
pd.DataFrame(entries, index=["Train", "Test", "Validation"])
# Out:
# Processing /home/mabarbet/PythonFastSim/data/Rich-kaon-2016MU-train
# Processing /home/mabarbet/PythonFastSim/data/Rich-kaon-2016MU-test
# Processing /home/mabarbet/PythonFastSim/data/Rich-kaon-2016MU-validation
#                    0
# Train       91758464
# Test        73415332
# Validation  18350223

# %%
reader_train =  FeatherReader(environ.get("RICH_KAON_TRAIN", f"{DATA_PATH}/Rich-kaon-{SAMPLE}-train"), max_files=3)
ds_train_k = reader_train.as_tf_dataset()

# %%
X_k, y_k = next(iter(ds_train_k.batch(2_000_000)))
X_k.shape, y_k.shape
# Out:
# (TensorShape([2000000, 4]), TensorShape([2000000, 4]))

# %%
plt.figure(figsize=(32, 5), dpi=100)

for i, x_var in enumerate(conditions):
    plt.subplot(1, 4, i+1)
    plt.xlabel(x_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(X_k[:, i].numpy()[:100000], bins=100)

plt.show()

# %%
plt.figure(figsize=(24, 10), dpi=100)

for i, y_var in enumerate(["RichDLLe", "RichDLLmu"]):
    plt.subplot(2, 3, i+1)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_k[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 3)
plt.xlabel("RichDLLmue", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_k[:, 1].numpy()[:100000] - y_k[:, 0].numpy()[:100000], bins=100)

for i, y_var in enumerate(["RichDLLk", "RichDLLp"], 2):
    plt.subplot(2, 3, i+2)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_k[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 6)
plt.xlabel("RichDLLpk", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_k[:, 3].numpy()[:100000] - y_k[:, 2].numpy()[:100000], bins=100)

plt.show()

# %%
np.savez_compressed(
    file=f"{DATA_PATH}/Rich-kaon-{SAMPLE}-trainset.npz",
    x=X_k.numpy(),
    x_vars=conditions,
    y=y_k.numpy(),
    y_vars=target,
    w=None,
    w_var=None,
)

# %% [markdown]
# ### Protons

# %%
entries = split_and_store(
    sim["proton"][conditions + target],
    [
        (0.5, environ.get("RICH_PROTON_TRAIN", f"{DATA_PATH}/Rich-proton-{SAMPLE}-train")),
        (0.4, environ.get("RICH_PROTON_TEST", f"{DATA_PATH}/Rich-proton-{SAMPLE}-test")),
        (0.1, environ.get("RICH_PROTON_VALIDATION", f"{DATA_PATH}/Rich-proton-{SAMPLE}-validation"))
    ],
    chunksize="100MB",
    features=conditions,
    labels=target,
    preprocessorX=prep_step_x["proton"],
    preprocessorY=prep_step_y["proton"],
)
    
pd.DataFrame(entries, index=["Train", "Test", "Validation"])
# Out:
# Processing /home/mabarbet/PythonFastSim/data/Rich-proton-2016MU-train
# Processing /home/mabarbet/PythonFastSim/data/Rich-proton-2016MU-test
# Processing /home/mabarbet/PythonFastSim/data/Rich-proton-2016MU-validation
#                    0
# Train       65542895
# Test        52430433
# Validation  13107596

# %%
reader_train =  FeatherReader(environ.get("RICH_PROTON_TRAIN", f"{DATA_PATH}/Rich-proton-{SAMPLE}-train"), max_files=3)
ds_train_p = reader_train.as_tf_dataset()

# %%
X_p, y_p = next(iter(ds_train_p.batch(2_000_000)))
X_p.shape, y_p.shape
# Out:
# (TensorShape([2000000, 4]), TensorShape([2000000, 4]))

# %%
plt.figure(figsize=(32, 5), dpi=100)

for i, x_var in enumerate(conditions):
    plt.subplot(1, 4, i+1)
    plt.xlabel(x_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(X_p[:, i].numpy()[:100000], bins=100)

plt.show()

# %%
plt.figure(figsize=(24, 10), dpi=100)

for i, y_var in enumerate(["RichDLLe", "RichDLLmu"]):
    plt.subplot(2, 3, i+1)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_p[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 3)
plt.xlabel("RichDLLmue", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_p[:, 1].numpy()[:100000] - y_p[:, 0].numpy()[:100000], bins=100)

for i, y_var in enumerate(["RichDLLk", "RichDLLp"], 2):
    plt.subplot(2, 3, i+2)
    plt.xlabel(y_var, fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_p[:, i].numpy()[:100000], bins=100)

plt.subplot(2, 3, 6)
plt.xlabel("RichDLLpk", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(y_p[:, 3].numpy()[:100000] - y_p[:, 2].numpy()[:100000], bins=100)

plt.show()

# %%
np.savez_compressed(
    file=f"{DATA_PATH}/Rich-proton-{SAMPLE}-trainset.npz",
    x=X_p.numpy(),
    x_vars=conditions,
    y=y_p.numpy(),
    y_vars=target,
    w=None,
    w_var=None,
)
