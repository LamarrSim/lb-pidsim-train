# %% [markdown]
# # Training of the _isMuon_ model for _pions_
#
# In this notebook we setup the training for the isMuon model for _pions_, based on a Deep Neural Network.
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [isMuon-preprocessing.ipynb](./isMuon-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("ISMUON_PION_TRAIN_DATA", f"{DATA_PATH}/isMuon-pion-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("ISMUON_PION_VAL_DATA", f"{DATA_PATH}/isMuon-pion-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 4]), TensorShape([500000, 1]))

# %% [markdown]
# ## Model definition
#
# The function we are modelling is not a trivial one, requiring a sufficiently deep neural network.
# In order to limit the effect of the vanishing gradient and make the trainig procedure faster, we are using the concept of Residual Layer, introducing skipping connections between the input and the output of each layer.
#
# With residual layers, the neural network is trained to learn the deviation from identity which is a much less demanding task than learning the whole transformation.
#
# The output layer of the neural network has a sigmoid activation function to be mapped into the interval 0-1 and being interpreted as the **probability** for the particle of **passing the isMuon criterion**.

# %%
from pidgan.players.classifiers import ResClassifier

model = ResClassifier(
    num_hidden_layers=10,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=tf.keras.regularizers.L2(1e-4),
    mlp_dropout_rates=0.0,
    name="classifier",
)

# %%
model(X[:256])
model.summary()
# Out:
# Model: "classifier_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 4)]                  0         []
#
#  dense_0 (Dense)             (None, 128)                  640       ['input_1[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['dense_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['dense_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  16512     ['add_3-4[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_5[0][0]']
#
#  add_4-5 (Add)               (None, 128)                  0         ['add_3-4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  16512     ['add_4-5[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  add_5-6 (Add)               (None, 128)                  0         ['add_4-5[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  16512     ['add_5-6[0][0]']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['dense_7[0][0]']
#
#  add_6-7 (Add)               (None, 128)                  0         ['add_5-6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_8 (Dense)             (None, 128)                  16512     ['add_6-7[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_8[0][0]']
#
#  add_7-8 (Add)               (None, 128)                  0         ['add_6-7[0][0]',
#                                                                      'dropout_8[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  16512     ['add_7-8[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_9[0][0]']
#
#  add_8-9 (Add)               (None, 128)                  0         ['add_7-8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  dense_out (Dense)           (None, 1)                    129       ['add_8-9[0][0]']
#
# ==================================================================================================
# Total params: 149377 (583.50 KB)
# Trainable params: 149377 (583.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model.export_model,
    to_file="./images/isMuon-pion-model.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# The rest of the training procedure is rather standard:
#  * loss function: [binary cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy)
#  * optimizer: [RMSprop](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/experimental/RMSprop) or [Adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)

# %%
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# To speed up convergence, we split the training procedure in two steps:
# * First, we start with a high learning rate that is exponentially decreased by using a custom [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler), and with a binary cross-entropy loss with `label_smoothing` set to 0.05.
# * Then, we operate some fine tuning by fixing the learning rate to the value reached by the scheduler, and by removing the `label_smoothing`.

# %%
model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.05),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(0.05),
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

lr_sched = LearnRateExpDecay(
    model.optimizer,
    decay_rate=0.1,
    decay_steps=50_000,
    verbose=True,
)

# early_stop = tf.keras.callbacks.EarlyStopping(
#     monitor="val_auc",
#     min_delta=1e-5,
#     patience=3,
#     mode="max",
# )

# %%
batch_size = 20_000
num_epochs = 200

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

callbacks = [lr_sched]  # [lr_sched, early_stop]

train = model.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)
# Out:
# Epoch 1/200
#       4/Unknown - 7s 20ms/step - loss: 781.1816 - auc: 0.5044 - lr: 0.0500WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0158s vs `on_train_batch_begin` time: 0.0926s). Check your callbacks.
# 609/609 [==============================] - 23s 27ms/step - loss: 5.6606 - auc: 0.6869 - lr: 0.0493 - val_loss: 0.4159 - val_auc: 0.7619
# Epoch 2/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.3997 - auc: 0.7599 - lr: 0.0479 - val_loss: 0.3820 - val_auc: 0.7731
# Epoch 3/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.3705 - auc: 0.7628 - lr: 0.0466 - val_loss: 0.3559 - val_auc: 0.7714
# Epoch 4/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.3459 - auc: 0.7646 - lr: 0.0453 - val_loss: 0.3330 - val_auc: 0.7725
# Epoch 5/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.3237 - auc: 0.7658 - lr: 0.0441 - val_loss: 0.3117 - val_auc: 0.7722
# Epoch 6/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.3032 - auc: 0.7664 - lr: 0.0429 - val_loss: 0.2919 - val_auc: 0.7720
# Epoch 7/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.2842 - auc: 0.7669 - lr: 0.0417 - val_loss: 0.2737 - val_auc: 0.7713
# Epoch 8/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.2666 - auc: 0.7677 - lr: 0.0405 - val_loss: 0.2568 - val_auc: 0.7704
# Epoch 9/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.2505 - auc: 0.7681 - lr: 0.0394 - val_loss: 0.2414 - val_auc: 0.7713
# Epoch 10/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.2359 - auc: 0.7685 - lr: 0.0383 - val_loss: 0.2277 - val_auc: 0.7720
# Epoch 11/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.2231 - auc: 0.7690 - lr: 0.0372 - val_loss: 0.2159 - val_auc: 0.7704
# Epoch 12/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.2122 - auc: 0.7694 - lr: 0.0362 - val_loss: 0.2060 - val_auc: 0.7729
# Epoch 13/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.2033 - auc: 0.7699 - lr: 0.0352 - val_loss: 0.1980 - val_auc: 0.7714
# Epoch 14/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1963 - auc: 0.7700 - lr: 0.0342 - val_loss: 0.1920 - val_auc: 0.7708
# Epoch 15/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1912 - auc: 0.7701 - lr: 0.0333 - val_loss: 0.1878 - val_auc: 0.7695
# Epoch 16/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1878 - auc: 0.7702 - lr: 0.0324 - val_loss: 0.1851 - val_auc: 0.7706
# Epoch 17/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1857 - auc: 0.7703 - lr: 0.0315 - val_loss: 0.1836 - val_auc: 0.7696
# Epoch 18/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1846 - auc: 0.7703 - lr: 0.0306 - val_loss: 0.1828 - val_auc: 0.7704
# Epoch 19/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1840 - auc: 0.7701 - lr: 0.0298 - val_loss: 0.1824 - val_auc: 0.7693
# Epoch 20/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1838 - auc: 0.7703 - lr: 0.0289 - val_loss: 0.1823 - val_auc: 0.7713
# Epoch 21/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1837 - auc: 0.7703 - lr: 0.0281 - val_loss: 0.1822 - val_auc: 0.7683
# Epoch 22/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1837 - auc: 0.7705 - lr: 0.0274 - val_loss: 0.1821 - val_auc: 0.7695
# Epoch 23/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1837 - auc: 0.7706 - lr: 0.0266 - val_loss: 0.1821 - val_auc: 0.7688
# Epoch 24/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1837 - auc: 0.7707 - lr: 0.0259 - val_loss: 0.1821 - val_auc: 0.7693
# Epoch 25/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1837 - auc: 0.7709 - lr: 0.0252 - val_loss: 0.1822 - val_auc: 0.7683
# Epoch 26/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1836 - auc: 0.7711 - lr: 0.0245 - val_loss: 0.1821 - val_auc: 0.7723
# Epoch 27/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1836 - auc: 0.7715 - lr: 0.0238 - val_loss: 0.1821 - val_auc: 0.7732
# Epoch 28/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7717 - lr: 0.0231 - val_loss: 0.1821 - val_auc: 0.7756
# Epoch 29/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1836 - auc: 0.7719 - lr: 0.0225 - val_loss: 0.1821 - val_auc: 0.7736
# Epoch 30/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7720 - lr: 0.0219 - val_loss: 0.1821 - val_auc: 0.7744
# Epoch 31/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7721 - lr: 0.0213 - val_loss: 0.1821 - val_auc: 0.7741
# Epoch 32/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1836 - auc: 0.7722 - lr: 0.0207 - val_loss: 0.1821 - val_auc: 0.7740
# Epoch 33/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7724 - lr: 0.0201 - val_loss: 0.1820 - val_auc: 0.7755
# Epoch 34/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7724 - lr: 0.0195 - val_loss: 0.1820 - val_auc: 0.7716
# Epoch 35/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1836 - auc: 0.7725 - lr: 0.0190 - val_loss: 0.1820 - val_auc: 0.7725
# Epoch 36/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1835 - auc: 0.7727 - lr: 0.0185 - val_loss: 0.1820 - val_auc: 0.7713
# Epoch 37/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7728 - lr: 0.0180 - val_loss: 0.1820 - val_auc: 0.7725
# Epoch 38/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7728 - lr: 0.0175 - val_loss: 0.1820 - val_auc: 0.7732
# Epoch 39/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1835 - auc: 0.7729 - lr: 0.0170 - val_loss: 0.1820 - val_auc: 0.7732
# Epoch 40/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7730 - lr: 0.0165 - val_loss: 0.1820 - val_auc: 0.7723
# Epoch 41/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1835 - auc: 0.7731 - lr: 0.0161 - val_loss: 0.1820 - val_auc: 0.7731
# Epoch 42/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7732 - lr: 0.0156 - val_loss: 0.1820 - val_auc: 0.7721
# Epoch 43/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7732 - lr: 0.0152 - val_loss: 0.1820 - val_auc: 0.7727
# Epoch 44/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1835 - auc: 0.7732 - lr: 0.0148 - val_loss: 0.1820 - val_auc: 0.7739
# Epoch 45/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1835 - auc: 0.7734 - lr: 0.0144 - val_loss: 0.1820 - val_auc: 0.7735
# Epoch 46/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7733 - lr: 0.0140 - val_loss: 0.1820 - val_auc: 0.7740
# Epoch 47/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7734 - lr: 0.0136 - val_loss: 0.1820 - val_auc: 0.7736
# Epoch 48/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1835 - auc: 0.7734 - lr: 0.0132 - val_loss: 0.1820 - val_auc: 0.7732
# Epoch 49/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1835 - auc: 0.7735 - lr: 0.0128 - val_loss: 0.1820 - val_auc: 0.7739
# Epoch 50/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7736 - lr: 0.0125 - val_loss: 0.1820 - val_auc: 0.7732
# Epoch 51/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1835 - auc: 0.7736 - lr: 0.0121 - val_loss: 0.1820 - val_auc: 0.7734
# Epoch 52/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1835 - auc: 0.7737 - lr: 0.0118 - val_loss: 0.1820 - val_auc: 0.7725
# Epoch 53/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1835 - auc: 0.7738 - lr: 0.0115 - val_loss: 0.1820 - val_auc: 0.7721
# Epoch 54/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1835 - auc: 0.7738 - lr: 0.0112 - val_loss: 0.1820 - val_auc: 0.7704
# Epoch 55/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7738 - lr: 0.0108 - val_loss: 0.1819 - val_auc: 0.7712
# Epoch 56/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7739 - lr: 0.0105 - val_loss: 0.1819 - val_auc: 0.7715
# Epoch 57/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7739 - lr: 0.0103 - val_loss: 0.1820 - val_auc: 0.7719
# Epoch 58/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7741 - lr: 0.0100 - val_loss: 0.1820 - val_auc: 0.7714
# Epoch 59/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7740 - lr: 0.0097 - val_loss: 0.1820 - val_auc: 0.7715
# Epoch 60/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7741 - lr: 0.0094 - val_loss: 0.1820 - val_auc: 0.7719
# Epoch 61/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7741 - lr: 0.0092 - val_loss: 0.1819 - val_auc: 0.7699
# Epoch 62/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7742 - lr: 0.0089 - val_loss: 0.1820 - val_auc: 0.7708
# Epoch 63/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7742 - lr: 0.0087 - val_loss: 0.1820 - val_auc: 0.7727
# Epoch 64/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7742 - lr: 0.0084 - val_loss: 0.1820 - val_auc: 0.7724
# Epoch 65/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7743 - lr: 0.0082 - val_loss: 0.1820 - val_auc: 0.7724
# Epoch 66/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7743 - lr: 0.0080 - val_loss: 0.1820 - val_auc: 0.7700
# Epoch 67/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7744 - lr: 0.0077 - val_loss: 0.1820 - val_auc: 0.7724
# Epoch 68/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1834 - auc: 0.7744 - lr: 0.0075 - val_loss: 0.1820 - val_auc: 0.7730
# Epoch 69/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7745 - lr: 0.0073 - val_loss: 0.1820 - val_auc: 0.7721
# Epoch 70/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7745 - lr: 0.0071 - val_loss: 0.1820 - val_auc: 0.7730
# Epoch 71/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7745 - lr: 0.0069 - val_loss: 0.1820 - val_auc: 0.7725
# Epoch 72/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7745 - lr: 0.0067 - val_loss: 0.1820 - val_auc: 0.7735
# Epoch 73/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7746 - lr: 0.0065 - val_loss: 0.1820 - val_auc: 0.7727
# Epoch 74/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7746 - lr: 0.0064 - val_loss: 0.1820 - val_auc: 0.7729
# Epoch 75/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7746 - lr: 0.0062 - val_loss: 0.1820 - val_auc: 0.7731
# Epoch 76/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7747 - lr: 0.0060 - val_loss: 0.1820 - val_auc: 0.7729
# Epoch 77/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7746 - lr: 0.0059 - val_loss: 0.1820 - val_auc: 0.7722
# Epoch 78/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7747 - lr: 0.0057 - val_loss: 0.1820 - val_auc: 0.7727
# Epoch 79/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7747 - lr: 0.0055 - val_loss: 0.1820 - val_auc: 0.7719
# Epoch 80/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7748 - lr: 0.0054 - val_loss: 0.1820 - val_auc: 0.7708
# Epoch 81/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7748 - lr: 0.0052 - val_loss: 0.1819 - val_auc: 0.7714
# Epoch 82/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7748 - lr: 0.0051 - val_loss: 0.1820 - val_auc: 0.7718
# Epoch 83/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7748 - lr: 0.0049 - val_loss: 0.1819 - val_auc: 0.7718
# Epoch 84/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1834 - auc: 0.7749 - lr: 0.0048 - val_loss: 0.1820 - val_auc: 0.7709
# Epoch 85/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7749 - lr: 0.0047 - val_loss: 0.1820 - val_auc: 0.7708
# Epoch 86/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1834 - auc: 0.7749 - lr: 0.0045 - val_loss: 0.1820 - val_auc: 0.7703
# Epoch 87/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7750 - lr: 0.0044 - val_loss: 0.1820 - val_auc: 0.7711
# Epoch 88/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7750 - lr: 0.0043 - val_loss: 0.1820 - val_auc: 0.7714
# Epoch 89/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7750 - lr: 0.0042 - val_loss: 0.1820 - val_auc: 0.7716
# Epoch 90/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1834 - auc: 0.7751 - lr: 0.0041 - val_loss: 0.1820 - val_auc: 0.7713
# Epoch 91/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0040 - val_loss: 0.1820 - val_auc: 0.7719
# Epoch 92/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0038 - val_loss: 0.1820 - val_auc: 0.7717
# Epoch 93/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0037 - val_loss: 0.1819 - val_auc: 0.7714
# Epoch 94/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0036 - val_loss: 0.1819 - val_auc: 0.7717
# Epoch 95/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0035 - val_loss: 0.1820 - val_auc: 0.7716
# Epoch 96/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7751 - lr: 0.0034 - val_loss: 0.1819 - val_auc: 0.7722
# Epoch 97/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0033 - val_loss: 0.1819 - val_auc: 0.7722
# Epoch 98/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0032 - val_loss: 0.1819 - val_auc: 0.7725
# Epoch 99/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0032 - val_loss: 0.1819 - val_auc: 0.7721
# Epoch 100/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0031 - val_loss: 0.1819 - val_auc: 0.7727
# Epoch 101/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0030 - val_loss: 0.1819 - val_auc: 0.7722
# Epoch 102/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0029 - val_loss: 0.1820 - val_auc: 0.7730
# Epoch 103/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0028 - val_loss: 0.1820 - val_auc: 0.7727
# Epoch 104/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7752 - lr: 0.0027 - val_loss: 0.1819 - val_auc: 0.7730
# Epoch 105/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7753 - lr: 0.0027 - val_loss: 0.1820 - val_auc: 0.7725
# Epoch 106/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7753 - lr: 0.0026 - val_loss: 0.1819 - val_auc: 0.7727
# Epoch 107/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7753 - lr: 0.0025 - val_loss: 0.1819 - val_auc: 0.7718
# Epoch 108/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0025 - val_loss: 0.1819 - val_auc: 0.7736
# Epoch 109/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0024 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 110/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0023 - val_loss: 0.1819 - val_auc: 0.7738
# Epoch 111/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0023 - val_loss: 0.1819 - val_auc: 0.7731
# Epoch 112/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0022 - val_loss: 0.1819 - val_auc: 0.7733
# Epoch 113/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7754 - lr: 0.0021 - val_loss: 0.1819 - val_auc: 0.7733
# Epoch 114/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0021 - val_loss: 0.1819 - val_auc: 0.7738
# Epoch 115/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0020 - val_loss: 0.1819 - val_auc: 0.7737
# Epoch 116/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0020 - val_loss: 0.1819 - val_auc: 0.7746
# Epoch 117/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0019 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 118/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0019 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 119/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0018 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 120/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0018 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 121/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7755 - lr: 0.0017 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 122/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0017 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 123/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0016 - val_loss: 0.1819 - val_auc: 0.7737
# Epoch 124/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0016 - val_loss: 0.1819 - val_auc: 0.7736
# Epoch 125/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0015 - val_loss: 0.1819 - val_auc: 0.7731
# Epoch 126/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0015 - val_loss: 0.1819 - val_auc: 0.7731
# Epoch 127/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7756 - lr: 0.0014 - val_loss: 0.1819 - val_auc: 0.7733
# Epoch 128/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0014 - val_loss: 0.1819 - val_auc: 0.7731
# Epoch 129/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0014 - val_loss: 0.1819 - val_auc: 0.7729
# Epoch 130/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0013 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 131/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0013 - val_loss: 0.1819 - val_auc: 0.7729
# Epoch 132/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0013 - val_loss: 0.1819 - val_auc: 0.7729
# Epoch 133/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0012 - val_loss: 0.1819 - val_auc: 0.7730
# Epoch 134/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0012 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 135/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0012 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 136/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0011 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 137/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7757 - lr: 0.0011 - val_loss: 0.1819 - val_auc: 0.7733
# Epoch 138/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7758 - lr: 0.0011 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 139/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7758 - lr: 0.0010 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 140/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1833 - auc: 0.7758 - lr: 9.9966e-04 - val_loss: 0.1819 - val_auc: 0.7735
# Epoch 141/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1833 - auc: 0.7758 - lr: 9.7202e-04 - val_loss: 0.1819 - val_auc: 0.7736
# Epoch 142/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7758 - lr: 9.4514e-04 - val_loss: 0.1819 - val_auc: 0.7729
# Epoch 143/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1833 - auc: 0.7758 - lr: 9.1900e-04 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 144/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7758 - lr: 8.9358e-04 - val_loss: 0.1819 - val_auc: 0.7735
# Epoch 145/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7758 - lr: 8.6887e-04 - val_loss: 0.1819 - val_auc: 0.7730
# Epoch 146/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7758 - lr: 8.4484e-04 - val_loss: 0.1819 - val_auc: 0.7728
# Epoch 147/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7758 - lr: 8.2147e-04 - val_loss: 0.1819 - val_auc: 0.7729
# Epoch 148/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 7.9876e-04 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 149/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7759 - lr: 7.7667e-04 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 150/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 7.5519e-04 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 151/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 7.3430e-04 - val_loss: 0.1819 - val_auc: 0.7733
# Epoch 152/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 7.1399e-04 - val_loss: 0.1819 - val_auc: 0.7732
# Epoch 153/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.9425e-04 - val_loss: 0.1819 - val_auc: 0.7735
# Epoch 154/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.7505e-04 - val_loss: 0.1819 - val_auc: 0.7736
# Epoch 155/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.5638e-04 - val_loss: 0.1819 - val_auc: 0.7734
# Epoch 156/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.3823e-04 - val_loss: 0.1819 - val_auc: 0.7737
# Epoch 157/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.2058e-04 - val_loss: 0.1819 - val_auc: 0.7737
# Epoch 158/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 6.0341e-04 - val_loss: 0.1819 - val_auc: 0.7737
# Epoch 159/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 5.8672e-04 - val_loss: 0.1819 - val_auc: 0.7738
# Epoch 160/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7759 - lr: 5.7050e-04 - val_loss: 0.1819 - val_auc: 0.7740
# Epoch 161/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7760 - lr: 5.5472e-04 - val_loss: 0.1819 - val_auc: 0.7740
# Epoch 162/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 5.3938e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 163/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 5.2446e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 164/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7760 - lr: 5.0996e-04 - val_loss: 0.1819 - val_auc: 0.7743
# Epoch 165/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.9585e-04 - val_loss: 0.1819 - val_auc: 0.7740
# Epoch 166/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.8214e-04 - val_loss: 0.1819 - val_auc: 0.7741
# Epoch 167/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.6881e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 168/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.5584e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 169/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.4324e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 170/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.3098e-04 - val_loss: 0.1819 - val_auc: 0.7745
# Epoch 171/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.1906e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 172/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7760 - lr: 4.0747e-04 - val_loss: 0.1819 - val_auc: 0.7746
# Epoch 173/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.9620e-04 - val_loss: 0.1819 - val_auc: 0.7739
# Epoch 174/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.8524e-04 - val_loss: 0.1819 - val_auc: 0.7741
# Epoch 175/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.7459e-04 - val_loss: 0.1819 - val_auc: 0.7740
# Epoch 176/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.6423e-04 - val_loss: 0.1819 - val_auc: 0.7740
# Epoch 177/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.5416e-04 - val_loss: 0.1819 - val_auc: 0.7739
# Epoch 178/200
# 609/609 [==============================] - 15s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.4436e-04 - val_loss: 0.1819 - val_auc: 0.7741
# Epoch 179/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.3484e-04 - val_loss: 0.1819 - val_auc: 0.7741
# Epoch 180/200
# 609/609 [==============================] - 17s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.2558e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 181/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.1657e-04 - val_loss: 0.1819 - val_auc: 0.7742
# Epoch 182/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 3.0782e-04 - val_loss: 0.1819 - val_auc: 0.7743
# Epoch 183/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.9931e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 184/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.9103e-04 - val_loss: 0.1819 - val_auc: 0.7745
# Epoch 185/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.8298e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 186/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.7515e-04 - val_loss: 0.1819 - val_auc: 0.7745
# Epoch 187/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.6754e-04 - val_loss: 0.1819 - val_auc: 0.7746
# Epoch 188/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.6014e-04 - val_loss: 0.1819 - val_auc: 0.7747
# Epoch 189/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.5295e-04 - val_loss: 0.1819 - val_auc: 0.7746
# Epoch 190/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.4595e-04 - val_loss: 0.1819 - val_auc: 0.7747
# Epoch 191/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.3915e-04 - val_loss: 0.1819 - val_auc: 0.7746
# Epoch 192/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.3254e-04 - val_loss: 0.1819 - val_auc: 0.7745
# Epoch 193/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.2611e-04 - val_loss: 0.1819 - val_auc: 0.7745
# Epoch 194/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.1985e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 195/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.1377e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 196/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.0786e-04 - val_loss: 0.1819 - val_auc: 0.7743
# Epoch 197/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7761 - lr: 2.0211e-04 - val_loss: 0.1819 - val_auc: 0.7744
# Epoch 198/200
# 609/609 [==============================] - 16s 26ms/step - loss: 0.1833 - auc: 0.7762 - lr: 1.9652e-04 - val_loss: 0.1819 - val_auc: 0.7743
# Epoch 199/200
# 609/609 [==============================] - 15s 24ms/step - loss: 0.1833 - auc: 0.7761 - lr: 1.9109e-04 - val_loss: 0.1819 - val_auc: 0.7743
# Epoch 200/200
# 609/609 [==============================] - 16s 25ms/step - loss: 0.1833 - auc: 0.7762 - lr: 1.8580e-04 - val_loss: 0.1819 - val_auc: 0.7743

# %%
from datetime import datetime

model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.0),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(1e-4),
)
early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=5)

callbacks = None  # [early_stop]

train_ft = model.fit(data_train, epochs=int(num_epochs/2.0), validation_data=data_val, callbacks=callbacks)

prefix = ""
timestamp = str(datetime.now())
timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
    prefix += time + unit  # YYYYMMDD-HHhMMmSSs
# Out:
# Epoch 1/100
# 609/609 [==============================] - 20s 26ms/step - loss: 0.1025 - auc: 0.7624 - val_loss: 0.0977 - val_auc: 0.7754
# Epoch 2/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0986 - auc: 0.7700 - val_loss: 0.0960 - val_auc: 0.7735
# Epoch 3/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0978 - auc: 0.7717 - val_loss: 0.0957 - val_auc: 0.7730
# Epoch 4/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0976 - auc: 0.7728 - val_loss: 0.0956 - val_auc: 0.7734
# Epoch 5/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0975 - auc: 0.7738 - val_loss: 0.0957 - val_auc: 0.7747
# Epoch 6/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0975 - auc: 0.7745 - val_loss: 0.0957 - val_auc: 0.7739
# Epoch 7/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7749 - val_loss: 0.0957 - val_auc: 0.7741
# Epoch 8/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0974 - auc: 0.7751 - val_loss: 0.0957 - val_auc: 0.7736
# Epoch 9/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7753 - val_loss: 0.0957 - val_auc: 0.7743
# Epoch 10/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0974 - auc: 0.7754 - val_loss: 0.0957 - val_auc: 0.7736
# Epoch 11/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0974 - auc: 0.7755 - val_loss: 0.0957 - val_auc: 0.7730
# Epoch 12/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7757 - val_loss: 0.0957 - val_auc: 0.7737
# Epoch 13/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0974 - auc: 0.7758 - val_loss: 0.0957 - val_auc: 0.7735
# Epoch 14/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7759 - val_loss: 0.0957 - val_auc: 0.7737
# Epoch 15/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7759 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 16/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0974 - auc: 0.7759 - val_loss: 0.0957 - val_auc: 0.7734
# Epoch 17/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0974 - auc: 0.7760 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 18/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7760 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 19/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0974 - auc: 0.7760 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 20/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0974 - auc: 0.7761 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 21/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0974 - auc: 0.7761 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 22/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0974 - auc: 0.7761 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 23/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0974 - auc: 0.7761 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 24/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0974 - auc: 0.7762 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 25/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0974 - auc: 0.7762 - val_loss: 0.0957 - val_auc: 0.7723
# Epoch 26/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7762 - val_loss: 0.0957 - val_auc: 0.7718
# Epoch 27/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7762 - val_loss: 0.0957 - val_auc: 0.7719
# Epoch 28/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7718
# Epoch 29/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7720
# Epoch 30/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7717
# Epoch 31/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7717
# Epoch 32/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7716
# Epoch 33/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7717
# Epoch 34/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7763 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 35/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7723
# Epoch 36/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 37/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7723
# Epoch 38/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 39/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 40/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7725
# Epoch 41/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 42/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7730
# Epoch 43/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 44/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 45/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 46/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 47/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 48/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7725
# Epoch 49/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7764 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 50/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7725
# Epoch 51/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7724
# Epoch 52/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7725
# Epoch 53/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7725
# Epoch 54/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 55/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 56/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7730
# Epoch 57/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7731
# Epoch 58/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7731
# Epoch 59/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7736
# Epoch 60/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7734
# Epoch 61/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 62/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 63/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 64/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 65/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 66/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7735
# Epoch 67/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7735
# Epoch 68/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7736
# Epoch 69/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7736
# Epoch 70/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 71/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 72/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 73/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 74/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7765 - val_loss: 0.0957 - val_auc: 0.7734
# Epoch 75/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 76/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 77/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 78/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 79/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 80/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 81/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 82/100
# 609/609 [==============================] - 15s 23ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 83/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 84/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7734
# Epoch 85/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7733
# Epoch 86/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 87/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7729
# Epoch 88/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7732
# Epoch 89/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 90/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 91/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 92/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7727
# Epoch 93/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 94/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 95/100
# 609/609 [==============================] - 15s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 96/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 97/100
# 609/609 [==============================] - 15s 24ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 98/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7766 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 99/100
# 609/609 [==============================] - 16s 26ms/step - loss: 0.0973 - auc: 0.7767 - val_loss: 0.0957 - val_auc: 0.7728
# Epoch 100/100
# 609/609 [==============================] - 16s 25ms/step - loss: 0.0973 - auc: 0.7767 - val_loss: 0.0957 - val_auc: 0.7728

# %% [markdown]
# The two regimes are well visibile in the plot below, combining the two training phases in a single epoch count.

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Binary cross-entropy", fontsize=12)
plt.plot(train.history["loss"][1:] + train_ft.history["loss"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_loss"][1:] + train_ft.history["val_loss"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("ROC AUC", fontsize=12)
plt.plot(train.history["auc"][1:] + train_ft.history["auc"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_auc"][1:] + train_ft.history["val_auc"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.show()

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-isMuon-pion-train.csv")

train_history_ft = train_ft.history.copy()
train_history_ft.update({"lr": [1e-4 for _ in range(int(num_epochs/2.0))]})
pd.DataFrame(train_history_ft).to_csv(f"./exports/{prefix}-isMuon-pion-train-ft.csv")

# %% [markdown]
# ## A first, rough validation
#
# While a proper validation of the model is demanded to a dedicated notebook (still to be prepared), here we check that the training was not completely failed and provides reasonable numbers.
#
# In particular, we compare the distributions of the training labels and of the predictions.
#
# Clearly, the training labels are either 1 or 0 because a particle passes either isMuon or not. Instead, the output of the neural network is a probability and hence it will be distributed between 0 and 1.
#
# The comparison is used to ensure that both the training labels and the network output are not unreasonable, for example collapsed into a single value or with training labels belonging to a single category.

# %%
reader_test = FeatherReader(environ.get("ISMUON_PION_TEST_DATA", f"{DATA_PATH}/isMuon-pion-{SAMPLE}-test"), max_files=5)
ds_test = reader_test.as_tf_dataset()

# %%
X_test, y_test = next(iter(ds_test.batch(20_000_000).as_numpy_iterator()))
preds = model.predict(X_test, batch_size=50_000)
# Out:
# 311/311 [==============================] - 2s 5ms/step

# %%
bins = np.linspace(0, 1, 11)
plt.hist(y_test, bins=bins, label="Simulation")
plt.hist(preds, bins=bins, histtype='step', linewidth=2, label="Predictions")
plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# Then we can compare the distribution of a preprocessed variable before and after the application of the isMuon criterion.
#
# Here, for example, we consider the preprocessed of the momentum $p$.
#
# Since the variable is preprocessed, without applying any cut (**Generated**) we have a perfectly normalized Gaussian.
#
# Applying the criterion `isMuon == 1`, we get another distribution that we expect to model with decent approximation by applying the response of the trained neural networks as weights to the **Generated** dataset.
#
# The comparison of the two histograms (obtained by applying a cut on the true isMuon or applying a weight on the isMuon probability) provides a first validation on the quality of the parametrization.

# %%
prep_p = X_test[:, 0]
bins = np.linspace(-5, 5, 101)

denominator, _ = np.histogram(prep_p, bins=bins)
true_numerator, _ = np.histogram(prep_p, bins=bins, weights=y_test.flatten())
predicted_numerator, _ = np.histogram(prep_p, bins=bins, weights=preds.flatten())

plt.xlabel("Preprocessed $p$ [GeV/$c$]")

plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=denominator, label="Generated pions", histtype='step')
plt.fill_between(
    (bins[1:] + bins[:-1])/2, np.zeros(len(true_numerator)), true_numerator,
    label="isMuon passed (sim)",
    color='#88ee88'
)
plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=predicted_numerator, label="isMuon passed (model)", histtype='step', linewidth=2)

plt.legend(loc="upper left", fontsize=10)
plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
models_dir = "/home/mabarbet/PythonFastSim/models/isMuon_pion_models"

# %%
import pickle

file_path = f"{models_dir}/tX_{SAMPLE}.pkl"

with open(file_path, "rb") as file:
    X_scaler = pickle.load(file)

# %%
import json

with open(f"{DATA_PATH}/isMuon-pion-{SAMPLE}-test/definitions.json") as json_file:
    definitions = json.load(json_file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer

print(f"Shapes:", X_test.shape, y_test.shape, preds.shape)

X_post = invertColumnTransformer(X_scaler, X_test)
np.savez_compressed(
    f"./exports/{prefix}-isMuon-pion-results.npz",
    feat_vars=np.array(definitions["features"]),
    label_vars=np.array(definitions["labels"]),
    results=np.c_[X_post, y_test, preds][:5_000_000],
)
# Out:
# Shapes: (15548986, 4) (15548986, 1) (15548986, 1)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_isMuon_pion_{SAMPLE}_ann"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    model.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_pion_models/20231230-01h43m08s_isMuon_pion_2016MU_model/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_pion_models/20231230-01h43m08s_isMuon_pion_2016MU_model/assets
