# %% [markdown]
# # Training of the _isMuon_ model for _protons_
#
# In this notebook we setup the training for the isMuon model for _protons_, based on a Deep Neural Network.
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [isMuon-preprocessing.ipynb](./isMuon-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("ISMUON_PROTON_TRAIN_DATA", f"{DATA_PATH}/isMuon-proton-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("ISMUON_PROTON_VAL_DATA", f"{DATA_PATH}/isMuon-proton-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 4]), TensorShape([500000, 1]))

# %% [markdown]
# ## Model definition
#
# The function we are modelling is not a trivial one, requiring a sufficiently deep neural network.
# In order to limit the effect of the vanishing gradient and make the trainig procedure faster, we are using the concept of Residual Layer, introducing skipping connections between the input and the output of each layer.
#
# With residual layers, the neural network is trained to learn the deviation from identity which is a much less demanding task than learning the whole transformation.
#
# The output layer of the neural network has a sigmoid activation function to be mapped into the interval 0-1 and being interpreted as the **probability** for the particle of **passing the isMuon criterion**.

# %%
from pidgan.players.classifiers import ResClassifier

model = ResClassifier(
    num_hidden_layers=10,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=tf.keras.regularizers.L2(5e-5),
    mlp_dropout_rates=0.0,
    name="classifier",
)

# %%
model(X[:256])
model.summary()
# Out:
# Model: "classifier_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 4)]                  0         []
#
#  dense_0 (Dense)             (None, 128)                  640       ['input_1[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['dense_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['dense_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  16512     ['add_3-4[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_5[0][0]']
#
#  add_4-5 (Add)               (None, 128)                  0         ['add_3-4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  16512     ['add_4-5[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  add_5-6 (Add)               (None, 128)                  0         ['add_4-5[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  16512     ['add_5-6[0][0]']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['dense_7[0][0]']
#
#  add_6-7 (Add)               (None, 128)                  0         ['add_5-6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_8 (Dense)             (None, 128)                  16512     ['add_6-7[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_8[0][0]']
#
#  add_7-8 (Add)               (None, 128)                  0         ['add_6-7[0][0]',
#                                                                      'dropout_8[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  16512     ['add_7-8[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_9[0][0]']
#
#  add_8-9 (Add)               (None, 128)                  0         ['add_7-8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  dense_out (Dense)           (None, 1)                    129       ['add_8-9[0][0]']
#
# ==================================================================================================
# Total params: 149377 (583.50 KB)
# Trainable params: 149377 (583.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model.export_model,
    to_file="./images/isMuon-proton-model.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# The rest of the training procedure is rather standard:
#  * loss function: [binary cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy)
#  * optimizer: [RMSprop](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/experimental/RMSprop) or [Adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)

# %%
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# To speed up convergence, we split the training procedure in two steps:
# * First, we start with a high learning rate that is exponentially decreased by using a custom [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler), and with a binary cross-entropy loss with `label_smoothing` set to 0.05.
# * Then, we operate some fine tuning by fixing the learning rate to the value reached by the scheduler, and by removing the `label_smoothing`.

# %%
model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.05),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(0.05),
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

lr_sched = LearnRateExpDecay(
    model.optimizer,
    decay_rate=0.1,
    decay_steps=50_000,
    verbose=True,
)

# early_stop = tf.keras.callbacks.EarlyStopping(
#     monitor="val_auc",
#     min_delta=1e-5,
#     patience=3,
#     mode="max",
# )

# %%
batch_size = 20_000
num_epochs = 200

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

callbacks = [lr_sched]  # [lr_sched, early_stop]

train = model.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)
# Out:
# Epoch 1/200
#       4/Unknown - 6s 19ms/step - loss: 2276.8091 - auc: 0.5120 - lr: 0.0500WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0156s vs `on_train_batch_begin` time: 0.0810s). Check your callbacks.
# 619/619 [==============================] - 24s 29ms/step - loss: 15.2204 - auc: 0.7578 - lr: 0.0493 - val_loss: 0.4035 - val_auc: 0.8030
# Epoch 2/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.3693 - auc: 0.7942 - lr: 0.0479 - val_loss: 0.3495 - val_auc: 0.8041
# Epoch 3/200
# 619/619 [==============================] - 15s 25ms/step - loss: 0.3352 - auc: 0.7954 - lr: 0.0466 - val_loss: 0.3274 - val_auc: 0.8086
# Epoch 4/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.3181 - auc: 0.7952 - lr: 0.0453 - val_loss: 0.3139 - val_auc: 0.8047
# Epoch 5/200
# 619/619 [==============================] - 15s 24ms/step - loss: 0.3060 - auc: 0.7953 - lr: 0.0440 - val_loss: 0.3029 - val_auc: 0.8063
# Epoch 6/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.2956 - auc: 0.7954 - lr: 0.0427 - val_loss: 0.2926 - val_auc: 0.8123
# Epoch 7/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.2857 - auc: 0.7968 - lr: 0.0415 - val_loss: 0.2828 - val_auc: 0.8118
# Epoch 8/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.2759 - auc: 0.7977 - lr: 0.0404 - val_loss: 0.2730 - val_auc: 0.8084
# Epoch 9/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.2660 - auc: 0.7988 - lr: 0.0392 - val_loss: 0.2631 - val_auc: 0.8107
# Epoch 10/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.2560 - auc: 0.7996 - lr: 0.0381 - val_loss: 0.2531 - val_auc: 0.8113
# Epoch 11/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.2459 - auc: 0.8008 - lr: 0.0371 - val_loss: 0.2430 - val_auc: 0.8110
# Epoch 12/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.2358 - auc: 0.8018 - lr: 0.0360 - val_loss: 0.2330 - val_auc: 0.8112
# Epoch 13/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.2259 - auc: 0.8025 - lr: 0.0350 - val_loss: 0.2231 - val_auc: 0.8109
# Epoch 14/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.2162 - auc: 0.8033 - lr: 0.0340 - val_loss: 0.2137 - val_auc: 0.8134
# Epoch 15/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.2072 - auc: 0.8040 - lr: 0.0331 - val_loss: 0.2052 - val_auc: 0.8117
# Epoch 16/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1991 - auc: 0.8043 - lr: 0.0321 - val_loss: 0.1978 - val_auc: 0.8123
# Epoch 17/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1923 - auc: 0.8045 - lr: 0.0312 - val_loss: 0.1916 - val_auc: 0.8106
# Epoch 18/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1869 - auc: 0.8049 - lr: 0.0304 - val_loss: 0.1870 - val_auc: 0.8116
# Epoch 19/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1831 - auc: 0.8050 - lr: 0.0295 - val_loss: 0.1840 - val_auc: 0.8124
# Epoch 20/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1808 - auc: 0.8052 - lr: 0.0287 - val_loss: 0.1821 - val_auc: 0.8126
# Epoch 21/200
# 619/619 [==============================] - 15s 25ms/step - loss: 0.1795 - auc: 0.8055 - lr: 0.0279 - val_loss: 0.1812 - val_auc: 0.8114
# Epoch 22/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1789 - auc: 0.8055 - lr: 0.0271 - val_loss: 0.1809 - val_auc: 0.8116
# Epoch 23/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1787 - auc: 0.8055 - lr: 0.0263 - val_loss: 0.1808 - val_auc: 0.8114
# Epoch 24/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1787 - auc: 0.8054 - lr: 0.0256 - val_loss: 0.1808 - val_auc: 0.8116
# Epoch 25/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1786 - auc: 0.8053 - lr: 0.0249 - val_loss: 0.1808 - val_auc: 0.8111
# Epoch 26/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8052 - lr: 0.0242 - val_loss: 0.1809 - val_auc: 0.8107
# Epoch 27/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8052 - lr: 0.0235 - val_loss: 0.1808 - val_auc: 0.8117
# Epoch 28/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8053 - lr: 0.0228 - val_loss: 0.1809 - val_auc: 0.8111
# Epoch 29/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8057 - lr: 0.0222 - val_loss: 0.1809 - val_auc: 0.8123
# Epoch 30/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1786 - auc: 0.8058 - lr: 0.0216 - val_loss: 0.1809 - val_auc: 0.8124
# Epoch 31/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8058 - lr: 0.0210 - val_loss: 0.1809 - val_auc: 0.8114
# Epoch 32/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8060 - lr: 0.0204 - val_loss: 0.1808 - val_auc: 0.8131
# Epoch 33/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8060 - lr: 0.0198 - val_loss: 0.1808 - val_auc: 0.8128
# Epoch 34/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1786 - auc: 0.8061 - lr: 0.0192 - val_loss: 0.1809 - val_auc: 0.8121
# Epoch 35/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1786 - auc: 0.8061 - lr: 0.0187 - val_loss: 0.1808 - val_auc: 0.8123
# Epoch 36/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1786 - auc: 0.8062 - lr: 0.0182 - val_loss: 0.1808 - val_auc: 0.8134
# Epoch 37/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8063 - lr: 0.0177 - val_loss: 0.1808 - val_auc: 0.8124
# Epoch 38/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8064 - lr: 0.0172 - val_loss: 0.1808 - val_auc: 0.8126
# Epoch 39/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8065 - lr: 0.0167 - val_loss: 0.1808 - val_auc: 0.8127
# Epoch 40/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8065 - lr: 0.0162 - val_loss: 0.1808 - val_auc: 0.8122
# Epoch 41/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8066 - lr: 0.0158 - val_loss: 0.1807 - val_auc: 0.8122
# Epoch 42/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8066 - lr: 0.0153 - val_loss: 0.1806 - val_auc: 0.8143
# Epoch 43/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8067 - lr: 0.0149 - val_loss: 0.1807 - val_auc: 0.8129
# Epoch 44/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8068 - lr: 0.0145 - val_loss: 0.1807 - val_auc: 0.8125
# Epoch 45/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8069 - lr: 0.0141 - val_loss: 0.1807 - val_auc: 0.8119
# Epoch 46/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8069 - lr: 0.0137 - val_loss: 0.1807 - val_auc: 0.8122
# Epoch 47/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8070 - lr: 0.0133 - val_loss: 0.1806 - val_auc: 0.8109
# Epoch 48/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8071 - lr: 0.0129 - val_loss: 0.1806 - val_auc: 0.8128
# Epoch 49/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8072 - lr: 0.0125 - val_loss: 0.1806 - val_auc: 0.8120
# Epoch 50/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1785 - auc: 0.8072 - lr: 0.0122 - val_loss: 0.1806 - val_auc: 0.8128
# Epoch 51/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8074 - lr: 0.0119 - val_loss: 0.1806 - val_auc: 0.8125
# Epoch 52/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8075 - lr: 0.0115 - val_loss: 0.1806 - val_auc: 0.8129
# Epoch 53/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8075 - lr: 0.0112 - val_loss: 0.1806 - val_auc: 0.8128
# Epoch 54/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8076 - lr: 0.0109 - val_loss: 0.1806 - val_auc: 0.8134
# Epoch 55/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8077 - lr: 0.0106 - val_loss: 0.1806 - val_auc: 0.8127
# Epoch 56/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8078 - lr: 0.0103 - val_loss: 0.1806 - val_auc: 0.8124
# Epoch 57/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8079 - lr: 0.0100 - val_loss: 0.1806 - val_auc: 0.8127
# Epoch 58/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8078 - lr: 0.0097 - val_loss: 0.1805 - val_auc: 0.8114
# Epoch 59/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8080 - lr: 0.0094 - val_loss: 0.1806 - val_auc: 0.8126
# Epoch 60/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8080 - lr: 0.0092 - val_loss: 0.1805 - val_auc: 0.8124
# Epoch 61/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8081 - lr: 0.0089 - val_loss: 0.1805 - val_auc: 0.8122
# Epoch 62/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8082 - lr: 0.0087 - val_loss: 0.1805 - val_auc: 0.8131
# Epoch 63/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8083 - lr: 0.0084 - val_loss: 0.1805 - val_auc: 0.8121
# Epoch 64/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1784 - auc: 0.8084 - lr: 0.0082 - val_loss: 0.1805 - val_auc: 0.8122
# Epoch 65/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1784 - auc: 0.8084 - lr: 0.0080 - val_loss: 0.1805 - val_auc: 0.8108
# Epoch 66/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8085 - lr: 0.0077 - val_loss: 0.1805 - val_auc: 0.8135
# Epoch 67/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8086 - lr: 0.0075 - val_loss: 0.1805 - val_auc: 0.8117
# Epoch 68/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8087 - lr: 0.0073 - val_loss: 0.1805 - val_auc: 0.8115
# Epoch 69/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8087 - lr: 0.0071 - val_loss: 0.1805 - val_auc: 0.8122
# Epoch 70/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8087 - lr: 0.0069 - val_loss: 0.1805 - val_auc: 0.8121
# Epoch 71/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1784 - auc: 0.8088 - lr: 0.0067 - val_loss: 0.1805 - val_auc: 0.8117
# Epoch 72/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1784 - auc: 0.8088 - lr: 0.0065 - val_loss: 0.1805 - val_auc: 0.8107
# Epoch 73/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8089 - lr: 0.0063 - val_loss: 0.1805 - val_auc: 0.8116
# Epoch 74/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8090 - lr: 0.0062 - val_loss: 0.1806 - val_auc: 0.8122
# Epoch 75/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8089 - lr: 0.0060 - val_loss: 0.1806 - val_auc: 0.8115
# Epoch 76/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8090 - lr: 0.0058 - val_loss: 0.1806 - val_auc: 0.8106
# Epoch 77/200
# 619/619 [==============================] - 16s 24ms/step - loss: 0.1783 - auc: 0.8091 - lr: 0.0056 - val_loss: 0.1806 - val_auc: 0.8104
# Epoch 78/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8091 - lr: 0.0055 - val_loss: 0.1806 - val_auc: 0.8095
# Epoch 79/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8091 - lr: 0.0053 - val_loss: 0.1806 - val_auc: 0.8098
# Epoch 80/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8091 - lr: 0.0052 - val_loss: 0.1806 - val_auc: 0.8102
# Epoch 81/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8092 - lr: 0.0050 - val_loss: 0.1806 - val_auc: 0.8098
# Epoch 82/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8093 - lr: 0.0049 - val_loss: 0.1806 - val_auc: 0.8091
# Epoch 83/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8093 - lr: 0.0048 - val_loss: 0.1806 - val_auc: 0.8092
# Epoch 84/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8093 - lr: 0.0046 - val_loss: 0.1806 - val_auc: 0.8090
# Epoch 85/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8092 - lr: 0.0045 - val_loss: 0.1806 - val_auc: 0.8086
# Epoch 86/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8093 - lr: 0.0044 - val_loss: 0.1805 - val_auc: 0.8098
# Epoch 87/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8094 - lr: 0.0042 - val_loss: 0.1806 - val_auc: 0.8093
# Epoch 88/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8094 - lr: 0.0041 - val_loss: 0.1805 - val_auc: 0.8096
# Epoch 89/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8095 - lr: 0.0040 - val_loss: 0.1805 - val_auc: 0.8091
# Epoch 90/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8095 - lr: 0.0039 - val_loss: 0.1805 - val_auc: 0.8083
# Epoch 91/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8096 - lr: 0.0038 - val_loss: 0.1805 - val_auc: 0.8099
# Epoch 92/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8097 - lr: 0.0037 - val_loss: 0.1805 - val_auc: 0.8083
# Epoch 93/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8097 - lr: 0.0036 - val_loss: 0.1805 - val_auc: 0.8093
# Epoch 94/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8099 - lr: 0.0035 - val_loss: 0.1805 - val_auc: 0.8099
# Epoch 95/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1783 - auc: 0.8099 - lr: 0.0034 - val_loss: 0.1805 - val_auc: 0.8099
# Epoch 96/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1783 - auc: 0.8099 - lr: 0.0033 - val_loss: 0.1805 - val_auc: 0.8095
# Epoch 97/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8100 - lr: 0.0032 - val_loss: 0.1805 - val_auc: 0.8100
# Epoch 98/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8100 - lr: 0.0031 - val_loss: 0.1805 - val_auc: 0.8097
# Epoch 99/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8101 - lr: 0.0030 - val_loss: 0.1805 - val_auc: 0.8103
# Epoch 100/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8101 - lr: 0.0029 - val_loss: 0.1805 - val_auc: 0.8102
# Epoch 101/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8102 - lr: 0.0028 - val_loss: 0.1805 - val_auc: 0.8103
# Epoch 102/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8102 - lr: 0.0028 - val_loss: 0.1805 - val_auc: 0.8103
# Epoch 103/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8102 - lr: 0.0027 - val_loss: 0.1805 - val_auc: 0.8101
# Epoch 104/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8102 - lr: 0.0026 - val_loss: 0.1805 - val_auc: 0.8111
# Epoch 105/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8103 - lr: 0.0025 - val_loss: 0.1805 - val_auc: 0.8113
# Epoch 106/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8103 - lr: 0.0025 - val_loss: 0.1805 - val_auc: 0.8103
# Epoch 107/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8103 - lr: 0.0024 - val_loss: 0.1805 - val_auc: 0.8111
# Epoch 108/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8103 - lr: 0.0023 - val_loss: 0.1805 - val_auc: 0.8106
# Epoch 109/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8104 - lr: 0.0023 - val_loss: 0.1805 - val_auc: 0.8115
# Epoch 110/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8104 - lr: 0.0022 - val_loss: 0.1805 - val_auc: 0.8124
# Epoch 111/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8104 - lr: 0.0021 - val_loss: 0.1805 - val_auc: 0.8119
# Epoch 112/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8104 - lr: 0.0021 - val_loss: 0.1805 - val_auc: 0.8123
# Epoch 113/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1783 - auc: 0.8105 - lr: 0.0020 - val_loss: 0.1805 - val_auc: 0.8121
# Epoch 114/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8105 - lr: 0.0020 - val_loss: 0.1805 - val_auc: 0.8123
# Epoch 115/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1783 - auc: 0.8105 - lr: 0.0019 - val_loss: 0.1805 - val_auc: 0.8125
# Epoch 116/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8105 - lr: 0.0019 - val_loss: 0.1805 - val_auc: 0.8123
# Epoch 117/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1783 - auc: 0.8105 - lr: 0.0018 - val_loss: 0.1805 - val_auc: 0.8118
# Epoch 118/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1783 - auc: 0.8106 - lr: 0.0018 - val_loss: 0.1805 - val_auc: 0.8112
# Epoch 119/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1783 - auc: 0.8106 - lr: 0.0017 - val_loss: 0.1805 - val_auc: 0.8124
# Epoch 120/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8106 - lr: 0.0017 - val_loss: 0.1805 - val_auc: 0.8127
# Epoch 121/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8106 - lr: 0.0016 - val_loss: 0.1805 - val_auc: 0.8120
# Epoch 122/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8106 - lr: 0.0016 - val_loss: 0.1805 - val_auc: 0.8121
# Epoch 123/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8106 - lr: 0.0015 - val_loss: 0.1805 - val_auc: 0.8129
# Epoch 124/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0015 - val_loss: 0.1805 - val_auc: 0.8127
# Epoch 125/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8106 - lr: 0.0014 - val_loss: 0.1805 - val_auc: 0.8124
# Epoch 126/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0014 - val_loss: 0.1804 - val_auc: 0.8126
# Epoch 127/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0014 - val_loss: 0.1804 - val_auc: 0.8127
# Epoch 128/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0013 - val_loss: 0.1804 - val_auc: 0.8121
# Epoch 129/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0013 - val_loss: 0.1804 - val_auc: 0.8123
# Epoch 130/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0012 - val_loss: 0.1804 - val_auc: 0.8131
# Epoch 131/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0012 - val_loss: 0.1804 - val_auc: 0.8132
# Epoch 132/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8107 - lr: 0.0012 - val_loss: 0.1804 - val_auc: 0.8125
# Epoch 133/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8108 - lr: 0.0011 - val_loss: 0.1804 - val_auc: 0.8131
# Epoch 134/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8108 - lr: 0.0011 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 135/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8108 - lr: 0.0011 - val_loss: 0.1804 - val_auc: 0.8129
# Epoch 136/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8108 - lr: 0.0011 - val_loss: 0.1804 - val_auc: 0.8136
# Epoch 137/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8108 - lr: 0.0010 - val_loss: 0.1804 - val_auc: 0.8127
# Epoch 138/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8108 - lr: 9.9246e-04 - val_loss: 0.1804 - val_auc: 0.8119
# Epoch 139/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8108 - lr: 9.6457e-04 - val_loss: 0.1804 - val_auc: 0.8125
# Epoch 140/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8108 - lr: 9.3746e-04 - val_loss: 0.1804 - val_auc: 0.8125
# Epoch 141/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8109 - lr: 9.1112e-04 - val_loss: 0.1804 - val_auc: 0.8127
# Epoch 142/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8109 - lr: 8.8551e-04 - val_loss: 0.1804 - val_auc: 0.8130
# Epoch 143/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8109 - lr: 8.6063e-04 - val_loss: 0.1804 - val_auc: 0.8130
# Epoch 144/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8109 - lr: 8.3644e-04 - val_loss: 0.1804 - val_auc: 0.8130
# Epoch 145/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8109 - lr: 8.1293e-04 - val_loss: 0.1804 - val_auc: 0.8131
# Epoch 146/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8109 - lr: 7.9009e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 147/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8109 - lr: 7.6788e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 148/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8109 - lr: 7.4630e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 149/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8110 - lr: 7.2533e-04 - val_loss: 0.1804 - val_auc: 0.8136
# Epoch 150/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8110 - lr: 7.0494e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 151/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8110 - lr: 6.8513e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 152/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8110 - lr: 6.6588e-04 - val_loss: 0.1804 - val_auc: 0.8135
# Epoch 153/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8111 - lr: 6.4716e-04 - val_loss: 0.1804 - val_auc: 0.8135
# Epoch 154/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8111 - lr: 6.2898e-04 - val_loss: 0.1804 - val_auc: 0.8132
# Epoch 155/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 6.1130e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 156/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.9412e-04 - val_loss: 0.1804 - val_auc: 0.8131
# Epoch 157/200
# 619/619 [==============================] - 15s 24ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.7742e-04 - val_loss: 0.1804 - val_auc: 0.8131
# Epoch 158/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.6120e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 159/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.4542e-04 - val_loss: 0.1804 - val_auc: 0.8134
# Epoch 160/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.3010e-04 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 161/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.1520e-04 - val_loss: 0.1804 - val_auc: 0.8130
# Epoch 162/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 5.0072e-04 - val_loss: 0.1804 - val_auc: 0.8136
# Epoch 163/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 4.8665e-04 - val_loss: 0.1804 - val_auc: 0.8136
# Epoch 164/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8111 - lr: 4.7297e-04 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 165/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 4.5968e-04 - val_loss: 0.1804 - val_auc: 0.8132
# Epoch 166/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 4.4676e-04 - val_loss: 0.1804 - val_auc: 0.8130
# Epoch 167/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 4.3420e-04 - val_loss: 0.1804 - val_auc: 0.8135
# Epoch 168/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 4.2200e-04 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 169/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 4.1014e-04 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 170/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.9862e-04 - val_loss: 0.1804 - val_auc: 0.8133
# Epoch 171/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.8741e-04 - val_loss: 0.1804 - val_auc: 0.8139
# Epoch 172/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.7653e-04 - val_loss: 0.1804 - val_auc: 0.8138
# Epoch 173/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.6594e-04 - val_loss: 0.1804 - val_auc: 0.8139
# Epoch 174/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.5566e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 175/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.4566e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 176/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.3595e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 177/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.2651e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 178/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.1733e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 179/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 3.0841e-04 - val_loss: 0.1804 - val_auc: 0.8145
# Epoch 180/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.9975e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 181/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8112 - lr: 2.9132e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 182/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 2.8314e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 183/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 2.7518e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 184/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.6745e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 185/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.5993e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 186/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 2.5262e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 187/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8112 - lr: 2.4552e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 188/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.3862e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 189/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.3192e-04 - val_loss: 0.1804 - val_auc: 0.8145
# Epoch 190/200
# 619/619 [==============================] - 17s 27ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.2540e-04 - val_loss: 0.1804 - val_auc: 0.8145
# Epoch 191/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.1907e-04 - val_loss: 0.1804 - val_auc: 0.8145
# Epoch 192/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.1291e-04 - val_loss: 0.1804 - val_auc: 0.8146
# Epoch 193/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.0693e-04 - val_loss: 0.1804 - val_auc: 0.8143
# Epoch 194/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8113 - lr: 2.0111e-04 - val_loss: 0.1804 - val_auc: 0.8146
# Epoch 195/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.9546e-04 - val_loss: 0.1804 - val_auc: 0.8145
# Epoch 196/200
# 619/619 [==============================] - 15s 24ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.8997e-04 - val_loss: 0.1804 - val_auc: 0.8146
# Epoch 197/200
# 619/619 [==============================] - 16s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.8463e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 198/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.7944e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 199/200
# 619/619 [==============================] - 16s 25ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.7440e-04 - val_loss: 0.1804 - val_auc: 0.8144
# Epoch 200/200
# 619/619 [==============================] - 17s 26ms/step - loss: 0.1782 - auc: 0.8113 - lr: 1.6949e-04 - val_loss: 0.1804 - val_auc: 0.8144

# %%
from datetime import datetime

model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.0),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(1e-4),
)
early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=5)

callbacks = None  # [early_stop]

train_ft = model.fit(data_train, epochs=int(num_epochs/2.0), validation_data=data_val, callbacks=callbacks)

prefix = ""
timestamp = str(datetime.now())
timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
    prefix += time + unit  # YYYYMMDD-HHhMMmSSs
# Out:
# Epoch 1/100
# 619/619 [==============================] - 20s 26ms/step - loss: 0.0931 - auc: 0.7976 - val_loss: 0.0928 - val_auc: 0.8156
# Epoch 2/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0898 - auc: 0.8070 - val_loss: 0.0918 - val_auc: 0.8155
# Epoch 3/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0892 - auc: 0.8084 - val_loss: 0.0916 - val_auc: 0.8150
# Epoch 4/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0890 - auc: 0.8087 - val_loss: 0.0916 - val_auc: 0.8136
# Epoch 5/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0889 - auc: 0.8089 - val_loss: 0.0915 - val_auc: 0.8133
# Epoch 6/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0889 - auc: 0.8091 - val_loss: 0.0915 - val_auc: 0.8130
# Epoch 7/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0889 - auc: 0.8092 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 8/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0889 - auc: 0.8093 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 9/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8094 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 10/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0888 - auc: 0.8094 - val_loss: 0.0915 - val_auc: 0.8129
# Epoch 11/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0888 - auc: 0.8095 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 12/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0888 - auc: 0.8096 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 13/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0888 - auc: 0.8097 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 14/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0888 - auc: 0.8097 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 15/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8098 - val_loss: 0.0916 - val_auc: 0.8126
# Epoch 16/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8098 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 17/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8099 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 18/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8100 - val_loss: 0.0916 - val_auc: 0.8134
# Epoch 19/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8100 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 20/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0888 - auc: 0.8101 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 21/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8101 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 22/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8101 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 23/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8101 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 24/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8101 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 25/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8102 - val_loss: 0.0916 - val_auc: 0.8131
# Epoch 26/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8102 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 27/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8102 - val_loss: 0.0916 - val_auc: 0.8131
# Epoch 28/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8102 - val_loss: 0.0916 - val_auc: 0.8131
# Epoch 29/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8130
# Epoch 30/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 31/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 32/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8129
# Epoch 33/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8129
# Epoch 34/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 35/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 36/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8131
# Epoch 37/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8103 - val_loss: 0.0916 - val_auc: 0.8131
# Epoch 38/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 39/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 40/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 41/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 42/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8136
# Epoch 43/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8134
# Epoch 44/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8135
# Epoch 45/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8134
# Epoch 46/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 47/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8132
# Epoch 48/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8104 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 49/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8133
# Epoch 50/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8134
# Epoch 51/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8136
# Epoch 52/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8135
# Epoch 53/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8135
# Epoch 54/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 55/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 56/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 57/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8129
# Epoch 58/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8129
# Epoch 59/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8128
# Epoch 60/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0916 - val_auc: 0.8127
# Epoch 61/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 62/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 63/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8130
# Epoch 64/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8130
# Epoch 65/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8130
# Epoch 66/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 67/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 68/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 69/100
# 619/619 [==============================] - 16s 24ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8133
# Epoch 70/100
# 619/619 [==============================] - 15s 24ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8133
# Epoch 71/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8105 - val_loss: 0.0915 - val_auc: 0.8133
# Epoch 72/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8133
# Epoch 73/100
# 619/619 [==============================] - 15s 24ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8134
# Epoch 74/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8135
# Epoch 75/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8135
# Epoch 76/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8135
# Epoch 77/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8135
# Epoch 78/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 79/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8132
# Epoch 80/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 81/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 82/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 83/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 84/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 85/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8129
# Epoch 86/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8131
# Epoch 87/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8129
# Epoch 88/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 89/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 90/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8127
# Epoch 91/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8127
# Epoch 92/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8126
# Epoch 93/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8125
# Epoch 94/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 95/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8128
# Epoch 96/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8107 - val_loss: 0.0915 - val_auc: 0.8127
# Epoch 97/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8107 - val_loss: 0.0915 - val_auc: 0.8124
# Epoch 98/100
# 619/619 [==============================] - 17s 26ms/step - loss: 0.0887 - auc: 0.8107 - val_loss: 0.0915 - val_auc: 0.8125
# Epoch 99/100
# 619/619 [==============================] - 16s 25ms/step - loss: 0.0887 - auc: 0.8106 - val_loss: 0.0915 - val_auc: 0.8124
# Epoch 100/100
# 619/619 [==============================] - 16s 26ms/step - loss: 0.0887 - auc: 0.8107 - val_loss: 0.0915 - val_auc: 0.8124

# %% [markdown]
# The two regimes are well visibile in the plot below, combining the two training phases in a single epoch count.

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Binary cross-entropy", fontsize=12)
plt.plot(train.history["loss"][1:] + train_ft.history["loss"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_loss"][1:] + train_ft.history["val_loss"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("ROC AUC", fontsize=12)
plt.plot(train.history["auc"][1:] + train_ft.history["auc"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_auc"][1:] + train_ft.history["val_auc"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.show()

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-isMuon-proton-train.csv")

train_history_ft = train_ft.history.copy()
train_history_ft.update({"lr": [1e-4 for _ in range(int(num_epochs/2.0))]})
pd.DataFrame(train_history_ft).to_csv(f"./exports/{prefix}-isMuon-proton-train-ft.csv")

# %% [markdown]
# ## A first, rough validation
#
# While a proper validation of the model is demanded to a dedicated notebook (still to be prepared), here we check that the training was not completely failed and provides reasonable numbers.
#
# In particular, we compare the distributions of the training labels and of the predictions.
#
# Clearly, the training labels are either 1 or 0 because a particle passes either isMuon or not. Instead, the output of the neural network is a probability and hence it will be distributed between 0 and 1.
#
# The comparison is used to ensure that both the training labels and the network output are not unreasonable, for example collapsed into a single value or with training labels belonging to a single category.

# %%
reader_test = FeatherReader(environ.get("ISMUON_PROTON_TEST_DATA", f"{DATA_PATH}/isMuon-proton-{SAMPLE}-test"), max_files=5)
ds_test = reader_test.as_tf_dataset()

# %%
X_test, y_test = next(iter(ds_test.batch(20_000_000).as_numpy_iterator()))
preds = model.predict(X_test, batch_size=50_000)
# Out:
# 297/297 [==============================] - 2s 5ms/step

# %%
bins = np.linspace(0, 1, 11)
plt.hist(y_test, bins=bins, label="Simulation")
plt.hist(preds, bins=bins, histtype='step', linewidth=2, label="Predictions")
plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# Then we can compare the distribution of a preprocessed variable before and after the application of the isMuon criterion.
#
# Here, for example, we consider the preprocessed of the momentum $p$.
#
# Since the variable is preprocessed, without applying any cut (**Generated**) we have a perfectly normalized Gaussian.
#
# Applying the criterion `isMuon == 1`, we get another distribution that we expect to model with decent approximation by applying the response of the trained neural networks as weights to the **Generated** dataset.
#
# The comparison of the two histograms (obtained by applying a cut on the true isMuon or applying a weight on the isMuon probability) provides a first validation on the quality of the parametrization.

# %%
prep_p = X_test[:, 0]
bins = np.linspace(-5, 5, 101)

denominator, _ = np.histogram(prep_p, bins=bins)
true_numerator, _ = np.histogram(prep_p, bins=bins, weights=y_test.flatten())
predicted_numerator, _ = np.histogram(prep_p, bins=bins, weights=preds.flatten())

plt.xlabel("Preprocessed $p$ [GeV/$c$]")

plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=denominator, label="Generated protons", histtype='step')
plt.fill_between(
    (bins[1:] + bins[:-1])/2, np.zeros(len(true_numerator)), true_numerator,
    label="isMuon passed (sim)",
    color='#88ee88'
)
plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=predicted_numerator, label="isMuon passed (model)", histtype='step', linewidth=2)

plt.legend(loc="upper left", fontsize=10)
plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
models_dir = "/home/mabarbet/PythonFastSim/models/isMuon_proton_models"

# %%
import pickle

file_path = f"{models_dir}/tX_{SAMPLE}.pkl"

with open(file_path, "rb") as file:
    X_scaler = pickle.load(file)

# %%
import json

with open(f"{DATA_PATH}/isMuon-proton-{SAMPLE}-test/definitions.json") as json_file:
    definitions = json.load(json_file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer

print(f"Shapes:", X_test.shape, y_test.shape, preds.shape)

X_post = invertColumnTransformer(X_scaler, X_test)
np.savez_compressed(
    f"./exports/{prefix}-isMuon-proton-results.npz",
    feat_vars=np.array(definitions["features"]),
    label_vars=np.array(definitions["labels"]),
    results=np.c_[X_post, y_test, preds][:5_000_000],
)
# Out:
# Shapes: (14831908, 4) (14831908, 1) (14831908, 1)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_isMuon_proton_{SAMPLE}_ann"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    model.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_proton_models/20231229-19h45m38s_isMuon_proton_2016MU_model/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_proton_models/20231229-19h45m38s_isMuon_proton_2016MU_model/assets
