# %% [markdown]
# # Training of the _GlobalPID_ model for _muons_ passing the isMuon criterion
#
# In this notebook we setup the training for the GlobalPID model for _muons_ that pass the isMuon criterion, based on Generative Adversarial Networks (GAN).
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [GlobalPID-preprocessing.ipynb](./GlobalPID-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"
TEST = False

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("GLOBALPID_IM_MUON_TRAIN_DATA", f"{DATA_PATH}/GlobalPID-im-muon-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("GLOBALPID_IM_MUON_VAL_DATA", f"{DATA_PATH}/GlobalPID-im-muon-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
x_vars = reader_train.features
y_vars = reader_train.labels

x_vars, y_vars
# Out:
# (['p_GeV',
#   'eta',
#   'nTracks_f',
#   'RichDLLe',
#   'RichDLLmu',
#   'RichDLLk',
#   'RichDLLp',
#   'MuonMuLL',
#   'MuonBgLL',
#   'charge'],
#  ['PIDe',
#   'PIDK',
#   'PIDp',
#   'ProbNNe',
#   'ProbNNpi',
#   'ProbNNk',
#   'ProbNNp',
#   'PIDmu',
#   'ProbNNmu'])

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 10]), TensorShape([500000, 9]))

# %% [markdown]
# ## Model definition
#
# TBA

# %% [markdown]
# ### Generator architecture
#
# TBA

# %%
from pidgan.players.generators import ResGenerator

generator = ResGenerator(
    output_dim=y.shape[1],
    latent_dim=64,
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    output_activation=None,
    name="generator",
)

# %%
generator(X[:256])
generator.summary()
# Out:
# Model: "generator_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 74)]                 0         []
#
#  dense_0 (Dense)             (None, 128)                  9600      ['input_1[0][0]']
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)                  0         ['dense_0[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['leaky_relu_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)                  0         ['dense_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['leaky_relu_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)                  0         ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['leaky_relu_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)                  0         ['dense_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['leaky_relu_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)                  0         ['dense_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['leaky_relu_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_out (Dense)           (None, 9)                    1161      ['add_3-4[0][0]']
#
# ==================================================================================================
# Total params: 76809 (300.04 KB)
# Trainable params: 76809 (300.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    generator.export_model,
    to_file="./images/GlobalPID-im-muon-generator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Discriminator architecture
#
# TBA

# %%
from pidgan.players.discriminators import AuxDiscriminator

discriminator = AuxDiscriminator(
    output_dim=1,
    aux_features=["3 - 0", "2 - 1"],  # ["PIDmu - PIDe", "PIDK - PIDp"]
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    enable_residual_blocks=True,
    output_activation=None,
    name="discriminator",
)

# %%
discriminator((X[:256], y[:256]))
discriminator.summary()
# Out:
# Model: "discriminator_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 21)]                 0         []
#
#  dense_0 (Dense)             (None, 128)                  2816      ['input_2[0][0]']
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)                  0         ['dense_0[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['leaky_relu_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)                  0         ['dense_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['leaky_relu_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)                  0         ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['leaky_relu_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)                  0         ['dense_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['leaky_relu_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)                  0         ['dense_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['leaky_relu_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_out (Dense)           (None, 1)                    129       ['add_3-4[0][0]']
#
# ==================================================================================================
# Total params: 68993 (269.50 KB)
# Trainable params: 68993 (269.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    discriminator.export_model,
    to_file="./images/GlobalPID-im-muon-discriminator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Referee architecture

# %%
from pidgan.players.classifiers import Classifier

referee = Classifier(
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=None,
    mlp_dropout_rates=0.0,
    name="referee",
)

# %%
referee((X[:256], y[:256]))
referee.summary()
# Out:
# Model: "referee_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             (256, 128)                2560
#
#  dropout_0 (Dropout)         (256, 128)                0
#
#  dense_1 (Dense)             (256, 128)                16512
#
#  dropout_1 (Dropout)         (256, 128)                0
#
#  dense_2 (Dense)             (256, 128)                16512
#
#  dropout_2 (Dropout)         (256, 128)                0
#
#  dense_3 (Dense)             (256, 128)                16512
#
#  dropout_3 (Dropout)         (256, 128)                0
#
#  dense_4 (Dense)             (256, 128)                16512
#
#  dropout_4 (Dropout)         (256, 128)                0
#
#  dense_out (Dense)           (256, 1)                  129
#
# =================================================================
# Total params: 68737 (268.50 KB)
# Trainable params: 68737 (268.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    referee.export_model,
    to_file="./images/GlobalPID-im-muon-referee.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Training setup
#
# TBA

# %%
from pidgan.algorithms import BceGAN_ALP

gan = BceGAN_ALP(
    generator=generator,
    discriminator=discriminator,
    lipschitz_penalty=1.0,
    lipschitz_penalty_strategy="one-sided",
    feature_matching_penalty=0.0,
    # referee=referee,
)

# %%
from tensorflow.keras.optimizers import RMSprop, Adam

g_lr0 = 6e-4
d_lr0 = 4e-4

gan.compile(
    metrics=["wass_dist"],
    generator_optimizer=RMSprop(g_lr0),
    discriminator_optimizer=RMSprop(d_lr0),
    generator_upds_per_batch=1,
    discriminator_upds_per_batch=1,
    # referee_optimizer=Adam(1e-3),
    # referee_upds_per_batch=1,
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

callbacks = list()

g_lr_sched = LearnRateExpDecay(
    gan.generator_optimizer,
    decay_rate=0.1,
    decay_steps=120_000,
    min_learning_rate=g_lr0/1e3,
    verbose=True,
    key="g_lr",
)
callbacks.append(g_lr_sched)

d_lr_sched = LearnRateExpDecay(
    gan.discriminator_optimizer,
    decay_rate=0.1,
    decay_steps=190_000,
    min_learning_rate=d_lr0/1e3,
    verbose=True,
    key="d_lr",
)
callbacks.append(d_lr_sched)

# r_lr_sched = LearnRateExpDecay(
#     gan.referee_optimizer,
#     decay_rate=0.1,
#     decay_steps=150_000,
#     verbose=True,
#     key="r_lr",
# )
# callbacks.append(r_lr_sched)

# %%
from datetime import datetime

batch_size = 10_000
num_epochs = 500 if not TEST else 150

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

train = gan.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)

if not TEST:
    prefix = ""
    timestamp = str(datetime.now())
    timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
    for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
        prefix += time + unit  # YYYYMMDD-HHhMMmSSs
else:
    prefix = "test"
# Out:
# Epoch 1/500
#       4/Unknown - 11s 18ms/step - g_loss: 2.6761 - d_loss: 1.2115 - wass_dist: 0.6820 - g_lr: 5.9998e-04 - d_lr: 3.9999e-04WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0139s vs `on_train_batch_begin` time: 0.1712s). Check your callbacks.
# 453/453 [==============================] - 22s 25ms/step - g_loss: 0.8973 - d_loss: 0.6445 - wass_dist: -0.1417 - g_lr: 5.9740e-04 - d_lr: 3.9890e-04 - val_g_loss: 0.8096 - val_d_loss: 0.6635 - val_wass_dist: -0.1640
# Epoch 2/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7734 - d_loss: 0.6742 - wass_dist: -0.1020 - g_lr: 5.9222e-04 - d_lr: 3.9672e-04 - val_g_loss: 0.6716 - val_d_loss: 0.6746 - val_wass_dist: -0.1601
# Epoch 3/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7869 - d_loss: 0.6777 - wass_dist: -0.1328 - g_lr: 5.8709e-04 - d_lr: 3.9454e-04 - val_g_loss: 0.8335 - val_d_loss: 0.6691 - val_wass_dist: -0.1959
# Epoch 4/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7704 - d_loss: 0.6921 - wass_dist: -0.0507 - g_lr: 5.8201e-04 - d_lr: 3.9238e-04 - val_g_loss: 0.6852 - val_d_loss: 0.6829 - val_wass_dist: -0.1124
# Epoch 5/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7518 - d_loss: 0.6985 - wass_dist: -0.0325 - g_lr: 5.7697e-04 - d_lr: 3.9024e-04 - val_g_loss: 0.7025 - val_d_loss: 0.6854 - val_wass_dist: -0.0440
# Epoch 6/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7366 - d_loss: 0.6942 - wass_dist: -0.0081 - g_lr: 5.7198e-04 - d_lr: 3.8810e-04 - val_g_loss: 0.6802 - val_d_loss: 0.6915 - val_wass_dist: -0.0312
# Epoch 7/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7265 - d_loss: 0.6931 - wass_dist: -0.0026 - g_lr: 5.6703e-04 - d_lr: 3.8597e-04 - val_g_loss: 0.6491 - val_d_loss: 0.6947 - val_wass_dist: -3.6683e-05
# Epoch 8/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7200 - d_loss: 0.6929 - wass_dist: -0.0051 - g_lr: 5.6212e-04 - d_lr: 3.8386e-04 - val_g_loss: 0.6706 - val_d_loss: 0.6923 - val_wass_dist: -0.0051
# Epoch 9/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7163 - d_loss: 0.6934 - wass_dist: -0.0138 - g_lr: 5.5726e-04 - d_lr: 3.8176e-04 - val_g_loss: 0.6966 - val_d_loss: 0.6900 - val_wass_dist: -0.0129
# Epoch 10/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7126 - d_loss: 0.6925 - wass_dist: -0.0073 - g_lr: 5.5244e-04 - d_lr: 3.7967e-04 - val_g_loss: 0.6796 - val_d_loss: 0.6921 - val_wass_dist: 0.0068
# Epoch 11/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7109 - d_loss: 0.6924 - wass_dist: -0.0057 - g_lr: 5.4765e-04 - d_lr: 3.7759e-04 - val_g_loss: 0.7081 - val_d_loss: 0.6930 - val_wass_dist: 0.0086
# Epoch 12/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7096 - d_loss: 0.6924 - wass_dist: -0.0044 - g_lr: 5.4291e-04 - d_lr: 3.7552e-04 - val_g_loss: 0.6878 - val_d_loss: 0.6935 - val_wass_dist: 0.0086
# Epoch 13/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7083 - d_loss: 0.6924 - wass_dist: -1.0793e-04 - g_lr: 5.3822e-04 - d_lr: 3.7347e-04 - val_g_loss: 0.6904 - val_d_loss: 0.6945 - val_wass_dist: 0.0238
# Epoch 14/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7073 - d_loss: 0.6924 - wass_dist: -0.0083 - g_lr: 5.3356e-04 - d_lr: 3.7142e-04 - val_g_loss: 0.6869 - val_d_loss: 0.6919 - val_wass_dist: 0.0038
# Epoch 15/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7065 - d_loss: 0.6924 - wass_dist: -0.0019 - g_lr: 5.2894e-04 - d_lr: 3.6939e-04 - val_g_loss: 0.6965 - val_d_loss: 0.6940 - val_wass_dist: -0.0058
# Epoch 16/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7058 - d_loss: 0.6924 - wass_dist: -0.0025 - g_lr: 5.2436e-04 - d_lr: 3.6737e-04 - val_g_loss: 0.6771 - val_d_loss: 0.6933 - val_wass_dist: -0.0208
# Epoch 17/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7053 - d_loss: 0.6923 - wass_dist: -0.0044 - g_lr: 5.1982e-04 - d_lr: 3.6536e-04 - val_g_loss: 0.6877 - val_d_loss: 0.6923 - val_wass_dist: -0.0023
# Epoch 18/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7049 - d_loss: 0.6923 - wass_dist: -0.0064 - g_lr: 5.1533e-04 - d_lr: 3.6336e-04 - val_g_loss: 0.6854 - val_d_loss: 0.6921 - val_wass_dist: 0.0115
# Epoch 19/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7043 - d_loss: 0.6923 - wass_dist: -0.0042 - g_lr: 5.1087e-04 - d_lr: 3.6137e-04 - val_g_loss: 0.6987 - val_d_loss: 0.6927 - val_wass_dist: 0.0289
# Epoch 20/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7038 - d_loss: 0.6923 - wass_dist: -0.0058 - g_lr: 5.0644e-04 - d_lr: 3.5939e-04 - val_g_loss: 0.6915 - val_d_loss: 0.6927 - val_wass_dist: -0.0112
# Epoch 21/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7034 - d_loss: 0.6923 - wass_dist: -0.0076 - g_lr: 5.0206e-04 - d_lr: 3.5742e-04 - val_g_loss: 0.6998 - val_d_loss: 0.6922 - val_wass_dist: -0.0129
# Epoch 22/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7030 - d_loss: 0.6923 - wass_dist: -0.0064 - g_lr: 4.9772e-04 - d_lr: 3.5546e-04 - val_g_loss: 0.6959 - val_d_loss: 0.6922 - val_wass_dist: 0.0073
# Epoch 23/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7028 - d_loss: 0.6923 - wass_dist: -0.0020 - g_lr: 4.9341e-04 - d_lr: 3.5352e-04 - val_g_loss: 0.6811 - val_d_loss: 0.6933 - val_wass_dist: 0.0020
# Epoch 24/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7027 - d_loss: 0.6923 - wass_dist: -0.0040 - g_lr: 4.8914e-04 - d_lr: 3.5158e-04 - val_g_loss: 0.6958 - val_d_loss: 0.6928 - val_wass_dist: 0.0116
# Epoch 25/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7024 - d_loss: 0.6923 - wass_dist: -0.0059 - g_lr: 4.8491e-04 - d_lr: 3.4966e-04 - val_g_loss: 0.6909 - val_d_loss: 0.6924 - val_wass_dist: 0.0037
# Epoch 26/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7023 - d_loss: 0.6923 - wass_dist: 2.2080e-04 - g_lr: 4.8071e-04 - d_lr: 3.4774e-04 - val_g_loss: 0.6927 - val_d_loss: 0.6942 - val_wass_dist: 0.0178
# Epoch 27/500
# 453/453 [==============================] - 12s 24ms/step - g_loss: 0.7022 - d_loss: 0.6923 - wass_dist: -0.0042 - g_lr: 4.7655e-04 - d_lr: 3.4584e-04 - val_g_loss: 0.6797 - val_d_loss: 0.6926 - val_wass_dist: -0.0083
# Epoch 28/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7022 - d_loss: 0.6923 - wass_dist: -0.0012 - g_lr: 4.7242e-04 - d_lr: 3.4395e-04 - val_g_loss: 0.6812 - val_d_loss: 0.6933 - val_wass_dist: 0.0127
# Epoch 29/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7021 - d_loss: 0.6923 - wass_dist: -0.0043 - g_lr: 4.6834e-04 - d_lr: 3.4206e-04 - val_g_loss: 0.6898 - val_d_loss: 0.6926 - val_wass_dist: 0.0070
# Epoch 30/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7021 - d_loss: 0.6923 - wass_dist: -0.0042 - g_lr: 4.6428e-04 - d_lr: 3.4019e-04 - val_g_loss: 0.6890 - val_d_loss: 0.6927 - val_wass_dist: 0.0101
# Epoch 31/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7020 - d_loss: 0.6922 - wass_dist: -0.0039 - g_lr: 4.6026e-04 - d_lr: 3.3833e-04 - val_g_loss: 0.6903 - val_d_loss: 0.6928 - val_wass_dist: 0.0025
# Epoch 32/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7019 - d_loss: 0.6923 - wass_dist: -0.0051 - g_lr: 4.5628e-04 - d_lr: 3.3647e-04 - val_g_loss: 0.6877 - val_d_loss: 0.6929 - val_wass_dist: -0.0067
# Epoch 33/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7018 - d_loss: 0.6923 - wass_dist: -0.0056 - g_lr: 4.5233e-04 - d_lr: 3.3463e-04 - val_g_loss: 0.6871 - val_d_loss: 0.6926 - val_wass_dist: 0.0082
# Epoch 34/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7017 - d_loss: 0.6923 - wass_dist: -0.0067 - g_lr: 4.4842e-04 - d_lr: 3.3280e-04 - val_g_loss: 0.6937 - val_d_loss: 0.6926 - val_wass_dist: 0.0023
# Epoch 35/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7016 - d_loss: 0.6923 - wass_dist: -0.0057 - g_lr: 4.4454e-04 - d_lr: 3.3098e-04 - val_g_loss: 0.6877 - val_d_loss: 0.6926 - val_wass_dist: 0.0135
# Epoch 36/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7015 - d_loss: 0.6924 - wass_dist: -0.0058 - g_lr: 4.4069e-04 - d_lr: 3.2917e-04 - val_g_loss: 0.6890 - val_d_loss: 0.6927 - val_wass_dist: 0.0026
# Epoch 37/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7014 - d_loss: 0.6924 - wass_dist: -0.0064 - g_lr: 4.3687e-04 - d_lr: 3.2736e-04 - val_g_loss: 0.6947 - val_d_loss: 0.6926 - val_wass_dist: 0.0232
# Epoch 38/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7012 - d_loss: 0.6924 - wass_dist: -0.0052 - g_lr: 4.3309e-04 - d_lr: 3.2557e-04 - val_g_loss: 0.6926 - val_d_loss: 0.6929 - val_wass_dist: 0.0135
# Epoch 39/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7011 - d_loss: 0.6924 - wass_dist: -0.0047 - g_lr: 4.2935e-04 - d_lr: 3.2379e-04 - val_g_loss: 0.6912 - val_d_loss: 0.6926 - val_wass_dist: 0.0137
# Epoch 40/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7009 - d_loss: 0.6924 - wass_dist: -0.0023 - g_lr: 4.2563e-04 - d_lr: 3.2202e-04 - val_g_loss: 0.6938 - val_d_loss: 0.6932 - val_wass_dist: -0.0026
# Epoch 41/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7008 - d_loss: 0.6924 - wass_dist: -0.0047 - g_lr: 4.2195e-04 - d_lr: 3.2025e-04 - val_g_loss: 0.6860 - val_d_loss: 0.6931 - val_wass_dist: 0.0056
# Epoch 42/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7007 - d_loss: 0.6924 - wass_dist: -0.0039 - g_lr: 4.1829e-04 - d_lr: 3.1850e-04 - val_g_loss: 0.6921 - val_d_loss: 0.6926 - val_wass_dist: 0.0056
# Epoch 43/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7006 - d_loss: 0.6925 - wass_dist: -0.0057 - g_lr: 4.1467e-04 - d_lr: 3.1676e-04 - val_g_loss: 0.6934 - val_d_loss: 0.6926 - val_wass_dist: -0.0033
# Epoch 44/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7005 - d_loss: 0.6924 - wass_dist: -0.0030 - g_lr: 4.1109e-04 - d_lr: 3.1502e-04 - val_g_loss: 0.6908 - val_d_loss: 0.6929 - val_wass_dist: 0.0107
# Epoch 45/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7005 - d_loss: 0.6924 - wass_dist: -0.0044 - g_lr: 4.0753e-04 - d_lr: 3.1330e-04 - val_g_loss: 0.6940 - val_d_loss: 0.6927 - val_wass_dist: 0.0026
# Epoch 46/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7003 - d_loss: 0.6924 - wass_dist: -0.0050 - g_lr: 4.0400e-04 - d_lr: 3.1158e-04 - val_g_loss: 0.6885 - val_d_loss: 0.6926 - val_wass_dist: -0.0063
# Epoch 47/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6925 - wass_dist: -0.0026 - g_lr: 4.0050e-04 - d_lr: 3.0988e-04 - val_g_loss: 0.6980 - val_d_loss: 0.6930 - val_wass_dist: -0.0051
# Epoch 48/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7001 - d_loss: 0.6925 - wass_dist: -0.0047 - g_lr: 3.9704e-04 - d_lr: 3.0818e-04 - val_g_loss: 0.6887 - val_d_loss: 0.6925 - val_wass_dist: 0.0068
# Epoch 49/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7000 - d_loss: 0.6925 - wass_dist: -0.0051 - g_lr: 3.9360e-04 - d_lr: 3.0649e-04 - val_g_loss: 0.6951 - val_d_loss: 0.6925 - val_wass_dist: -0.0030
# Epoch 50/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7000 - d_loss: 0.6925 - wass_dist: -0.0031 - g_lr: 3.9020e-04 - d_lr: 3.0482e-04 - val_g_loss: 0.6960 - val_d_loss: 0.6930 - val_wass_dist: -0.0089
# Epoch 51/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6999 - d_loss: 0.6925 - wass_dist: -0.0048 - g_lr: 3.8682e-04 - d_lr: 3.0315e-04 - val_g_loss: 0.6894 - val_d_loss: 0.6930 - val_wass_dist: 0.0047
# Epoch 52/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6998 - d_loss: 0.6925 - wass_dist: -0.0048 - g_lr: 3.8347e-04 - d_lr: 3.0149e-04 - val_g_loss: 0.6956 - val_d_loss: 0.6926 - val_wass_dist: 0.0057
# Epoch 53/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6999 - d_loss: 0.6925 - wass_dist: -0.0030 - g_lr: 3.8015e-04 - d_lr: 2.9984e-04 - val_g_loss: 0.6883 - val_d_loss: 0.6932 - val_wass_dist: 0.0069
# Epoch 54/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6998 - d_loss: 0.6925 - wass_dist: -0.0049 - g_lr: 3.7686e-04 - d_lr: 2.9819e-04 - val_g_loss: 0.6927 - val_d_loss: 0.6926 - val_wass_dist: 0.0017
# Epoch 55/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6997 - d_loss: 0.6925 - wass_dist: -6.3549e-04 - g_lr: 3.7360e-04 - d_lr: 2.9656e-04 - val_g_loss: 0.6882 - val_d_loss: 0.6934 - val_wass_dist: -0.0014
# Epoch 56/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6997 - d_loss: 0.6925 - wass_dist: -0.0028 - g_lr: 3.7037e-04 - d_lr: 2.9494e-04 - val_g_loss: 0.6864 - val_d_loss: 0.6932 - val_wass_dist: 0.0107
# Epoch 57/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6997 - d_loss: 0.6925 - wass_dist: 1.4990e-04 - g_lr: 3.6716e-04 - d_lr: 2.9332e-04 - val_g_loss: 0.6875 - val_d_loss: 0.6936 - val_wass_dist: -0.0057
# Epoch 58/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0049 - g_lr: 3.6398e-04 - d_lr: 2.9172e-04 - val_g_loss: 0.6923 - val_d_loss: 0.6927 - val_wass_dist: -9.0518e-05
# Epoch 59/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6997 - d_loss: 0.6925 - wass_dist: -0.0048 - g_lr: 3.6083e-04 - d_lr: 2.9012e-04 - val_g_loss: 0.6934 - val_d_loss: 0.6930 - val_wass_dist: 0.0193
# Epoch 60/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0045 - g_lr: 3.5771e-04 - d_lr: 2.8853e-04 - val_g_loss: 0.6928 - val_d_loss: 0.6929 - val_wass_dist: -1.9051e-04
# Epoch 61/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0033 - g_lr: 3.5461e-04 - d_lr: 2.8695e-04 - val_g_loss: 0.6901 - val_d_loss: 0.6932 - val_wass_dist: 0.0124
# Epoch 62/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0050 - g_lr: 3.5155e-04 - d_lr: 2.8538e-04 - val_g_loss: 0.6928 - val_d_loss: 0.6929 - val_wass_dist: 0.0188
# Epoch 63/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0023 - g_lr: 3.4850e-04 - d_lr: 2.8382e-04 - val_g_loss: 0.6883 - val_d_loss: 0.6935 - val_wass_dist: 0.0012
# Epoch 64/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6925 - wass_dist: -0.0056 - g_lr: 3.4549e-04 - d_lr: 2.8227e-04 - val_g_loss: 0.6962 - val_d_loss: 0.6929 - val_wass_dist: -0.0024
# Epoch 65/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6995 - d_loss: 0.6925 - wass_dist: -0.0053 - g_lr: 3.4250e-04 - d_lr: 2.8072e-04 - val_g_loss: 0.6893 - val_d_loss: 0.6927 - val_wass_dist: 0.0019
# Epoch 66/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6994 - d_loss: 0.6925 - wass_dist: -3.4954e-04 - g_lr: 3.3953e-04 - d_lr: 2.7918e-04 - val_g_loss: 0.6896 - val_d_loss: 0.6936 - val_wass_dist: -0.0155
# Epoch 67/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6995 - d_loss: 0.6925 - wass_dist: -0.0059 - g_lr: 3.3659e-04 - d_lr: 2.7765e-04 - val_g_loss: 0.6977 - val_d_loss: 0.6924 - val_wass_dist: 0.0091
# Epoch 68/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6995 - d_loss: 0.6925 - wass_dist: -0.0025 - g_lr: 3.3368e-04 - d_lr: 2.7613e-04 - val_g_loss: 0.6906 - val_d_loss: 0.6936 - val_wass_dist: 0.0066
# Epoch 69/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6925 - wass_dist: -0.0040 - g_lr: 3.3079e-04 - d_lr: 2.7462e-04 - val_g_loss: 0.6883 - val_d_loss: 0.6931 - val_wass_dist: -0.0067
# Epoch 70/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6925 - wass_dist: -0.0017 - g_lr: 3.2793e-04 - d_lr: 2.7312e-04 - val_g_loss: 0.6899 - val_d_loss: 0.6934 - val_wass_dist: 0.0200
# Epoch 71/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6925 - wass_dist: -0.0047 - g_lr: 3.2509e-04 - d_lr: 2.7162e-04 - val_g_loss: 0.6876 - val_d_loss: 0.6926 - val_wass_dist: 0.0162
# Epoch 72/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6994 - d_loss: 0.6925 - wass_dist: -0.0034 - g_lr: 3.2228e-04 - d_lr: 2.7014e-04 - val_g_loss: 0.6920 - val_d_loss: 0.6930 - val_wass_dist: 0.0189
# Epoch 73/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6924 - wass_dist: -0.0058 - g_lr: 3.1949e-04 - d_lr: 2.6866e-04 - val_g_loss: 0.6908 - val_d_loss: 0.6926 - val_wass_dist: 0.0099
# Epoch 74/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6994 - d_loss: 0.6924 - wass_dist: -0.0032 - g_lr: 3.1672e-04 - d_lr: 2.6719e-04 - val_g_loss: 0.6906 - val_d_loss: 0.6934 - val_wass_dist: 0.0027
# Epoch 75/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6924 - wass_dist: -0.0050 - g_lr: 3.1398e-04 - d_lr: 2.6572e-04 - val_g_loss: 0.6947 - val_d_loss: 0.6926 - val_wass_dist: 0.0306
# Epoch 76/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6924 - wass_dist: -0.0032 - g_lr: 3.1127e-04 - d_lr: 2.6427e-04 - val_g_loss: 0.6889 - val_d_loss: 0.6927 - val_wass_dist: 0.0159
# Epoch 77/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6924 - wass_dist: -0.0041 - g_lr: 3.0857e-04 - d_lr: 2.6282e-04 - val_g_loss: 0.6904 - val_d_loss: 0.6928 - val_wass_dist: 0.0044
# Epoch 78/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6993 - d_loss: 0.6924 - wass_dist: -0.0039 - g_lr: 3.0590e-04 - d_lr: 2.6138e-04 - val_g_loss: 0.6886 - val_d_loss: 0.6928 - val_wass_dist: -0.0193
# Epoch 79/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6924 - wass_dist: -0.0039 - g_lr: 3.0325e-04 - d_lr: 2.5995e-04 - val_g_loss: 0.6852 - val_d_loss: 0.6927 - val_wass_dist: 0.0025
# Epoch 80/500
# 453/453 [==============================] - 12s 25ms/step - g_loss: 0.6992 - d_loss: 0.6924 - wass_dist: -0.0045 - g_lr: 3.0063e-04 - d_lr: 2.5853e-04 - val_g_loss: 0.6929 - val_d_loss: 0.6925 - val_wass_dist: -0.0058
# Epoch 81/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6924 - wass_dist: -0.0041 - g_lr: 2.9803e-04 - d_lr: 2.5711e-04 - val_g_loss: 0.6911 - val_d_loss: 0.6924 - val_wass_dist: -0.0240
# Epoch 82/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6924 - wass_dist: -0.0052 - g_lr: 2.9545e-04 - d_lr: 2.5571e-04 - val_g_loss: 0.6849 - val_d_loss: 0.6925 - val_wass_dist: -0.0126
# Epoch 83/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6924 - wass_dist: -0.0039 - g_lr: 2.9289e-04 - d_lr: 2.5431e-04 - val_g_loss: 0.6891 - val_d_loss: 0.6928 - val_wass_dist: -0.0053
# Epoch 84/500
# 453/453 [==============================] - 12s 24ms/step - g_loss: 0.6992 - d_loss: 0.6924 - wass_dist: -0.0042 - g_lr: 2.9036e-04 - d_lr: 2.5291e-04 - val_g_loss: 0.6880 - val_d_loss: 0.6929 - val_wass_dist: -0.0029
# Epoch 85/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6924 - wass_dist: -0.0053 - g_lr: 2.8784e-04 - d_lr: 2.5153e-04 - val_g_loss: 0.6893 - val_d_loss: 0.6928 - val_wass_dist: 0.0012
# Epoch 86/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6991 - d_loss: 0.6924 - wass_dist: -0.0048 - g_lr: 2.8535e-04 - d_lr: 2.5015e-04 - val_g_loss: 0.6864 - val_d_loss: 0.6928 - val_wass_dist: -0.0247
# Epoch 87/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6924 - wass_dist: -0.0049 - g_lr: 2.8288e-04 - d_lr: 2.4878e-04 - val_g_loss: 0.6844 - val_d_loss: 0.6927 - val_wass_dist: -0.0111
# Epoch 88/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6924 - wass_dist: -0.0041 - g_lr: 2.8043e-04 - d_lr: 2.4742e-04 - val_g_loss: 0.6840 - val_d_loss: 0.6925 - val_wass_dist: -0.0109
# Epoch 89/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6990 - d_loss: 0.6923 - wass_dist: -0.0063 - g_lr: 2.7801e-04 - d_lr: 2.4607e-04 - val_g_loss: 0.6856 - val_d_loss: 0.6923 - val_wass_dist: -0.0034
# Epoch 90/500
# 453/453 [==============================] - 12s 24ms/step - g_loss: 0.6991 - d_loss: 0.6924 - wass_dist: -0.0048 - g_lr: 2.7560e-04 - d_lr: 2.4472e-04 - val_g_loss: 0.6840 - val_d_loss: 0.6924 - val_wass_dist: -0.0171
# Epoch 91/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0055 - g_lr: 2.7322e-04 - d_lr: 2.4338e-04 - val_g_loss: 0.6870 - val_d_loss: 0.6926 - val_wass_dist: -0.0017
# Epoch 92/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0068 - g_lr: 2.7085e-04 - d_lr: 2.4205e-04 - val_g_loss: 0.6892 - val_d_loss: 0.6928 - val_wass_dist: -0.0049
# Epoch 93/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0054 - g_lr: 2.6851e-04 - d_lr: 2.4072e-04 - val_g_loss: 0.6904 - val_d_loss: 0.6925 - val_wass_dist: -0.0207
# Epoch 94/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0051 - g_lr: 2.6618e-04 - d_lr: 2.3940e-04 - val_g_loss: 0.6920 - val_d_loss: 0.6924 - val_wass_dist: -0.0085
# Epoch 95/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0051 - g_lr: 2.6388e-04 - d_lr: 2.3809e-04 - val_g_loss: 0.6884 - val_d_loss: 0.6922 - val_wass_dist: -0.0053
# Epoch 96/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0053 - g_lr: 2.6160e-04 - d_lr: 2.3679e-04 - val_g_loss: 0.6903 - val_d_loss: 0.6922 - val_wass_dist: -0.0120
# Epoch 97/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6991 - d_loss: 0.6923 - wass_dist: -0.0056 - g_lr: 2.5933e-04 - d_lr: 2.3549e-04 - val_g_loss: 0.6821 - val_d_loss: 0.6924 - val_wass_dist: -0.0014
# Epoch 98/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0060 - g_lr: 2.5709e-04 - d_lr: 2.3420e-04 - val_g_loss: 0.6817 - val_d_loss: 0.6924 - val_wass_dist: 0.0012
# Epoch 99/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6922 - wass_dist: -0.0051 - g_lr: 2.5486e-04 - d_lr: 2.3292e-04 - val_g_loss: 0.6804 - val_d_loss: 0.6923 - val_wass_dist: -0.0060
# Epoch 100/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0040 - g_lr: 2.5266e-04 - d_lr: 2.3165e-04 - val_g_loss: 0.6838 - val_d_loss: 0.6930 - val_wass_dist: -0.0109
# Epoch 101/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0045 - g_lr: 2.5047e-04 - d_lr: 2.3038e-04 - val_g_loss: 0.6851 - val_d_loss: 0.6921 - val_wass_dist: 0.0058
# Epoch 102/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0060 - g_lr: 2.4830e-04 - d_lr: 2.2912e-04 - val_g_loss: 0.6829 - val_d_loss: 0.6925 - val_wass_dist: -0.0071
# Epoch 103/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6922 - wass_dist: -0.0059 - g_lr: 2.4615e-04 - d_lr: 2.2786e-04 - val_g_loss: 0.6817 - val_d_loss: 0.6927 - val_wass_dist: -0.0011
# Epoch 104/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0053 - g_lr: 2.4402e-04 - d_lr: 2.2662e-04 - val_g_loss: 0.6844 - val_d_loss: 0.6927 - val_wass_dist: -0.0011
# Epoch 105/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6922 - wass_dist: -0.0050 - g_lr: 2.4191e-04 - d_lr: 2.2537e-04 - val_g_loss: 0.6901 - val_d_loss: 0.6927 - val_wass_dist: -9.3078e-04
# Epoch 106/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6991 - d_loss: 0.6921 - wass_dist: -0.0056 - g_lr: 2.3982e-04 - d_lr: 2.2414e-04 - val_g_loss: 0.6835 - val_d_loss: 0.6923 - val_wass_dist: -0.0054
# Epoch 107/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6991 - d_loss: 0.6922 - wass_dist: -0.0056 - g_lr: 2.3774e-04 - d_lr: 2.2291e-04 - val_g_loss: 0.6854 - val_d_loss: 0.6920 - val_wass_dist: -0.0189
# Epoch 108/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0061 - g_lr: 2.3568e-04 - d_lr: 2.2169e-04 - val_g_loss: 0.6876 - val_d_loss: 0.6925 - val_wass_dist: 6.6896e-04
# Epoch 109/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0057 - g_lr: 2.3365e-04 - d_lr: 2.2048e-04 - val_g_loss: 0.6826 - val_d_loss: 0.6924 - val_wass_dist: -0.0085
# Epoch 110/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0063 - g_lr: 2.3162e-04 - d_lr: 2.1927e-04 - val_g_loss: 0.6828 - val_d_loss: 0.6922 - val_wass_dist: -9.5415e-04
# Epoch 111/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0053 - g_lr: 2.2962e-04 - d_lr: 2.1807e-04 - val_g_loss: 0.6803 - val_d_loss: 0.6931 - val_wass_dist: 0.0049
# Epoch 112/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0052 - g_lr: 2.2763e-04 - d_lr: 2.1688e-04 - val_g_loss: 0.6833 - val_d_loss: 0.6926 - val_wass_dist: -0.0116
# Epoch 113/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0059 - g_lr: 2.2566e-04 - d_lr: 2.1569e-04 - val_g_loss: 0.6816 - val_d_loss: 0.6923 - val_wass_dist: -0.0050
# Epoch 114/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0070 - g_lr: 2.2371e-04 - d_lr: 2.1451e-04 - val_g_loss: 0.6849 - val_d_loss: 0.6925 - val_wass_dist: -0.0124
# Epoch 115/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6920 - wass_dist: -0.0051 - g_lr: 2.2177e-04 - d_lr: 2.1334e-04 - val_g_loss: 0.6811 - val_d_loss: 0.6927 - val_wass_dist: -0.0244
# Epoch 116/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6920 - wass_dist: -0.0066 - g_lr: 2.1985e-04 - d_lr: 2.1217e-04 - val_g_loss: 0.6816 - val_d_loss: 0.6922 - val_wass_dist: -0.0282
# Epoch 117/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6920 - wass_dist: -0.0049 - g_lr: 2.1795e-04 - d_lr: 2.1101e-04 - val_g_loss: 0.6842 - val_d_loss: 0.6922 - val_wass_dist: -0.0187
# Epoch 118/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6993 - d_loss: 0.6920 - wass_dist: -0.0066 - g_lr: 2.1606e-04 - d_lr: 2.0985e-04 - val_g_loss: 0.6822 - val_d_loss: 0.6925 - val_wass_dist: -0.0287
# Epoch 119/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6993 - d_loss: 0.6920 - wass_dist: -0.0068 - g_lr: 2.1419e-04 - d_lr: 2.0870e-04 - val_g_loss: 0.6850 - val_d_loss: 0.6922 - val_wass_dist: -0.0257
# Epoch 120/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6920 - wass_dist: -0.0069 - g_lr: 2.1234e-04 - d_lr: 2.0756e-04 - val_g_loss: 0.6770 - val_d_loss: 0.6928 - val_wass_dist: -0.0169
# Epoch 121/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6920 - wass_dist: -0.0062 - g_lr: 2.1050e-04 - d_lr: 2.0642e-04 - val_g_loss: 0.6785 - val_d_loss: 0.6924 - val_wass_dist: -0.0124
# Epoch 122/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0084 - g_lr: 2.0868e-04 - d_lr: 2.0529e-04 - val_g_loss: 0.6841 - val_d_loss: 0.6922 - val_wass_dist: -0.0203
# Epoch 123/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6992 - d_loss: 0.6920 - wass_dist: -0.0062 - g_lr: 2.0687e-04 - d_lr: 2.0417e-04 - val_g_loss: 0.6790 - val_d_loss: 0.6923 - val_wass_dist: -0.0401
# Epoch 124/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0059 - g_lr: 2.0508e-04 - d_lr: 2.0305e-04 - val_g_loss: 0.6866 - val_d_loss: 0.6924 - val_wass_dist: -0.0131
# Epoch 125/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0061 - g_lr: 2.0331e-04 - d_lr: 2.0194e-04 - val_g_loss: 0.6807 - val_d_loss: 0.6926 - val_wass_dist: -0.0104
# Epoch 126/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0071 - g_lr: 2.0155e-04 - d_lr: 2.0083e-04 - val_g_loss: 0.6834 - val_d_loss: 0.6917 - val_wass_dist: -0.0150
# Epoch 127/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0072 - g_lr: 1.9981e-04 - d_lr: 1.9973e-04 - val_g_loss: 0.6800 - val_d_loss: 0.6920 - val_wass_dist: 0.0084
# Epoch 128/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0082 - g_lr: 1.9808e-04 - d_lr: 1.9864e-04 - val_g_loss: 0.6859 - val_d_loss: 0.6916 - val_wass_dist: -0.0122
# Epoch 129/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0067 - g_lr: 1.9636e-04 - d_lr: 1.9755e-04 - val_g_loss: 0.6823 - val_d_loss: 0.6922 - val_wass_dist: -0.0077
# Epoch 130/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6994 - d_loss: 0.6919 - wass_dist: -0.0087 - g_lr: 1.9466e-04 - d_lr: 1.9647e-04 - val_g_loss: 0.6837 - val_d_loss: 0.6923 - val_wass_dist: -0.0155
# Epoch 131/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6992 - d_loss: 0.6919 - wass_dist: -0.0074 - g_lr: 1.9298e-04 - d_lr: 1.9540e-04 - val_g_loss: 0.6841 - val_d_loss: 0.6919 - val_wass_dist: 0.0052
# Epoch 132/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6919 - wass_dist: -0.0091 - g_lr: 1.9131e-04 - d_lr: 1.9433e-04 - val_g_loss: 0.6759 - val_d_loss: 0.6922 - val_wass_dist: -0.0147
# Epoch 133/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6993 - d_loss: 0.6918 - wass_dist: -0.0080 - g_lr: 1.8965e-04 - d_lr: 1.9326e-04 - val_g_loss: 0.6788 - val_d_loss: 0.6923 - val_wass_dist: 0.0042
# Epoch 134/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6993 - d_loss: 0.6918 - wass_dist: -0.0073 - g_lr: 1.8801e-04 - d_lr: 1.9220e-04 - val_g_loss: 0.6840 - val_d_loss: 0.6919 - val_wass_dist: -0.0158
# Epoch 135/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6993 - d_loss: 0.6918 - wass_dist: -0.0076 - g_lr: 1.8638e-04 - d_lr: 1.9115e-04 - val_g_loss: 0.6743 - val_d_loss: 0.6922 - val_wass_dist: 0.0025
# Epoch 136/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6918 - wass_dist: -0.0077 - g_lr: 1.8477e-04 - d_lr: 1.9011e-04 - val_g_loss: 0.6802 - val_d_loss: 0.6916 - val_wass_dist: 0.0153
# Epoch 137/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6994 - d_loss: 0.6918 - wass_dist: -0.0081 - g_lr: 1.8317e-04 - d_lr: 1.8906e-04 - val_g_loss: 0.6791 - val_d_loss: 0.6918 - val_wass_dist: -0.0177
# Epoch 138/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6995 - d_loss: 0.6918 - wass_dist: -0.0067 - g_lr: 1.8159e-04 - d_lr: 1.8803e-04 - val_g_loss: 0.6703 - val_d_loss: 0.6928 - val_wass_dist: -0.0037
# Epoch 139/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6994 - d_loss: 0.6918 - wass_dist: -0.0074 - g_lr: 1.8001e-04 - d_lr: 1.8700e-04 - val_g_loss: 0.6749 - val_d_loss: 0.6926 - val_wass_dist: 0.0251
# Epoch 140/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6995 - d_loss: 0.6918 - wass_dist: -0.0082 - g_lr: 1.7846e-04 - d_lr: 1.8598e-04 - val_g_loss: 0.6805 - val_d_loss: 0.6927 - val_wass_dist: -0.0362
# Epoch 141/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6994 - d_loss: 0.6917 - wass_dist: -0.0083 - g_lr: 1.7691e-04 - d_lr: 1.8496e-04 - val_g_loss: 0.6868 - val_d_loss: 0.6921 - val_wass_dist: 0.0028
# Epoch 142/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6995 - d_loss: 0.6917 - wass_dist: -0.0085 - g_lr: 1.7538e-04 - d_lr: 1.8395e-04 - val_g_loss: 0.6847 - val_d_loss: 0.6922 - val_wass_dist: -0.0183
# Epoch 143/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6995 - d_loss: 0.6917 - wass_dist: -0.0066 - g_lr: 1.7386e-04 - d_lr: 1.8294e-04 - val_g_loss: 0.6834 - val_d_loss: 0.6926 - val_wass_dist: 0.0069
# Epoch 144/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6994 - d_loss: 0.6917 - wass_dist: -0.0095 - g_lr: 1.7236e-04 - d_lr: 1.8194e-04 - val_g_loss: 0.6775 - val_d_loss: 0.6921 - val_wass_dist: -0.0313
# Epoch 145/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6995 - d_loss: 0.6917 - wass_dist: -0.0097 - g_lr: 1.7087e-04 - d_lr: 1.8094e-04 - val_g_loss: 0.6896 - val_d_loss: 0.6916 - val_wass_dist: -0.0526
# Epoch 146/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6995 - d_loss: 0.6916 - wass_dist: -0.0081 - g_lr: 1.6939e-04 - d_lr: 1.7995e-04 - val_g_loss: 0.6883 - val_d_loss: 0.6919 - val_wass_dist: -0.0237
# Epoch 147/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6995 - d_loss: 0.6917 - wass_dist: -0.0098 - g_lr: 1.6792e-04 - d_lr: 1.7897e-04 - val_g_loss: 0.6786 - val_d_loss: 0.6917 - val_wass_dist: -0.0020
# Epoch 148/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6996 - d_loss: 0.6916 - wass_dist: -0.0096 - g_lr: 1.6647e-04 - d_lr: 1.7799e-04 - val_g_loss: 0.6792 - val_d_loss: 0.6922 - val_wass_dist: -0.0100
# Epoch 149/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6916 - wass_dist: -0.0090 - g_lr: 1.6503e-04 - d_lr: 1.7701e-04 - val_g_loss: 0.6820 - val_d_loss: 0.6922 - val_wass_dist: -0.0251
# Epoch 150/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6996 - d_loss: 0.6916 - wass_dist: -0.0079 - g_lr: 1.6360e-04 - d_lr: 1.7604e-04 - val_g_loss: 0.6746 - val_d_loss: 0.6927 - val_wass_dist: -0.0457
# Epoch 151/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6997 - d_loss: 0.6916 - wass_dist: -0.0102 - g_lr: 1.6218e-04 - d_lr: 1.7508e-04 - val_g_loss: 0.6811 - val_d_loss: 0.6926 - val_wass_dist: -0.0045
# Epoch 152/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6996 - d_loss: 0.6916 - wass_dist: -0.0107 - g_lr: 1.6078e-04 - d_lr: 1.7412e-04 - val_g_loss: 0.6847 - val_d_loss: 0.6921 - val_wass_dist: -0.0139
# Epoch 153/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6997 - d_loss: 0.6916 - wass_dist: -0.0105 - g_lr: 1.5939e-04 - d_lr: 1.7317e-04 - val_g_loss: 0.6764 - val_d_loss: 0.6922 - val_wass_dist: -0.0182
# Epoch 154/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6997 - d_loss: 0.6916 - wass_dist: -0.0110 - g_lr: 1.5801e-04 - d_lr: 1.7222e-04 - val_g_loss: 0.6876 - val_d_loss: 0.6923 - val_wass_dist: -0.1162
# Epoch 155/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6997 - d_loss: 0.6915 - wass_dist: -0.0088 - g_lr: 1.5664e-04 - d_lr: 1.7128e-04 - val_g_loss: 0.6698 - val_d_loss: 0.6925 - val_wass_dist: -0.0165
# Epoch 156/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6915 - wass_dist: -0.0086 - g_lr: 1.5529e-04 - d_lr: 1.7034e-04 - val_g_loss: 0.6830 - val_d_loss: 0.6922 - val_wass_dist: 0.0015
# Epoch 157/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6915 - wass_dist: -0.0098 - g_lr: 1.5394e-04 - d_lr: 1.6941e-04 - val_g_loss: 0.6837 - val_d_loss: 0.6919 - val_wass_dist: 4.4460e-04
# Epoch 158/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6915 - wass_dist: -0.0088 - g_lr: 1.5261e-04 - d_lr: 1.6848e-04 - val_g_loss: 0.6854 - val_d_loss: 0.6926 - val_wass_dist: -0.0118
# Epoch 159/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6998 - d_loss: 0.6915 - wass_dist: -0.0103 - g_lr: 1.5129e-04 - d_lr: 1.6756e-04 - val_g_loss: 0.6721 - val_d_loss: 0.6923 - val_wass_dist: -0.0061
# Epoch 160/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6914 - wass_dist: -0.0094 - g_lr: 1.4998e-04 - d_lr: 1.6664e-04 - val_g_loss: 0.6829 - val_d_loss: 0.6916 - val_wass_dist: -0.0489
# Epoch 161/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6998 - d_loss: 0.6914 - wass_dist: -0.0105 - g_lr: 1.4868e-04 - d_lr: 1.6573e-04 - val_g_loss: 0.6884 - val_d_loss: 0.6921 - val_wass_dist: -0.0084
# Epoch 162/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6914 - wass_dist: -0.0107 - g_lr: 1.4739e-04 - d_lr: 1.6482e-04 - val_g_loss: 0.6804 - val_d_loss: 0.6917 - val_wass_dist: 0.0010
# Epoch 163/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6999 - d_loss: 0.6914 - wass_dist: -0.0103 - g_lr: 1.4612e-04 - d_lr: 1.6392e-04 - val_g_loss: 0.6880 - val_d_loss: 0.6918 - val_wass_dist: -0.0762
# Epoch 164/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6914 - wass_dist: -0.0084 - g_lr: 1.4485e-04 - d_lr: 1.6302e-04 - val_g_loss: 0.6746 - val_d_loss: 0.6924 - val_wass_dist: -0.0237
# Epoch 165/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6999 - d_loss: 0.6914 - wass_dist: -0.0112 - g_lr: 1.4360e-04 - d_lr: 1.6213e-04 - val_g_loss: 0.6857 - val_d_loss: 0.6918 - val_wass_dist: 0.0052
# Epoch 166/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6998 - d_loss: 0.6914 - wass_dist: -0.0108 - g_lr: 1.4236e-04 - d_lr: 1.6124e-04 - val_g_loss: 0.6914 - val_d_loss: 0.6920 - val_wass_dist: -0.0691
# Epoch 167/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6999 - d_loss: 0.6914 - wass_dist: -0.0094 - g_lr: 1.4113e-04 - d_lr: 1.6036e-04 - val_g_loss: 0.6844 - val_d_loss: 0.6925 - val_wass_dist: -0.0111
# Epoch 168/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.6999 - d_loss: 0.6914 - wass_dist: -0.0115 - g_lr: 1.3990e-04 - d_lr: 1.5948e-04 - val_g_loss: 0.6766 - val_d_loss: 0.6923 - val_wass_dist: -0.0156
# Epoch 169/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6999 - d_loss: 0.6913 - wass_dist: -0.0098 - g_lr: 1.3869e-04 - d_lr: 1.5860e-04 - val_g_loss: 0.6836 - val_d_loss: 0.6921 - val_wass_dist: -0.0341
# Epoch 170/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7000 - d_loss: 0.6913 - wass_dist: -0.0103 - g_lr: 1.3749e-04 - d_lr: 1.5774e-04 - val_g_loss: 0.6728 - val_d_loss: 0.6918 - val_wass_dist: -0.0310
# Epoch 171/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6999 - d_loss: 0.6913 - wass_dist: -0.0098 - g_lr: 1.3630e-04 - d_lr: 1.5687e-04 - val_g_loss: 0.6805 - val_d_loss: 0.6921 - val_wass_dist: -0.0150
# Epoch 172/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7000 - d_loss: 0.6913 - wass_dist: -0.0108 - g_lr: 1.3512e-04 - d_lr: 1.5601e-04 - val_g_loss: 0.6875 - val_d_loss: 0.6917 - val_wass_dist: -0.0079
# Epoch 173/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.6999 - d_loss: 0.6913 - wass_dist: -0.0117 - g_lr: 1.3395e-04 - d_lr: 1.5516e-04 - val_g_loss: 0.6738 - val_d_loss: 0.6924 - val_wass_dist: -0.0242
# Epoch 174/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7000 - d_loss: 0.6913 - wass_dist: -0.0096 - g_lr: 1.3280e-04 - d_lr: 1.5431e-04 - val_g_loss: 0.6755 - val_d_loss: 0.6918 - val_wass_dist: -0.0026
# Epoch 175/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7000 - d_loss: 0.6913 - wass_dist: -0.0101 - g_lr: 1.3165e-04 - d_lr: 1.5347e-04 - val_g_loss: 0.6817 - val_d_loss: 0.6918 - val_wass_dist: -0.0227
# Epoch 176/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7001 - d_loss: 0.6913 - wass_dist: -0.0124 - g_lr: 1.3051e-04 - d_lr: 1.5263e-04 - val_g_loss: 0.6793 - val_d_loss: 0.6921 - val_wass_dist: -0.0274
# Epoch 177/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7000 - d_loss: 0.6912 - wass_dist: -0.0120 - g_lr: 1.2938e-04 - d_lr: 1.5179e-04 - val_g_loss: 0.6849 - val_d_loss: 0.6919 - val_wass_dist: 0.0033
# Epoch 178/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7001 - d_loss: 0.6912 - wass_dist: -0.0105 - g_lr: 1.2826e-04 - d_lr: 1.5096e-04 - val_g_loss: 0.6838 - val_d_loss: 0.6920 - val_wass_dist: -0.0284
# Epoch 179/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7001 - d_loss: 0.6912 - wass_dist: -0.0110 - g_lr: 1.2715e-04 - d_lr: 1.5013e-04 - val_g_loss: 0.6898 - val_d_loss: 0.6922 - val_wass_dist: 0.0094
# Epoch 180/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7001 - d_loss: 0.6912 - wass_dist: -0.0119 - g_lr: 1.2605e-04 - d_lr: 1.4931e-04 - val_g_loss: 0.6891 - val_d_loss: 0.6921 - val_wass_dist: -0.0156
# Epoch 181/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7001 - d_loss: 0.6912 - wass_dist: -0.0126 - g_lr: 1.2496e-04 - d_lr: 1.4849e-04 - val_g_loss: 0.6787 - val_d_loss: 0.6924 - val_wass_dist: -0.0103
# Epoch 182/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7001 - d_loss: 0.6911 - wass_dist: -0.0099 - g_lr: 1.2387e-04 - d_lr: 1.4768e-04 - val_g_loss: 0.6815 - val_d_loss: 0.6926 - val_wass_dist: -0.0153
# Epoch 183/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7001 - d_loss: 0.6911 - wass_dist: -0.0107 - g_lr: 1.2280e-04 - d_lr: 1.4687e-04 - val_g_loss: 0.6844 - val_d_loss: 0.6917 - val_wass_dist: -0.0134
# Epoch 184/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6911 - wass_dist: -0.0110 - g_lr: 1.2174e-04 - d_lr: 1.4607e-04 - val_g_loss: 0.7086 - val_d_loss: 0.6921 - val_wass_dist: -0.0066
# Epoch 185/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7002 - d_loss: 0.6911 - wass_dist: -0.0115 - g_lr: 1.2069e-04 - d_lr: 1.4527e-04 - val_g_loss: 0.6890 - val_d_loss: 0.6920 - val_wass_dist: -0.0076
# Epoch 186/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6911 - wass_dist: -0.0112 - g_lr: 1.1964e-04 - d_lr: 1.4447e-04 - val_g_loss: 0.6867 - val_d_loss: 0.6923 - val_wass_dist: -0.0232
# Epoch 187/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6911 - wass_dist: -0.0117 - g_lr: 1.1861e-04 - d_lr: 1.4368e-04 - val_g_loss: 0.6649 - val_d_loss: 0.6931 - val_wass_dist: -0.0017
# Epoch 188/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7003 - d_loss: 0.6910 - wass_dist: -0.0120 - g_lr: 1.1758e-04 - d_lr: 1.4289e-04 - val_g_loss: 0.6726 - val_d_loss: 0.6914 - val_wass_dist: -0.0166
# Epoch 189/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6910 - wass_dist: -0.0121 - g_lr: 1.1656e-04 - d_lr: 1.4211e-04 - val_g_loss: 0.6768 - val_d_loss: 0.6914 - val_wass_dist: -0.0210
# Epoch 190/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6910 - wass_dist: -0.0121 - g_lr: 1.1555e-04 - d_lr: 1.4133e-04 - val_g_loss: 0.6866 - val_d_loss: 0.6915 - val_wass_dist: 0.0101
# Epoch 191/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7003 - d_loss: 0.6910 - wass_dist: -0.0127 - g_lr: 1.1455e-04 - d_lr: 1.4056e-04 - val_g_loss: 0.6793 - val_d_loss: 0.6920 - val_wass_dist: -0.0121
# Epoch 192/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6910 - wass_dist: -0.0086 - g_lr: 1.1356e-04 - d_lr: 1.3979e-04 - val_g_loss: 0.6776 - val_d_loss: 0.6918 - val_wass_dist: -0.0125
# Epoch 193/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6910 - wass_dist: -0.0116 - g_lr: 1.1258e-04 - d_lr: 1.3903e-04 - val_g_loss: 0.6803 - val_d_loss: 0.6918 - val_wass_dist: -0.0164
# Epoch 194/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7003 - d_loss: 0.6910 - wass_dist: -0.0103 - g_lr: 1.1160e-04 - d_lr: 1.3826e-04 - val_g_loss: 0.6810 - val_d_loss: 0.6922 - val_wass_dist: -0.0268
# Epoch 195/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6910 - wass_dist: -0.0126 - g_lr: 1.1064e-04 - d_lr: 1.3751e-04 - val_g_loss: 0.6957 - val_d_loss: 0.6916 - val_wass_dist: -0.0105
# Epoch 196/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7004 - d_loss: 0.6910 - wass_dist: -0.0106 - g_lr: 1.0968e-04 - d_lr: 1.3675e-04 - val_g_loss: 0.6847 - val_d_loss: 0.6924 - val_wass_dist: -0.0252
# Epoch 197/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6910 - wass_dist: -0.0126 - g_lr: 1.0873e-04 - d_lr: 1.3601e-04 - val_g_loss: 0.6971 - val_d_loss: 0.6918 - val_wass_dist: -0.0215
# Epoch 198/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7005 - d_loss: 0.6909 - wass_dist: -0.0117 - g_lr: 1.0779e-04 - d_lr: 1.3526e-04 - val_g_loss: 0.6797 - val_d_loss: 0.6919 - val_wass_dist: 3.7835e-04
# Epoch 199/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6909 - wass_dist: -0.0135 - g_lr: 1.0686e-04 - d_lr: 1.3452e-04 - val_g_loss: 0.6844 - val_d_loss: 0.6918 - val_wass_dist: -0.0529
# Epoch 200/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7004 - d_loss: 0.6909 - wass_dist: -0.0122 - g_lr: 1.0593e-04 - d_lr: 1.3378e-04 - val_g_loss: 0.7008 - val_d_loss: 0.6914 - val_wass_dist: -0.0153
# Epoch 201/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7005 - d_loss: 0.6909 - wass_dist: -0.0120 - g_lr: 1.0502e-04 - d_lr: 1.3305e-04 - val_g_loss: 0.6885 - val_d_loss: 0.6921 - val_wass_dist: 0.0137
# Epoch 202/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7005 - d_loss: 0.6909 - wass_dist: -0.0110 - g_lr: 1.0411e-04 - d_lr: 1.3232e-04 - val_g_loss: 0.6754 - val_d_loss: 0.6924 - val_wass_dist: -0.0187
# Epoch 203/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7005 - d_loss: 0.6909 - wass_dist: -0.0098 - g_lr: 1.0321e-04 - d_lr: 1.3160e-04 - val_g_loss: 0.6695 - val_d_loss: 0.6917 - val_wass_dist: -0.0155
# Epoch 204/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7006 - d_loss: 0.6909 - wass_dist: -0.0127 - g_lr: 1.0231e-04 - d_lr: 1.3088e-04 - val_g_loss: 0.6965 - val_d_loss: 0.6917 - val_wass_dist: -0.0272
# Epoch 205/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7006 - d_loss: 0.6908 - wass_dist: -0.0107 - g_lr: 1.0143e-04 - d_lr: 1.3016e-04 - val_g_loss: 0.6860 - val_d_loss: 0.6914 - val_wass_dist: 0.0038
# Epoch 206/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7006 - d_loss: 0.6908 - wass_dist: -0.0120 - g_lr: 1.0055e-04 - d_lr: 1.2945e-04 - val_g_loss: 0.6756 - val_d_loss: 0.6926 - val_wass_dist: -0.0160
# Epoch 207/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7007 - d_loss: 0.6908 - wass_dist: -0.0141 - g_lr: 9.9680e-05 - d_lr: 1.2874e-04 - val_g_loss: 0.6670 - val_d_loss: 0.6917 - val_wass_dist: -0.0045
# ...
# Epoch 432/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7039 - d_loss: 0.6885 - wass_dist: -0.0263 - g_lr: 1.4100e-05 - d_lr: 3.7434e-05 - val_g_loss: 0.6970 - val_d_loss: 0.6906 - val_wass_dist: 0.0074
# Epoch 433/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7041 - d_loss: 0.6886 - wass_dist: -0.0262 - g_lr: 1.3978e-05 - d_lr: 3.7229e-05 - val_g_loss: 0.6934 - val_d_loss: 0.6904 - val_wass_dist: 0.0463
# Epoch 434/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7040 - d_loss: 0.6885 - wass_dist: -0.0256 - g_lr: 1.3857e-05 - d_lr: 3.7025e-05 - val_g_loss: 0.6916 - val_d_loss: 0.6905 - val_wass_dist: -0.0473
# Epoch 435/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7040 - d_loss: 0.6886 - wass_dist: -0.0240 - g_lr: 1.3737e-05 - d_lr: 3.6823e-05 - val_g_loss: 0.6984 - val_d_loss: 0.6905 - val_wass_dist: -0.0156
# Epoch 436/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7040 - d_loss: 0.6885 - wass_dist: -0.0260 - g_lr: 1.3619e-05 - d_lr: 3.6621e-05 - val_g_loss: 0.6980 - val_d_loss: 0.6899 - val_wass_dist: -0.0242
# Epoch 437/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7041 - d_loss: 0.6885 - wass_dist: -0.0254 - g_lr: 1.3501e-05 - d_lr: 3.6421e-05 - val_g_loss: 0.6935 - val_d_loss: 0.6901 - val_wass_dist: 0.0079
# Epoch 438/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7041 - d_loss: 0.6885 - wass_dist: -0.0247 - g_lr: 1.3384e-05 - d_lr: 3.6221e-05 - val_g_loss: 0.6924 - val_d_loss: 0.6896 - val_wass_dist: -0.0440
# Epoch 439/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7041 - d_loss: 0.6885 - wass_dist: -0.0272 - g_lr: 1.3268e-05 - d_lr: 3.6023e-05 - val_g_loss: 0.6898 - val_d_loss: 0.6903 - val_wass_dist: -0.0826
# Epoch 440/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7042 - d_loss: 0.6885 - wass_dist: -0.0278 - g_lr: 1.3153e-05 - d_lr: 3.5826e-05 - val_g_loss: 0.6942 - val_d_loss: 0.6904 - val_wass_dist: 0.0088
# Epoch 441/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7041 - d_loss: 0.6885 - wass_dist: -0.0290 - g_lr: 1.3039e-05 - d_lr: 3.5630e-05 - val_g_loss: 0.6961 - val_d_loss: 0.6898 - val_wass_dist: -0.0453
# Epoch 442/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7041 - d_loss: 0.6885 - wass_dist: -0.0269 - g_lr: 1.2927e-05 - d_lr: 3.5435e-05 - val_g_loss: 0.6939 - val_d_loss: 0.6899 - val_wass_dist: -0.0132
# Epoch 443/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7042 - d_loss: 0.6884 - wass_dist: -0.0275 - g_lr: 1.2815e-05 - d_lr: 3.5241e-05 - val_g_loss: 0.6934 - val_d_loss: 0.6902 - val_wass_dist: -0.0145
# Epoch 444/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7041 - d_loss: 0.6884 - wass_dist: -0.0285 - g_lr: 1.2704e-05 - d_lr: 3.5048e-05 - val_g_loss: 0.6910 - val_d_loss: 0.6910 - val_wass_dist: 0.0060
# Epoch 445/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7042 - d_loss: 0.6885 - wass_dist: -0.0272 - g_lr: 1.2594e-05 - d_lr: 3.4856e-05 - val_g_loss: 0.6947 - val_d_loss: 0.6899 - val_wass_dist: 0.0226
# Epoch 446/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7043 - d_loss: 0.6885 - wass_dist: -0.0271 - g_lr: 1.2485e-05 - d_lr: 3.4665e-05 - val_g_loss: 0.6946 - val_d_loss: 0.6891 - val_wass_dist: -0.0370
# Epoch 447/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7042 - d_loss: 0.6884 - wass_dist: -0.0268 - g_lr: 1.2377e-05 - d_lr: 3.4475e-05 - val_g_loss: 0.6946 - val_d_loss: 0.6908 - val_wass_dist: 0.0117
# Epoch 448/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7042 - d_loss: 0.6884 - wass_dist: -0.0266 - g_lr: 1.2270e-05 - d_lr: 3.4286e-05 - val_g_loss: 0.6944 - val_d_loss: 0.6899 - val_wass_dist: -0.0385
# Epoch 449/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7042 - d_loss: 0.6884 - wass_dist: -0.0279 - g_lr: 1.2163e-05 - d_lr: 3.4099e-05 - val_g_loss: 0.6932 - val_d_loss: 0.6903 - val_wass_dist: 0.0329
# Epoch 450/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7043 - d_loss: 0.6884 - wass_dist: -0.0260 - g_lr: 1.2058e-05 - d_lr: 3.3912e-05 - val_g_loss: 0.6955 - val_d_loss: 0.6892 - val_wass_dist: 0.0165
# Epoch 451/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7044 - d_loss: 0.6884 - wass_dist: -0.0279 - g_lr: 1.1954e-05 - d_lr: 3.3726e-05 - val_g_loss: 0.6965 - val_d_loss: 0.6906 - val_wass_dist: -0.0139
# Epoch 452/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7044 - d_loss: 0.6884 - wass_dist: -0.0254 - g_lr: 1.1850e-05 - d_lr: 3.3542e-05 - val_g_loss: 0.6943 - val_d_loss: 0.6895 - val_wass_dist: -0.0081
# Epoch 453/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7044 - d_loss: 0.6884 - wass_dist: -0.0274 - g_lr: 1.1748e-05 - d_lr: 3.3358e-05 - val_g_loss: 0.6960 - val_d_loss: 0.6896 - val_wass_dist: -0.0184
# Epoch 454/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7043 - d_loss: 0.6884 - wass_dist: -0.0248 - g_lr: 1.1646e-05 - d_lr: 3.3175e-05 - val_g_loss: 0.6943 - val_d_loss: 0.6900 - val_wass_dist: 0.0140
# Epoch 455/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7043 - d_loss: 0.6883 - wass_dist: -0.0249 - g_lr: 1.1545e-05 - d_lr: 3.2994e-05 - val_g_loss: 0.6938 - val_d_loss: 0.6892 - val_wass_dist: -0.0415
# Epoch 456/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7044 - d_loss: 0.6883 - wass_dist: -0.0279 - g_lr: 1.1445e-05 - d_lr: 3.2813e-05 - val_g_loss: 0.6949 - val_d_loss: 0.6896 - val_wass_dist: -0.0322
# Epoch 457/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7044 - d_loss: 0.6883 - wass_dist: -0.0265 - g_lr: 1.1346e-05 - d_lr: 3.2633e-05 - val_g_loss: 0.6980 - val_d_loss: 0.6898 - val_wass_dist: -0.0511
# Epoch 458/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7045 - d_loss: 0.6883 - wass_dist: -0.0260 - g_lr: 1.1248e-05 - d_lr: 3.2455e-05 - val_g_loss: 0.6969 - val_d_loss: 0.6902 - val_wass_dist: 0.0202
# Epoch 459/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7043 - d_loss: 0.6883 - wass_dist: -0.0288 - g_lr: 1.1151e-05 - d_lr: 3.2277e-05 - val_g_loss: 0.6940 - val_d_loss: 0.6899 - val_wass_dist: -0.0366
# Epoch 460/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7045 - d_loss: 0.6883 - wass_dist: -0.0270 - g_lr: 1.1054e-05 - d_lr: 3.2100e-05 - val_g_loss: 0.6980 - val_d_loss: 0.6894 - val_wass_dist: 0.0159
# Epoch 461/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.7045 - d_loss: 0.6883 - wass_dist: -0.0252 - g_lr: 1.0959e-05 - d_lr: 3.1925e-05 - val_g_loss: 0.6946 - val_d_loss: 0.6898 - val_wass_dist: -0.0397
# Epoch 462/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7045 - d_loss: 0.6883 - wass_dist: -0.0259 - g_lr: 1.0864e-05 - d_lr: 3.1750e-05 - val_g_loss: 0.6974 - val_d_loss: 0.6890 - val_wass_dist: 0.0106
# Epoch 463/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7044 - d_loss: 0.6883 - wass_dist: -0.0272 - g_lr: 1.0770e-05 - d_lr: 3.1576e-05 - val_g_loss: 0.6938 - val_d_loss: 0.6900 - val_wass_dist: -0.0231
# Epoch 464/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7045 - d_loss: 0.6883 - wass_dist: -0.0277 - g_lr: 1.0677e-05 - d_lr: 3.1403e-05 - val_g_loss: 0.6960 - val_d_loss: 0.6891 - val_wass_dist: 0.0046
# Epoch 465/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7045 - d_loss: 0.6882 - wass_dist: -0.0248 - g_lr: 1.0584e-05 - d_lr: 3.1231e-05 - val_g_loss: 0.6948 - val_d_loss: 0.6903 - val_wass_dist: -0.0063
# Epoch 466/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7044 - d_loss: 0.6883 - wass_dist: -0.0269 - g_lr: 1.0493e-05 - d_lr: 3.1060e-05 - val_g_loss: 0.6957 - val_d_loss: 0.6899 - val_wass_dist: -0.0310
# Epoch 467/500
# 453/453 [==============================] - 12s 24ms/step - g_loss: 0.7045 - d_loss: 0.6882 - wass_dist: -0.0287 - g_lr: 1.0402e-05 - d_lr: 3.0890e-05 - val_g_loss: 0.6939 - val_d_loss: 0.6904 - val_wass_dist: -0.0242
# Epoch 468/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7046 - d_loss: 0.6882 - wass_dist: -0.0262 - g_lr: 1.0312e-05 - d_lr: 3.0721e-05 - val_g_loss: 0.6950 - val_d_loss: 0.6895 - val_wass_dist: -0.0128
# Epoch 469/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0271 - g_lr: 1.0222e-05 - d_lr: 3.0553e-05 - val_g_loss: 0.6979 - val_d_loss: 0.6897 - val_wass_dist: -0.0305
# Epoch 470/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7046 - d_loss: 0.6882 - wass_dist: -0.0286 - g_lr: 1.0134e-05 - d_lr: 3.0386e-05 - val_g_loss: 0.6968 - val_d_loss: 0.6897 - val_wass_dist: -0.0200
# Epoch 471/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7046 - d_loss: 0.6882 - wass_dist: -0.0267 - g_lr: 1.0046e-05 - d_lr: 3.0219e-05 - val_g_loss: 0.6943 - val_d_loss: 0.6894 - val_wass_dist: -0.0044
# Epoch 472/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0306 - g_lr: 9.9594e-06 - d_lr: 3.0054e-05 - val_g_loss: 0.6959 - val_d_loss: 0.6889 - val_wass_dist: 0.0327
# Epoch 473/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0278 - g_lr: 9.8732e-06 - d_lr: 2.9889e-05 - val_g_loss: 0.6966 - val_d_loss: 0.6900 - val_wass_dist: -0.0154
# Epoch 474/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0262 - g_lr: 9.7877e-06 - d_lr: 2.9726e-05 - val_g_loss: 0.6958 - val_d_loss: 0.6889 - val_wass_dist: 0.0060
# Epoch 475/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0253 - g_lr: 9.7030e-06 - d_lr: 2.9563e-05 - val_g_loss: 0.6953 - val_d_loss: 0.6902 - val_wass_dist: -0.0199
# Epoch 476/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0282 - g_lr: 9.6190e-06 - d_lr: 2.9401e-05 - val_g_loss: 0.6971 - val_d_loss: 0.6897 - val_wass_dist: 0.0161
# Epoch 477/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6882 - wass_dist: -0.0237 - g_lr: 9.5358e-06 - d_lr: 2.9240e-05 - val_g_loss: 0.6972 - val_d_loss: 0.6902 - val_wass_dist: 0.0107
# Epoch 478/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6881 - wass_dist: -0.0267 - g_lr: 9.4533e-06 - d_lr: 2.9080e-05 - val_g_loss: 0.6955 - val_d_loss: 0.6891 - val_wass_dist: 0.0746
# Epoch 479/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7048 - d_loss: 0.6881 - wass_dist: -0.0264 - g_lr: 9.3715e-06 - d_lr: 2.8921e-05 - val_g_loss: 0.6948 - val_d_loss: 0.6899 - val_wass_dist: 0.0225
# Epoch 480/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7046 - d_loss: 0.6881 - wass_dist: -0.0282 - g_lr: 9.2903e-06 - d_lr: 2.8762e-05 - val_g_loss: 0.6987 - val_d_loss: 0.6897 - val_wass_dist: 0.0093
# Epoch 481/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7048 - d_loss: 0.6881 - wass_dist: -0.0285 - g_lr: 9.2099e-06 - d_lr: 2.8605e-05 - val_g_loss: 0.6960 - val_d_loss: 0.6896 - val_wass_dist: 0.0141
# Epoch 482/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7048 - d_loss: 0.6882 - wass_dist: -0.0300 - g_lr: 9.1302e-06 - d_lr: 2.8448e-05 - val_g_loss: 0.7005 - val_d_loss: 0.6903 - val_wass_dist: 0.0190
# Epoch 483/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7047 - d_loss: 0.6881 - wass_dist: -0.0294 - g_lr: 9.0512e-06 - d_lr: 2.8293e-05 - val_g_loss: 0.6972 - val_d_loss: 0.6903 - val_wass_dist: 0.0012
# Epoch 484/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7048 - d_loss: 0.6881 - wass_dist: -0.0284 - g_lr: 8.9729e-06 - d_lr: 2.8138e-05 - val_g_loss: 0.6966 - val_d_loss: 0.6897 - val_wass_dist: 0.0310
# Epoch 485/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7048 - d_loss: 0.6881 - wass_dist: -0.0300 - g_lr: 8.8952e-06 - d_lr: 2.7984e-05 - val_g_loss: 0.6966 - val_d_loss: 0.6895 - val_wass_dist: 0.0262
# Epoch 486/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7048 - d_loss: 0.6880 - wass_dist: -0.0276 - g_lr: 8.8182e-06 - d_lr: 2.7831e-05 - val_g_loss: 0.6984 - val_d_loss: 0.6898 - val_wass_dist: -0.0285
# Epoch 487/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.7049 - d_loss: 0.6881 - wass_dist: -0.0276 - g_lr: 8.7419e-06 - d_lr: 2.7678e-05 - val_g_loss: 0.6958 - val_d_loss: 0.6898 - val_wass_dist: -7.1240e-04
# Epoch 488/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7048 - d_loss: 0.6881 - wass_dist: -0.0289 - g_lr: 8.6663e-06 - d_lr: 2.7527e-05 - val_g_loss: 0.6968 - val_d_loss: 0.6906 - val_wass_dist: -0.0227
# Epoch 489/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7050 - d_loss: 0.6881 - wass_dist: -0.0281 - g_lr: 8.5913e-06 - d_lr: 2.7376e-05 - val_g_loss: 0.6961 - val_d_loss: 0.6894 - val_wass_dist: -0.0338
# Epoch 490/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7049 - d_loss: 0.6881 - wass_dist: -0.0281 - g_lr: 8.5169e-06 - d_lr: 2.7226e-05 - val_g_loss: 0.6957 - val_d_loss: 0.6903 - val_wass_dist: -0.0649
# Epoch 491/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7048 - d_loss: 0.6880 - wass_dist: -0.0276 - g_lr: 8.4432e-06 - d_lr: 2.7077e-05 - val_g_loss: 0.6996 - val_d_loss: 0.6895 - val_wass_dist: -0.0522
# Epoch 492/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7049 - d_loss: 0.6880 - wass_dist: -0.0282 - g_lr: 8.3701e-06 - d_lr: 2.6929e-05 - val_g_loss: 0.6962 - val_d_loss: 0.6899 - val_wass_dist: -0.0220
# Epoch 493/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7049 - d_loss: 0.6881 - wass_dist: -0.0289 - g_lr: 8.2977e-06 - d_lr: 2.6781e-05 - val_g_loss: 0.6975 - val_d_loss: 0.6904 - val_wass_dist: -0.0335
# Epoch 494/500
# 453/453 [==============================] - 11s 24ms/step - g_loss: 0.7049 - d_loss: 0.6880 - wass_dist: -0.0265 - g_lr: 8.2259e-06 - d_lr: 2.6635e-05 - val_g_loss: 0.6952 - val_d_loss: 0.6893 - val_wass_dist: -0.0110
# Epoch 495/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7049 - d_loss: 0.6880 - wass_dist: -0.0287 - g_lr: 8.1547e-06 - d_lr: 2.6489e-05 - val_g_loss: 0.6978 - val_d_loss: 0.6902 - val_wass_dist: -0.0270
# Epoch 496/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7050 - d_loss: 0.6880 - wass_dist: -0.0278 - g_lr: 8.0841e-06 - d_lr: 2.6344e-05 - val_g_loss: 0.6969 - val_d_loss: 0.6904 - val_wass_dist: 0.0116
# Epoch 497/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7049 - d_loss: 0.6879 - wass_dist: -0.0273 - g_lr: 8.0141e-06 - d_lr: 2.6200e-05 - val_g_loss: 0.6978 - val_d_loss: 0.6891 - val_wass_dist: -0.0139
# Epoch 498/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7050 - d_loss: 0.6880 - wass_dist: -0.0255 - g_lr: 7.9448e-06 - d_lr: 2.6056e-05 - val_g_loss: 0.6950 - val_d_loss: 0.6884 - val_wass_dist: -0.0037
# Epoch 499/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7050 - d_loss: 0.6880 - wass_dist: -0.0310 - g_lr: 7.8760e-06 - d_lr: 2.5914e-05 - val_g_loss: 0.6972 - val_d_loss: 0.6889 - val_wass_dist: -0.0645
# Epoch 500/500
# 453/453 [==============================] - 11s 23ms/step - g_loss: 0.7051 - d_loss: 0.6880 - wass_dist: -0.0263 - g_lr: 7.8079e-06 - d_lr: 2.5772e-05 - val_g_loss: 0.6985 - val_d_loss: 0.6897 - val_wass_dist: 0.0298

# %%
plt.figure(figsize=(16, 5), dpi=100)

start_epoch = 3

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#3288bd", label="generator")
plt.plot(train.history["d_loss"][start_epoch:], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_loss"][start_epoch:], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Learning rate scheduling", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Learning rate", fontsize=12)
plt.plot(train.history["g_lr"], color="#3288bd", label="generator")
plt.plot(train.history["d_lr"], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_lr"], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.show()

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Generator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_g_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Discriminator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["d_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_d_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.show()

# %%
plt.figure(figsize=(24, 5), dpi=100)

# plt.subplot(1, 3, 1)
# plt.title("Metric curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Accuracy", fontsize=12)
# plt.plot(train.history["accuracy"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_accuracy"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 3, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Wasserstein distance", fontsize=12)
plt.plot(train.history["wass_dist"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_wass_dist"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="upper left", fontsize=10)
# plt.yscale("log")

# plt.subplot(1, 3, 3)
# plt.title("Referee learning curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Binary cross-entropy", fontsize=12)
# plt.plot(train.history["r_loss"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_r_loss"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="upper right", fontsize=10)

plt.show()

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-GlobalPID-im-muon-train.csv")

# %% [markdown]
# ## A first, rough validation
#
# TBA

# %%
reader_test = FeatherReader(environ.get("GLOBALPID_IM_MUON_TEST_DATA", f"{DATA_PATH}/GlobalPID-im-muon-{SAMPLE}-test"), max_files=50)
head = reader_test.as_dask_dataframe().head(20_000_000, npartitions=-1)

# %%
X_test = head[reader_test.features].values
y_test = head[reader_test.labels].values
preds = gan.generator.predict(X_test, batch_size=50_000)
# Out:
# 187/187 [==============================] - 1s 3ms/step

# %%
X_test.shape, y_test.shape, preds.shape
# Out:
# ((9309431, 10), (9309431, 9), (9309431, 9))

# %%
# referee_true = gan.referee.predict((X_test, y_test), batch_size=50_000)
# referee_pred = gan.referee.predict((X_test, preds), batch_size=50_000)

# %%
# plt.figure(figsize=(8, 5), dpi=100)
# plt.xlabel("Referee score", fontsize=12)
# plt.ylabel("Candidates", fontsize=12)
# 
# bins = np.linspace(0.0, 1.0, 101)
# plt.hist(referee_true, bins=bins, label="Detailed Simulation")
# plt.hist(referee_pred, bins=bins, histtype="step", lw=2, label="GAN-based model")
# plt.legend(fontsize=10)
# 
# plt.show()

# %%
# from pidgan.optimization.scores import KSDistance
# 
# ks_dist = KSDistance()
# ks_score = ks_dist(referee_true, referee_pred, bins=100, range=[0.0, 1.0])
# 
# print(f"K-S distance (referee): {ks_score:.3f}")

# %%
# chunk_size = 5_000_000
# 
# np.savez_compressed(
#     f"./exports/{prefix}-Muon-muon-referee.npz",
#     referee_true=referee_true[:chunk_size],
#     referee_pred=referee_pred[:chunk_size],
#     ks_score=ks_score,
# )

# %%
import pickle

models_dir = "/home/mabarbet/PythonFastSim/models/GlobalPID-im_muon_models"

with open(f"{models_dir}/tX_{SAMPLE}.pkl", "rb") as file:
    X_scaler = pickle.load(file)

with open(f"{models_dir}/tY_{SAMPLE}.pkl", "rb") as file:
    y_scaler = pickle.load(file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer
    
X_post = invertColumnTransformer(X_scaler, X_test)
y_post = invertColumnTransformer(y_scaler, y_test)
preds_post = invertColumnTransformer(y_scaler, preds)

# %%
plt.figure(figsize=(32, 15), dpi=100)

# PIDe
plt.subplot(3, 4, 1)
bins = np.linspace(-20.0, 10.0, 101)
plt.xlabel("$\mathtt{PIDe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDK
plt.subplot(3, 4, 2)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDp
plt.subplot(3, 4, 3)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDpK
plt.subplot(3, 4, 4)
bins = np.linspace(-100.0, 50.0, 101)
plt.xlabel("$\mathtt{PIDpK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000] - y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000] - preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNe
plt.subplot(3, 4, 5)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNe")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNpi
plt.subplot(3, 4, 6)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNpi}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNpi")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNpi")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# ProbNNk
plt.subplot(3, 4, 7)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNk}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNk")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNk")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNp
plt.subplot(3, 4, 8)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNp")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# PIDmu
plt.subplot(3, 4, 9)
bins = np.linspace(-15.0, 25.0, 101)
plt.xlabel("$\mathtt{PIDmu}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# ProbNNmu
plt.subplot(3, 4, 10)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNmu}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNmu")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNmu")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# PIDmue
plt.subplot(3, 4, 11)
bins = np.linspace(-20.0, 30.0, 101)
plt.xlabel("$\mathtt{PIDmue}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000] - y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000] - preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
np.savez_compressed(
    f"./exports/{prefix}-GlobalPID-im-muon-results.npz",
    feat_vars=np.array(x_vars[:3] + [x_vars[-1]]),
    label_vars=np.array(y_vars),
    results=np.c_[X_post[:, :3], X_post[:, -1], y_post, preds_post][:750_000],
)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_GlobalPID-im_muon_{SAMPLE}_gan"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    generator.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-im_muon_models/20240108-12h45m23s_GlobalPID-im_muon_2016MU_gan/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-im_muon_models/20240108-12h45m23s_GlobalPID-im_muon_2016MU_gan/assets
