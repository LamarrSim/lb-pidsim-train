# %% [markdown]
# # Training of the _isMuon_ model for _muons_
#
# In this notebook we setup the training for the isMuon model for _muons_, based on a Deep Neural Network.
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [isMuon-preprocessing.ipynb](./isMuon-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("ISMUON_MUON_TRAIN_DATA", f"{DATA_PATH}/isMuon-muon-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("ISMUON_MUON_VAL_DATA", f"{DATA_PATH}/isMuon-muon-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 4]), TensorShape([500000, 1]))

# %% [markdown]
# ## Model definition
#
# The function we are modelling is not a trivial one, requiring a sufficiently deep neural network.
# In order to limit the effect of the vanishing gradient and make the trainig procedure faster, we are using the concept of Residual Layer, introducing skipping connections between the input and the output of each layer.
#
# With residual layers, the neural network is trained to learn the deviation from identity which is a much less demanding task than learning the whole transformation.
#
# The output layer of the neural network has a sigmoid activation function to be mapped into the interval 0-1 and being interpreted as the **probability** for the particle of **passing the isMuon criterion**.

# %%
from pidgan.players.classifiers import ResClassifier

model = ResClassifier(
    num_hidden_layers=10,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=tf.keras.regularizers.L2(5e-5),
    mlp_dropout_rates=0.0,
    name="classifier",
)

# %%
model(X[:256])
model.summary()
# Out:
# Model: "classifier_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 4)]                  0         []
#
#  dense_0 (Dense)             (None, 128)                  640       ['input_1[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['dense_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['dense_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  16512     ['add_3-4[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_5[0][0]']
#
#  add_4-5 (Add)               (None, 128)                  0         ['add_3-4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  16512     ['add_4-5[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  add_5-6 (Add)               (None, 128)                  0         ['add_4-5[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  16512     ['add_5-6[0][0]']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['dense_7[0][0]']
#
#  add_6-7 (Add)               (None, 128)                  0         ['add_5-6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  dense_8 (Dense)             (None, 128)                  16512     ['add_6-7[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_8[0][0]']
#
#  add_7-8 (Add)               (None, 128)                  0         ['add_6-7[0][0]',
#                                                                      'dropout_8[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  16512     ['add_7-8[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_9[0][0]']
#
#  add_8-9 (Add)               (None, 128)                  0         ['add_7-8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  dense_out (Dense)           (None, 1)                    129       ['add_8-9[0][0]']
#
# ==================================================================================================
# Total params: 149377 (583.50 KB)
# Trainable params: 149377 (583.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model.export_model,
    to_file="./images/isMuon-muon-model.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# The rest of the training procedure is rather standard:
#  * loss function: [binary cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy)
#  * optimizer: [RMSprop](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/experimental/RMSprop) or [Adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)

# %%
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# To speed up convergence, we split the training procedure in two steps:
# * First, we start with a high learning rate that is exponentially decreased by using a custom [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler), and with a binary cross-entropy loss with `label_smoothing` set to 0.05.
# * Then, we operate some fine tuning by fixing the learning rate to the value reached by the scheduler, and by removing the `label_smoothing`.

# %%
model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.05),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(0.05),
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

lr_sched = LearnRateExpDecay(
    model.optimizer,
    decay_rate=0.1,
    decay_steps=50_000,
    verbose=True,
)

# early_stop = tf.keras.callbacks.EarlyStopping(
#     monitor="val_auc",
#     min_delta=1e-5,
#     patience=3,
#     mode="max",
# )

# %%
batch_size = 20_000
num_epochs = 200

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

callbacks = [lr_sched]  # [lr_sched, early_stop]

train = model.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)
# Out:
# Epoch 1/200
#       4/Unknown - 7s 18ms/step - loss: 7830.6738 - auc: 0.4903 - lr: 0.0500WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0155s vs `on_train_batch_begin` time: 0.0910s). Check your callbacks.
# 615/615 [==============================] - 25s 31ms/step - loss: 51.5420 - auc: 0.9286 - lr: 0.0493 - val_loss: 0.5306 - val_auc: 0.9402
# Epoch 2/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.5083 - auc: 0.9376 - lr: 0.0479 - val_loss: 0.4919 - val_auc: 0.9409
# Epoch 3/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.4893 - auc: 0.9382 - lr: 0.0466 - val_loss: 0.4773 - val_auc: 0.9426
# Epoch 4/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.4783 - auc: 0.9390 - lr: 0.0453 - val_loss: 0.4683 - val_auc: 0.9429
# Epoch 5/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4696 - auc: 0.9394 - lr: 0.0440 - val_loss: 0.4608 - val_auc: 0.9432
# Epoch 6/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4623 - auc: 0.9396 - lr: 0.0428 - val_loss: 0.4525 - val_auc: 0.9438
# Epoch 7/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4550 - auc: 0.9398 - lr: 0.0416 - val_loss: 0.4459 - val_auc: 0.9436
# Epoch 8/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.4479 - auc: 0.9399 - lr: 0.0404 - val_loss: 0.4384 - val_auc: 0.9439
# Epoch 9/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.4407 - auc: 0.9400 - lr: 0.0393 - val_loss: 0.4311 - val_auc: 0.9440
# Epoch 10/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4334 - auc: 0.9402 - lr: 0.0382 - val_loss: 0.4241 - val_auc: 0.9439
# Epoch 11/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.4260 - auc: 0.9403 - lr: 0.0371 - val_loss: 0.4167 - val_auc: 0.9441
# Epoch 12/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4184 - auc: 0.9404 - lr: 0.0361 - val_loss: 0.4092 - val_auc: 0.9440
# Epoch 13/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.4107 - auc: 0.9405 - lr: 0.0351 - val_loss: 0.4014 - val_auc: 0.9440
# Epoch 14/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.4026 - auc: 0.9406 - lr: 0.0341 - val_loss: 0.3935 - val_auc: 0.9443
# Epoch 15/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3945 - auc: 0.9406 - lr: 0.0332 - val_loss: 0.3860 - val_auc: 0.9442
# Epoch 16/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3864 - auc: 0.9407 - lr: 0.0322 - val_loss: 0.3771 - val_auc: 0.9444
# Epoch 17/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3781 - auc: 0.9408 - lr: 0.0313 - val_loss: 0.3690 - val_auc: 0.9445
# Epoch 18/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3700 - auc: 0.9408 - lr: 0.0305 - val_loss: 0.3613 - val_auc: 0.9444
# Epoch 19/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3622 - auc: 0.9409 - lr: 0.0296 - val_loss: 0.3536 - val_auc: 0.9443
# Epoch 20/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3549 - auc: 0.9409 - lr: 0.0288 - val_loss: 0.3467 - val_auc: 0.9443
# Epoch 21/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3483 - auc: 0.9409 - lr: 0.0280 - val_loss: 0.3405 - val_auc: 0.9443
# Epoch 22/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3427 - auc: 0.9409 - lr: 0.0272 - val_loss: 0.3351 - val_auc: 0.9443
# Epoch 23/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3381 - auc: 0.9409 - lr: 0.0264 - val_loss: 0.3311 - val_auc: 0.9443
# Epoch 24/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3346 - auc: 0.9409 - lr: 0.0257 - val_loss: 0.3283 - val_auc: 0.9443
# Epoch 25/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3322 - auc: 0.9409 - lr: 0.0250 - val_loss: 0.3264 - val_auc: 0.9443
# Epoch 26/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3308 - auc: 0.9409 - lr: 0.0243 - val_loss: 0.3255 - val_auc: 0.9442
# Epoch 27/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3301 - auc: 0.9409 - lr: 0.0236 - val_loss: 0.3249 - val_auc: 0.9443
# Epoch 28/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3298 - auc: 0.9409 - lr: 0.0229 - val_loss: 0.3246 - val_auc: 0.9444
# Epoch 29/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3296 - auc: 0.9409 - lr: 0.0223 - val_loss: 0.3245 - val_auc: 0.9442
# Epoch 30/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3295 - auc: 0.9409 - lr: 0.0217 - val_loss: 0.3245 - val_auc: 0.9443
# Epoch 31/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3295 - auc: 0.9409 - lr: 0.0211 - val_loss: 0.3244 - val_auc: 0.9442
# Epoch 32/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3295 - auc: 0.9409 - lr: 0.0205 - val_loss: 0.3244 - val_auc: 0.9442
# Epoch 33/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3295 - auc: 0.9409 - lr: 0.0199 - val_loss: 0.3243 - val_auc: 0.9443
# Epoch 34/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3294 - auc: 0.9409 - lr: 0.0194 - val_loss: 0.3242 - val_auc: 0.9444
# Epoch 35/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3294 - auc: 0.9410 - lr: 0.0188 - val_loss: 0.3240 - val_auc: 0.9444
# Epoch 36/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3294 - auc: 0.9410 - lr: 0.0183 - val_loss: 0.3240 - val_auc: 0.9444
# Epoch 37/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3293 - auc: 0.9410 - lr: 0.0178 - val_loss: 0.3238 - val_auc: 0.9445
# Epoch 38/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3293 - auc: 0.9410 - lr: 0.0173 - val_loss: 0.3241 - val_auc: 0.9443
# Epoch 39/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3292 - auc: 0.9410 - lr: 0.0168 - val_loss: 0.3241 - val_auc: 0.9444
# Epoch 40/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3292 - auc: 0.9410 - lr: 0.0163 - val_loss: 0.3241 - val_auc: 0.9443
# Epoch 41/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3291 - auc: 0.9410 - lr: 0.0159 - val_loss: 0.3242 - val_auc: 0.9443
# Epoch 42/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3291 - auc: 0.9410 - lr: 0.0154 - val_loss: 0.3242 - val_auc: 0.9442
# Epoch 43/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3291 - auc: 0.9410 - lr: 0.0150 - val_loss: 0.3241 - val_auc: 0.9442
# Epoch 44/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0146 - val_loss: 0.3241 - val_auc: 0.9442
# Epoch 45/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0142 - val_loss: 0.3242 - val_auc: 0.9442
# Epoch 46/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0138 - val_loss: 0.3242 - val_auc: 0.9442
# Epoch 47/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0134 - val_loss: 0.3241 - val_auc: 0.9442
# Epoch 48/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0130 - val_loss: 0.3242 - val_auc: 0.9442
# Epoch 49/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3290 - auc: 0.9410 - lr: 0.0127 - val_loss: 0.3241 - val_auc: 0.9442
# Epoch 50/200
# 615/615 [==============================] - 15s 24ms/step - loss: 0.3289 - auc: 0.9410 - lr: 0.0123 - val_loss: 0.3241 - val_auc: 0.9442
# Epoch 51/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3289 - auc: 0.9410 - lr: 0.0120 - val_loss: 0.3240 - val_auc: 0.9443
# Epoch 52/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3289 - auc: 0.9411 - lr: 0.0116 - val_loss: 0.3240 - val_auc: 0.9442
# Epoch 53/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3289 - auc: 0.9411 - lr: 0.0113 - val_loss: 0.3240 - val_auc: 0.9443
# Epoch 54/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3288 - auc: 0.9411 - lr: 0.0110 - val_loss: 0.3239 - val_auc: 0.9443
# Epoch 55/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3288 - auc: 0.9411 - lr: 0.0107 - val_loss: 0.3240 - val_auc: 0.9442
# Epoch 56/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3288 - auc: 0.9411 - lr: 0.0104 - val_loss: 0.3239 - val_auc: 0.9443
# Epoch 57/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3288 - auc: 0.9411 - lr: 0.0101 - val_loss: 0.3239 - val_auc: 0.9442
# Epoch 58/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0098 - val_loss: 0.3239 - val_auc: 0.9443
# Epoch 59/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0095 - val_loss: 0.3239 - val_auc: 0.9442
# Epoch 60/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0093 - val_loss: 0.3239 - val_auc: 0.9442
# Epoch 61/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0090 - val_loss: 0.3238 - val_auc: 0.9442
# Epoch 62/200
# 615/615 [==============================] - 15s 25ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0088 - val_loss: 0.3238 - val_auc: 0.9443
# Epoch 63/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0085 - val_loss: 0.3238 - val_auc: 0.9443
# Epoch 64/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3287 - auc: 0.9411 - lr: 0.0083 - val_loss: 0.3238 - val_auc: 0.9443
# Epoch 65/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3286 - auc: 0.9411 - lr: 0.0080 - val_loss: 0.3237 - val_auc: 0.9443
# Epoch 66/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3286 - auc: 0.9411 - lr: 0.0078 - val_loss: 0.3238 - val_auc: 0.9443
# Epoch 67/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3286 - auc: 0.9412 - lr: 0.0076 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 68/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3286 - auc: 0.9412 - lr: 0.0074 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 69/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3286 - auc: 0.9412 - lr: 0.0072 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 70/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3286 - auc: 0.9412 - lr: 0.0070 - val_loss: 0.3238 - val_auc: 0.9444
# Epoch 71/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3286 - auc: 0.9412 - lr: 0.0068 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 72/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0066 - val_loss: 0.3237 - val_auc: 0.9443
# Epoch 73/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0064 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 74/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0062 - val_loss: 0.3237 - val_auc: 0.9444
# Epoch 75/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0061 - val_loss: 0.3237 - val_auc: 0.9445
# Epoch 76/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0059 - val_loss: 0.3237 - val_auc: 0.9445
# Epoch 77/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0057 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 78/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3285 - auc: 0.9412 - lr: 0.0056 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 79/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0054 - val_loss: 0.3237 - val_auc: 0.9445
# Epoch 80/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0053 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 81/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0051 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 82/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0050 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 83/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0048 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 84/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0047 - val_loss: 0.3237 - val_auc: 0.9445
# Epoch 85/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0046 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 86/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0044 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 87/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3284 - auc: 0.9412 - lr: 0.0043 - val_loss: 0.3236 - val_auc: 0.9444
# Epoch 88/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3283 - auc: 0.9412 - lr: 0.0042 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 89/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3283 - auc: 0.9412 - lr: 0.0041 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 90/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3283 - auc: 0.9412 - lr: 0.0040 - val_loss: 0.3235 - val_auc: 0.9445
# Epoch 91/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0039 - val_loss: 0.3236 - val_auc: 0.9445
# Epoch 92/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0037 - val_loss: 0.3235 - val_auc: 0.9445
# Epoch 93/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0036 - val_loss: 0.3235 - val_auc: 0.9445
# Epoch 94/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0035 - val_loss: 0.3235 - val_auc: 0.9445
# Epoch 95/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0034 - val_loss: 0.3235 - val_auc: 0.9445
# Epoch 96/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0033 - val_loss: 0.3235 - val_auc: 0.9444
# Epoch 97/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3283 - auc: 0.9413 - lr: 0.0033 - val_loss: 0.3235 - val_auc: 0.9444
# Epoch 98/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0032 - val_loss: 0.3235 - val_auc: 0.9443
# Epoch 99/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0031 - val_loss: 0.3235 - val_auc: 0.9444
# Epoch 100/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0030 - val_loss: 0.3235 - val_auc: 0.9444
# Epoch 101/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0029 - val_loss: 0.3234 - val_auc: 0.9444
# Epoch 102/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0028 - val_loss: 0.3234 - val_auc: 0.9444
# Epoch 103/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0027 - val_loss: 0.3234 - val_auc: 0.9444
# Epoch 104/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0027 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 105/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0026 - val_loss: 0.3234 - val_auc: 0.9444
# Epoch 106/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0025 - val_loss: 0.3234 - val_auc: 0.9444
# Epoch 107/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0024 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 108/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0024 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 109/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0023 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 110/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0022 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 111/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0022 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 112/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3282 - auc: 0.9413 - lr: 0.0021 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 113/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0021 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 114/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0020 - val_loss: 0.3234 - val_auc: 0.9445
# Epoch 115/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0020 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 116/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0019 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 117/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0018 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 118/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9413 - lr: 0.0018 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 119/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0017 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 120/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0017 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 121/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0016 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 122/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0016 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 123/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0016 - val_loss: 0.3233 - val_auc: 0.9445
# Epoch 124/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0015 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 125/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0015 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 126/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0014 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 127/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0014 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 128/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0014 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 129/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0013 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 130/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0013 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 131/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0012 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 132/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0012 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 133/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3281 - auc: 0.9414 - lr: 0.0012 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 134/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 0.0011 - val_loss: 0.3232 - val_auc: 0.9446
# Epoch 135/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 0.0011 - val_loss: 0.3232 - val_auc: 0.9446
# Epoch 136/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 0.0011 - val_loss: 0.3232 - val_auc: 0.9446
# Epoch 137/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 0.0010 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 138/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 0.0010 - val_loss: 0.3232 - val_auc: 0.9446
# Epoch 139/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 9.8950e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 140/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 9.6187e-04 - val_loss: 0.3232 - val_auc: 0.9446
# Epoch 141/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 9.3501e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 142/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 9.0890e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 143/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 8.8352e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 144/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 8.5884e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 145/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3280 - auc: 0.9414 - lr: 8.3486e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 146/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 8.1155e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 147/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 7.8889e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 148/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 7.6686e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 149/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 7.4544e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 150/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 7.2463e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 151/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 7.0439e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 152/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 6.8472e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 153/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 6.6560e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 154/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 6.4702e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 155/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 6.2895e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 156/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 6.1138e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 157/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.9431e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 158/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.7772e-04 - val_loss: 0.3232 - val_auc: 0.9445
# Epoch 159/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.6158e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 160/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.4590e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 161/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.3066e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 162/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.1584e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 163/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3280 - auc: 0.9414 - lr: 5.0143e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 164/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.8743e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 165/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.7382e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 166/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.6059e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 167/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.4773e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 168/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.3523e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 169/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.2307e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 170/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3280 - auc: 0.9414 - lr: 4.1126e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 171/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 3.9977e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 172/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 3.8861e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 173/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3280 - auc: 0.9414 - lr: 3.7776e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 174/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.6721e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 175/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.5696e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 176/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.4699e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 177/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.3730e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 178/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.2788e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 179/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.1872e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 180/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.0982e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 181/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3279 - auc: 0.9414 - lr: 3.0117e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 182/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.9276e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 183/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.8459e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 184/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.7664e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 185/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.6891e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 186/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.6141e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 187/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.5411e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 188/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.4701e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 189/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.4011e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 190/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.3341e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 191/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.2689e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 192/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.2055e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 193/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.1439e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 194/200
# 615/615 [==============================] - 16s 25ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.0841e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 195/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 2.0259e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 196/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 1.9693e-04 - val_loss: 0.3231 - val_auc: 0.9445
# Epoch 197/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 1.9143e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 198/200
# 615/615 [==============================] - 17s 27ms/step - loss: 0.3279 - auc: 0.9414 - lr: 1.8609e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 199/200
# 615/615 [==============================] - 17s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 1.8089e-04 - val_loss: 0.3231 - val_auc: 0.9446
# Epoch 200/200
# 615/615 [==============================] - 16s 26ms/step - loss: 0.3279 - auc: 0.9414 - lr: 1.7584e-04 - val_loss: 0.3231 - val_auc: 0.9445

# %%
from datetime import datetime

model.compile(
    loss=BinaryCrossentropy(label_smoothing=0.0),
    metrics=tf.keras.metrics.AUC(name="auc"),
    optimizer=Adam(1e-4),
)
early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=5)

callbacks = None  # [early_stop]

train_ft = model.fit(data_train, epochs=int(num_epochs/2.0), validation_data=data_val, callbacks=callbacks)

prefix = ""
timestamp = str(datetime.now())
timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
    prefix += time + unit  # YYYYMMDD-HHhMMmSSs
# Out:
# Epoch 1/100
# 615/615 [==============================] - 20s 26ms/step - loss: 0.2689 - auc: 0.9413 - val_loss: 0.2622 - val_auc: 0.9445
# Epoch 2/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2679 - auc: 0.9414 - val_loss: 0.2620 - val_auc: 0.9445
# Epoch 3/100
# 615/615 [==============================] - 15s 24ms/step - loss: 0.2678 - auc: 0.9414 - val_loss: 0.2619 - val_auc: 0.9446
# Epoch 4/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2678 - auc: 0.9414 - val_loss: 0.2619 - val_auc: 0.9446
# Epoch 5/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2678 - auc: 0.9414 - val_loss: 0.2619 - val_auc: 0.9446
# Epoch 6/100
# 615/615 [==============================] - 15s 24ms/step - loss: 0.2678 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 7/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2678 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 8/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 9/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 10/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 11/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 12/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 13/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 14/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 15/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 16/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 17/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 18/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 19/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 20/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 21/100
# 615/615 [==============================] - 15s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 22/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 23/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 24/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 25/100
# 615/615 [==============================] - 15s 24ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 26/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 27/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 28/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 29/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 30/100
# 615/615 [==============================] - 17s 27ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 31/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 32/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 33/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 34/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 35/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 36/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 37/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 38/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 39/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 40/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 41/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 42/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 43/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 44/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 45/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 46/100
# 615/615 [==============================] - 15s 24ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 47/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 48/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 49/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 50/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 51/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 52/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 53/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 54/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 55/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 56/100
# 615/615 [==============================] - 15s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 57/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 58/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 59/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 60/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 61/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 62/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 63/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9414 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 64/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2677 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9447
# Epoch 65/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2677 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 66/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 67/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 68/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 69/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 70/100
# 615/615 [==============================] - 15s 24ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 71/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 72/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 73/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 74/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 75/100
# 615/615 [==============================] - 15s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 76/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 77/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 78/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 79/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 80/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 81/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 82/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 83/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 84/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 85/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 86/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 87/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 88/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 89/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 90/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 91/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 92/100
# 615/615 [==============================] - 15s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 93/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 94/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 95/100
# 615/615 [==============================] - 16s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 96/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 97/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 98/100
# 615/615 [==============================] - 17s 26ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 99/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446
# Epoch 100/100
# 615/615 [==============================] - 16s 25ms/step - loss: 0.2676 - auc: 0.9415 - val_loss: 0.2618 - val_auc: 0.9446

# %% [markdown]
# The two regimes are well visibile in the plot below, combining the two training phases in a single epoch count.

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Binary cross-entropy", fontsize=12)
plt.plot(train.history["loss"][1:] + train_ft.history["loss"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_loss"][1:] + train_ft.history["val_loss"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("ROC AUC", fontsize=12)
plt.plot(train.history["auc"][1:] + train_ft.history["auc"], lw=1.5, color="#d01c8b", label="training set")
plt.plot(train.history["val_auc"][1:] + train_ft.history["val_auc"], lw=1.5, color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.show()

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-isMuon-muon-train.csv")

train_history_ft = train_ft.history.copy()
train_history_ft.update({"lr": [1e-4 for _ in range(int(num_epochs/2.0))]})
pd.DataFrame(train_history_ft).to_csv(f"./exports/{prefix}-isMuon-muon-train-ft.csv")

# %% [markdown]
# ## A first, rough validation
#
# While a proper validation of the model is demanded to a dedicated notebook (still to be prepared), here we check that the training was not completely failed and provides reasonable numbers.
#
# In particular, we compare the distributions of the training labels and of the predictions.
#
# Clearly, the training labels are either 1 or 0 because a particle passes either isMuon or not. Instead, the output of the neural network is a probability and hence it will be distributed between 0 and 1.
#
# The comparison is used to ensure that both the training labels and the network output are not unreasonable, for example collapsed into a single value or with training labels belonging to a single category.

# %%
reader_test = FeatherReader(environ.get("ISMUON_MUON_TEST_DATA", f"{DATA_PATH}/isMuon-muon-{SAMPLE}-test"), max_files=5)
ds_test = reader_test.as_tf_dataset()

# %%
X_test, y_test = next(iter(ds_test.batch(20_000_000).as_numpy_iterator()))
preds = model.predict(X_test, batch_size=50_000)
# Out:
# 310/310 [==============================] - 2s 5ms/step

# %%
bins = np.linspace(0, 1, 11)
plt.hist(y_test, bins=bins, label="Simulation")
plt.hist(preds, bins=bins, histtype='step', linewidth=2, label="Predictions")
plt.legend()
plt.show()

# %% [markdown]
# Then we can compare the distribution of a preprocessed variable before and after the application of the isMuon criterion.
#
# Here, for example, we consider the preprocessed of the momentum $p$.
#
# Since the variable is preprocessed, without applying any cut (**Generated**) we have a perfectly normalized Gaussian.
#
# Applying the criterion `isMuon == 1`, we get another distribution that we expect to model with decent approximation by applying the response of the trained neural networks as weights to the **Generated** dataset.
#
# The comparison of the two histograms (obtained by applying a cut on the true isMuon or applying a weight on the isMuon probability) provides a first validation on the quality of the parametrization.

# %%
prep_p = X_test[:, 0]
bins = np.linspace(-5, 5, 101)

denominator, _ = np.histogram(prep_p, bins=bins)
true_numerator, _ = np.histogram(prep_p, bins=bins, weights=y_test.flatten())
predicted_numerator, _ = np.histogram(prep_p, bins=bins, weights=preds.flatten())

plt.xlabel("Preprocessed $p$ [GeV/$c$]")

plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=denominator, label="Generated muons", histtype='step')
plt.fill_between(
    (bins[1:] + bins[:-1])/2, np.zeros(len(true_numerator)), true_numerator,
    label="isMuon passed (sim)",
    color='#88ee88'
)
plt.hist((bins[1:] + bins[:-1])/2, bins=bins, weights=predicted_numerator, label="isMuon passed (model)", histtype='step', linewidth=2)

plt.legend(loc="upper left", fontsize=10)
# plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
models_dir = "/home/mabarbet/PythonFastSim/models/isMuon_muon_models"

# %%
import pickle

file_path = f"{models_dir}/tX_{SAMPLE}.pkl"

with open(file_path, "rb") as file:
    X_scaler = pickle.load(file)

# %%
import json

with open(f"{DATA_PATH}/isMuon-muon-{SAMPLE}-test/definitions.json") as json_file:
    definitions = json.load(json_file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer

print(f"Shapes:", X_test.shape, y_test.shape, preds.shape)

X_post = invertColumnTransformer(X_scaler, X_test)
np.savez_compressed(
    f"./exports/{prefix}-isMuon-muon-results.npz",
    feat_vars=np.array(definitions["features"]),
    label_vars=np.array(definitions["labels"]),
    results=np.c_[X_post, y_test, preds][:5_000_000],
)
# Out:
# Shapes: (15467254, 4) (15467254, 1) (15467254, 1)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_isMuon_muon_{SAMPLE}_ann"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    model.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_muon_models/20231230-13h08m22s_isMuon_muon_2016MU_model/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/isMuon_muon_models/20231230-13h08m22s_isMuon_muon_2016MU_model/assets
