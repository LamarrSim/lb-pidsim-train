# %% [markdown]
# # Training of the _GlobalPID_ model for _kaons_ not passing the isMuon criterion
#
# In this notebook we setup the training for the GlobalPID model for _kaons_ that don't pass the isMuon criterion, based on Generative Adversarial Networks (GAN).
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [GlobalPID-preprocessing.ipynb](./GlobalPID-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"
TEST = False

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("GLOBALPID_NM_KAON_TRAIN_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("GLOBALPID_NM_KAON_VAL_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
x_vars = reader_train.features
y_vars = reader_train.labels

x_vars, y_vars
# Out:
# (['p_GeV',
#   'eta',
#   'nTracks_f',
#   'RichDLLe',
#   'RichDLLmu',
#   'RichDLLk',
#   'RichDLLp',
#   'charge'],
#  ['PIDe',
#   'PIDK',
#   'PIDp',
#   'ProbNNe',
#   'ProbNNpi',
#   'ProbNNk',
#   'ProbNNp',
#   'PIDmu'])

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 8]), TensorShape([500000, 8]))

# %% [markdown]
# ## Model definition
#
# TBA

# %% [markdown]
# ### Generator architecture
#
# TBA

# %%
from pidgan.players.generators import ResGenerator

generator = ResGenerator(
    output_dim=y.shape[1],
    latent_dim=64,
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    output_activation=None,
    name="generator",
)

# %%
generator(X[:256])
generator.summary()
# Out:
# Model: "generator_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 72)]                 0         []
#
#  dense_0 (Dense)             (None, 128)                  9344      ['input_1[0][0]']
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)                  0         ['dense_0[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['leaky_relu_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)                  0         ['dense_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['leaky_relu_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)                  0         ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['leaky_relu_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)                  0         ['dense_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['leaky_relu_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)                  0         ['dense_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['leaky_relu_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_out (Dense)           (None, 8)                    1032      ['add_3-4[0][0]']
#
# ==================================================================================================
# Total params: 76424 (298.53 KB)
# Trainable params: 76424 (298.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    generator.export_model,
    to_file="./images/GlobalPID-nm-kaon-generator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Discriminator architecture
#
# TBA

# %%
from pidgan.players.discriminators import AuxDiscriminator

discriminator = AuxDiscriminator(
    output_dim=1,
    aux_features=["3 - 0", "2 - 1"],  # ["PIDmu - PIDe", "PIDK - PIDp"]
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    enable_residual_blocks=False,
    output_activation=None,
    name="discriminator",
)

# %%
discriminator((X[:256], y[:256]))
discriminator.summary()
# Out:
# Model: "discriminator_func"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 18)]              0
#
#  dense_0 (Dense)             (None, 128)               2432
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)               0
#
#  dropout_0 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_out (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 68609 (268.00 KB)
# Trainable params: 68609 (268.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    discriminator.export_model,
    to_file="./images/GlobalPID-nm-kaon-discriminator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Referee architecture

# %%
from pidgan.players.classifiers import Classifier

referee = Classifier(
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=None,
    mlp_dropout_rates=0.0,
    name="referee",
)

# %%
referee((X[:256], y[:256]))
referee.summary()
# Out:
# Model: "referee_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             (256, 128)                2176
#
#  dropout_0 (Dropout)         (256, 128)                0
#
#  dense_1 (Dense)             (256, 128)                16512
#
#  dropout_1 (Dropout)         (256, 128)                0
#
#  dense_2 (Dense)             (256, 128)                16512
#
#  dropout_2 (Dropout)         (256, 128)                0
#
#  dense_3 (Dense)             (256, 128)                16512
#
#  dropout_3 (Dropout)         (256, 128)                0
#
#  dense_4 (Dense)             (256, 128)                16512
#
#  dropout_4 (Dropout)         (256, 128)                0
#
#  dense_out (Dense)           (256, 1)                  129
#
# =================================================================
# Total params: 68353 (267.00 KB)
# Trainable params: 68353 (267.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    referee.export_model,
    to_file="./images/GlobalPID-nm-kaon-referee.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Training setup
#
# TBA

# %%
from pidgan.algorithms import WGAN_ALP

gan = WGAN_ALP(
    generator=generator,
    discriminator=discriminator,
    lipschitz_penalty=1.0,
    lipschitz_penalty_strategy="one-sided",
    feature_matching_penalty=0.0,
    # referee=referee,
)

# %%
from tensorflow.keras.optimizers import RMSprop, Adam

g_lr0 = 9e-4
d_lr0 = 6e-4

gan.compile(
    metrics=["wass_dist"],
    generator_optimizer=RMSprop(g_lr0),
    discriminator_optimizer=RMSprop(d_lr0),
    generator_upds_per_batch=1,
    discriminator_upds_per_batch=1,
    # referee_optimizer=Adam(1e-3),
    # referee_upds_per_batch=1,
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

callbacks = list()

g_lr_sched = LearnRateExpDecay(
    gan.generator_optimizer,
    decay_rate=0.1,
    decay_steps=170_000,
    min_learning_rate=g_lr0/1e3,
    verbose=True,
    key="g_lr",
)
callbacks.append(g_lr_sched)

d_lr_sched = LearnRateExpDecay(
    gan.discriminator_optimizer,
    decay_rate=0.1,
    decay_steps=90_000,
    min_learning_rate=d_lr0/1e3,
    verbose=True,
    key="d_lr",
)
callbacks.append(d_lr_sched)

# r_lr_sched = LearnRateExpDecay(
#     gan.referee_optimizer,
#     decay_rate=0.1,
#     decay_steps=150_000,
#     verbose=True,
#     key="r_lr",
# )
# callbacks.append(r_lr_sched)

# %%
from datetime import datetime

batch_size = 9_000
num_epochs = 1000 if not TEST else 150

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

train = gan.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)

if not TEST:
    prefix = ""
    timestamp = str(datetime.now())
    timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
    for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
        prefix += time + unit  # YYYYMMDD-HHhMMmSSs
else:
    prefix = "test"
# Out:
# Epoch 1/1000
#       5/Unknown - 10s 16ms/step - g_loss: 0.6565 - d_loss: -0.1759 - wass_dist: -0.2951 - g_lr: 8.9998e-04 - d_lr: 5.9997e-04WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0123s vs `on_train_batch_begin` time: 0.1623s). Check your callbacks.
# 503/503 [==============================] - 20s 21ms/step - g_loss: 0.6292 - d_loss: -0.3518 - wass_dist: -1.1572 - g_lr: 8.9694e-04 - d_lr: 5.9616e-04 - val_g_loss: 1.1203 - val_d_loss: -1.0961 - val_wass_dist: -2.4510
# Epoch 2/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.2082 - d_loss: -0.5699 - wass_dist: -1.1763 - g_lr: 8.9084e-04 - d_lr: 5.8852e-04 - val_g_loss: 1.1547 - val_d_loss: -1.1605 - val_wass_dist: -1.6313
# Epoch 3/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.7814 - d_loss: -0.7065 - wass_dist: -0.8933 - g_lr: 8.8479e-04 - d_lr: 5.8099e-04 - val_g_loss: 0.9092 - val_d_loss: -0.9018 - val_wass_dist: -1.1089
# Epoch 4/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.8243 - d_loss: -0.5609 - wass_dist: -0.5957 - g_lr: 8.7878e-04 - d_lr: 5.7356e-04 - val_g_loss: 0.5966 - val_d_loss: -0.6003 - val_wass_dist: -1.1430
# Epoch 5/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.6722 - d_loss: -0.4260 - wass_dist: -0.6601 - g_lr: 8.7282e-04 - d_lr: 5.6623e-04 - val_g_loss: 0.7163 - val_d_loss: -0.7101 - val_wass_dist: -1.7449
# Epoch 6/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.5782 - d_loss: -0.3346 - wass_dist: -0.3156 - g_lr: 8.6689e-04 - d_lr: 5.5899e-04 - val_g_loss: 0.2737 - val_d_loss: -0.2909 - val_wass_dist: -1.1423
# Epoch 7/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.4849 - d_loss: -0.2983 - wass_dist: -0.1693 - g_lr: 8.6100e-04 - d_lr: 5.5184e-04 - val_g_loss: 0.2162 - val_d_loss: -0.1972 - val_wass_dist: -0.1759
# Epoch 8/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.4212 - d_loss: -0.2582 - wass_dist: -0.4244 - g_lr: 8.5516e-04 - d_lr: 5.4479e-04 - val_g_loss: 0.4480 - val_d_loss: -0.4240 - val_wass_dist: -0.7308
# Epoch 9/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.3850 - d_loss: -0.2696 - wass_dist: -0.5353 - g_lr: 8.4935e-04 - d_lr: 5.3782e-04 - val_g_loss: 0.5337 - val_d_loss: -0.5535 - val_wass_dist: -0.7964
# Epoch 10/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.3619 - d_loss: -0.2744 - wass_dist: -0.2210 - g_lr: 8.4358e-04 - d_lr: 5.3094e-04 - val_g_loss: 0.2652 - val_d_loss: -0.2588 - val_wass_dist: -1.2661
# Epoch 11/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.2913 - d_loss: -0.3177 - wass_dist: -0.3008 - g_lr: 8.3786e-04 - d_lr: 5.2416e-04 - val_g_loss: 0.2670 - val_d_loss: -0.3132 - val_wass_dist: -1.4460
# Epoch 12/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.2851 - d_loss: -0.4006 - wass_dist: -0.4891 - g_lr: 8.3217e-04 - d_lr: 5.1745e-04 - val_g_loss: 0.4954 - val_d_loss: -0.5054 - val_wass_dist: -2.0245
# Epoch 13/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.3562 - d_loss: -0.4950 - wass_dist: -1.0307 - g_lr: 8.2652e-04 - d_lr: 5.1084e-04 - val_g_loss: 0.9722 - val_d_loss: -1.0091 - val_wass_dist: -2.0783
# Epoch 14/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.4484 - d_loss: -0.5700 - wass_dist: -0.9508 - g_lr: 8.2091e-04 - d_lr: 5.0430e-04 - val_g_loss: 0.9291 - val_d_loss: -0.9855 - val_wass_dist: -3.5856
# Epoch 15/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.5399 - d_loss: -0.6225 - wass_dist: -1.2647 - g_lr: 8.1533e-04 - d_lr: 4.9786e-04 - val_g_loss: 1.1991 - val_d_loss: -1.1725 - val_wass_dist: -4.9873
# Epoch 16/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.6105 - d_loss: -0.6581 - wass_dist: -1.0153 - g_lr: 8.0980e-04 - d_lr: 4.9149e-04 - val_g_loss: 0.9815 - val_d_loss: -1.0239 - val_wass_dist: -3.5381
# Epoch 17/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.6573 - d_loss: -0.6664 - wass_dist: -1.1956 - g_lr: 8.0430e-04 - d_lr: 4.8521e-04 - val_g_loss: 1.1833 - val_d_loss: -1.1728 - val_wass_dist: -4.5107
# Epoch 18/1000
# 503/503 [==============================] - 11s 21ms/step - g_loss: 1.6977 - d_loss: -0.6626 - wass_dist: -1.0734 - g_lr: 7.9884e-04 - d_lr: 4.7900e-04 - val_g_loss: 1.0960 - val_d_loss: -1.0741 - val_wass_dist: -5.1179
# Epoch 19/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.7341 - d_loss: -0.6536 - wass_dist: -1.0935 - g_lr: 7.9341e-04 - d_lr: 4.7288e-04 - val_g_loss: 1.0568 - val_d_loss: -1.0663 - val_wass_dist: -1.6073
# Epoch 20/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.7532 - d_loss: -0.6445 - wass_dist: -0.8666 - g_lr: 7.8803e-04 - d_lr: 4.6683e-04 - val_g_loss: 0.8489 - val_d_loss: -0.8097 - val_wass_dist: -2.3847
# Epoch 21/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.7684 - d_loss: -0.6268 - wass_dist: -0.9993 - g_lr: 7.8268e-04 - d_lr: 4.6086e-04 - val_g_loss: 1.0734 - val_d_loss: -1.1113 - val_wass_dist: -2.6066
# Epoch 22/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.7759 - d_loss: -0.6284 - wass_dist: -0.8635 - g_lr: 7.7736e-04 - d_lr: 4.5497e-04 - val_g_loss: 0.9335 - val_d_loss: -0.9107 - val_wass_dist: -2.7266
# Epoch 23/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.8067 - d_loss: -0.6371 - wass_dist: -1.0995 - g_lr: 7.7208e-04 - d_lr: 4.4915e-04 - val_g_loss: 1.0886 - val_d_loss: -1.1243 - val_wass_dist: -3.4786
# Epoch 24/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.8007 - d_loss: -0.6723 - wass_dist: -0.9484 - g_lr: 7.6684e-04 - d_lr: 4.4341e-04 - val_g_loss: 0.8805 - val_d_loss: -0.8587 - val_wass_dist: -1.7324
# Epoch 25/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.7912 - d_loss: -0.6882 - wass_dist: -1.2092 - g_lr: 7.6163e-04 - d_lr: 4.3774e-04 - val_g_loss: 1.2604 - val_d_loss: -1.2467 - val_wass_dist: -4.5555
# Epoch 26/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.7538 - d_loss: -0.6949 - wass_dist: -1.0693 - g_lr: 7.5646e-04 - d_lr: 4.3214e-04 - val_g_loss: 1.1337 - val_d_loss: -1.0326 - val_wass_dist: -3.7221
# Epoch 27/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.6958 - d_loss: -0.6730 - wass_dist: -1.1835 - g_lr: 7.5133e-04 - d_lr: 4.2662e-04 - val_g_loss: 1.1622 - val_d_loss: -1.2274 - val_wass_dist: -4.1473
# Epoch 28/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.6742 - d_loss: -0.6638 - wass_dist: -1.2217 - g_lr: 7.4623e-04 - d_lr: 4.2116e-04 - val_g_loss: 1.1788 - val_d_loss: -1.2224 - val_wass_dist: -2.0796
# Epoch 29/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.6315 - d_loss: -0.6411 - wass_dist: -0.9553 - g_lr: 7.4116e-04 - d_lr: 4.1578e-04 - val_g_loss: 0.9007 - val_d_loss: -0.8967 - val_wass_dist: -3.4106
# Epoch 30/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.6216 - d_loss: -0.6335 - wass_dist: -1.2305 - g_lr: 7.3613e-04 - d_lr: 4.1046e-04 - val_g_loss: 1.2958 - val_d_loss: -1.2824 - val_wass_dist: -4.0432
# Epoch 31/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.6518 - d_loss: -0.6702 - wass_dist: -0.8587 - g_lr: 7.3113e-04 - d_lr: 4.0521e-04 - val_g_loss: 0.9583 - val_d_loss: -0.9003 - val_wass_dist: -2.1989
# Epoch 32/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.6711 - d_loss: -0.6743 - wass_dist: -0.7010 - g_lr: 7.2616e-04 - d_lr: 4.0003e-04 - val_g_loss: 0.6980 - val_d_loss: -0.7475 - val_wass_dist: -2.2213
# Epoch 33/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.6859 - d_loss: -0.6537 - wass_dist: -1.1248 - g_lr: 7.2123e-04 - d_lr: 3.9492e-04 - val_g_loss: 1.0886 - val_d_loss: -1.1048 - val_wass_dist: -3.3325
# Epoch 34/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.6928 - d_loss: -0.6613 - wass_dist: -0.8125 - g_lr: 7.1634e-04 - d_lr: 3.8987e-04 - val_g_loss: 0.7924 - val_d_loss: -0.8140 - val_wass_dist: -2.0220
# Epoch 35/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.6913 - d_loss: -0.6586 - wass_dist: -0.8856 - g_lr: 7.1147e-04 - d_lr: 3.8488e-04 - val_g_loss: 0.9007 - val_d_loss: -0.9759 - val_wass_dist: -2.3763
# Epoch 36/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.7032 - d_loss: -0.6799 - wass_dist: -0.9897 - g_lr: 7.0664e-04 - d_lr: 3.7996e-04 - val_g_loss: 0.9967 - val_d_loss: -1.0365 - val_wass_dist: -2.9002
# Epoch 37/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.7021 - d_loss: -0.6817 - wass_dist: -0.7400 - g_lr: 7.0184e-04 - d_lr: 3.7510e-04 - val_g_loss: 0.7900 - val_d_loss: -0.7540 - val_wass_dist: -2.9550
# Epoch 38/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.7067 - d_loss: -0.7020 - wass_dist: -1.3530 - g_lr: 6.9708e-04 - d_lr: 3.7031e-04 - val_g_loss: 1.3498 - val_d_loss: -1.3915 - val_wass_dist: -3.0671
# Epoch 39/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.7470 - d_loss: -0.7351 - wass_dist: -1.2992 - g_lr: 6.9235e-04 - d_lr: 3.6557e-04 - val_g_loss: 1.4084 - val_d_loss: -1.4110 - val_wass_dist: -3.9377
# Epoch 40/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.7698 - d_loss: -0.7610 - wass_dist: -1.3619 - g_lr: 6.8764e-04 - d_lr: 3.6090e-04 - val_g_loss: 1.3661 - val_d_loss: -1.4001 - val_wass_dist: -3.9148
# Epoch 41/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.8106 - d_loss: -0.7909 - wass_dist: -1.3636 - g_lr: 6.8298e-04 - d_lr: 3.5628e-04 - val_g_loss: 1.3580 - val_d_loss: -1.3918 - val_wass_dist: -3.2306
# Epoch 42/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.8355 - d_loss: -0.8211 - wass_dist: -1.6666 - g_lr: 6.7834e-04 - d_lr: 3.5173e-04 - val_g_loss: 1.6480 - val_d_loss: -1.6393 - val_wass_dist: -3.2225
# Epoch 43/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.8771 - d_loss: -0.8533 - wass_dist: -1.7482 - g_lr: 6.7373e-04 - d_lr: 3.4723e-04 - val_g_loss: 1.7332 - val_d_loss: -1.7385 - val_wass_dist: -4.3687
# Epoch 44/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.9011 - d_loss: -0.8820 - wass_dist: -1.5305 - g_lr: 6.6916e-04 - d_lr: 3.4279e-04 - val_g_loss: 1.4711 - val_d_loss: -1.4757 - val_wass_dist: -3.1096
# Epoch 45/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.9741 - d_loss: -0.9359 - wass_dist: -1.6362 - g_lr: 6.6461e-04 - d_lr: 3.3841e-04 - val_g_loss: 1.6792 - val_d_loss: -1.6687 - val_wass_dist: -6.0601
# Epoch 46/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.9764 - d_loss: -0.9442 - wass_dist: -1.2813 - g_lr: 6.6010e-04 - d_lr: 3.3408e-04 - val_g_loss: 1.3898 - val_d_loss: -1.2908 - val_wass_dist: -3.6615
# Epoch 47/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.9874 - d_loss: -0.9564 - wass_dist: -1.7829 - g_lr: 6.5562e-04 - d_lr: 3.2981e-04 - val_g_loss: 1.7971 - val_d_loss: -1.7558 - val_wass_dist: -3.3502
# Epoch 48/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 1.9921 - d_loss: -0.9658 - wass_dist: -1.8713 - g_lr: 6.5117e-04 - d_lr: 3.2559e-04 - val_g_loss: 1.8969 - val_d_loss: -1.8707 - val_wass_dist: -3.5899
# Epoch 49/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.0214 - d_loss: -0.9893 - wass_dist: -1.3550 - g_lr: 6.4675e-04 - d_lr: 3.2143e-04 - val_g_loss: 1.4145 - val_d_loss: -1.4136 - val_wass_dist: -4.4230
# Epoch 50/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.0347 - d_loss: -1.0031 - wass_dist: -1.7990 - g_lr: 6.4236e-04 - d_lr: 3.1732e-04 - val_g_loss: 1.8554 - val_d_loss: -1.8139 - val_wass_dist: -6.4650
# Epoch 51/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.1327 - d_loss: -1.0674 - wass_dist: -1.6035 - g_lr: 6.3799e-04 - d_lr: 3.1326e-04 - val_g_loss: 1.6856 - val_d_loss: -1.6684 - val_wass_dist: -5.2013
# Epoch 52/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.1566 - d_loss: -1.0884 - wass_dist: -1.9016 - g_lr: 6.3366e-04 - d_lr: 3.0925e-04 - val_g_loss: 1.9399 - val_d_loss: -1.9541 - val_wass_dist: -4.4984
# Epoch 53/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.1945 - d_loss: -1.1165 - wass_dist: -2.1214 - g_lr: 6.2936e-04 - d_lr: 3.0530e-04 - val_g_loss: 2.1615 - val_d_loss: -2.1509 - val_wass_dist: -6.2577
# Epoch 54/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1667 - d_loss: -1.1015 - wass_dist: -1.5393 - g_lr: 6.2509e-04 - d_lr: 3.0140e-04 - val_g_loss: 1.5962 - val_d_loss: -1.5700 - val_wass_dist: 0.4912
# Epoch 55/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1957 - d_loss: -1.1135 - wass_dist: -2.1633 - g_lr: 6.2084e-04 - d_lr: 2.9754e-04 - val_g_loss: 2.3018 - val_d_loss: -2.2548 - val_wass_dist: -5.6510
# Epoch 56/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2066 - d_loss: -1.1170 - wass_dist: -1.6871 - g_lr: 6.1663e-04 - d_lr: 2.9374e-04 - val_g_loss: 1.6299 - val_d_loss: -1.7292 - val_wass_dist: -4.1116
# Epoch 57/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2620 - d_loss: -1.1470 - wass_dist: -1.4409 - g_lr: 6.1244e-04 - d_lr: 2.8998e-04 - val_g_loss: 1.4032 - val_d_loss: -1.4064 - val_wass_dist: -1.5363
# Epoch 58/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2444 - d_loss: -1.1415 - wass_dist: -1.7334 - g_lr: 6.0828e-04 - d_lr: 2.8627e-04 - val_g_loss: 1.6880 - val_d_loss: -1.7045 - val_wass_dist: -4.1997
# Epoch 59/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2471 - d_loss: -1.1444 - wass_dist: -1.9165 - g_lr: 6.0415e-04 - d_lr: 2.8261e-04 - val_g_loss: 1.9672 - val_d_loss: -1.9244 - val_wass_dist: -5.3005
# Epoch 60/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.2504 - d_loss: -1.1461 - wass_dist: -1.8272 - g_lr: 6.0005e-04 - d_lr: 2.7900e-04 - val_g_loss: 1.8419 - val_d_loss: -1.8375 - val_wass_dist: -4.9086
# Epoch 61/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2687 - d_loss: -1.1462 - wass_dist: -1.9857 - g_lr: 5.9598e-04 - d_lr: 2.7543e-04 - val_g_loss: 1.9948 - val_d_loss: -1.9657 - val_wass_dist: -7.0719
# Epoch 62/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2064 - d_loss: -1.1218 - wass_dist: -2.3636 - g_lr: 5.9193e-04 - d_lr: 2.7191e-04 - val_g_loss: 2.3844 - val_d_loss: -2.4135 - val_wass_dist: -6.5167
# Epoch 63/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3016 - d_loss: -1.1735 - wass_dist: -1.9669 - g_lr: 5.8791e-04 - d_lr: 2.6843e-04 - val_g_loss: 2.0044 - val_d_loss: -1.9902 - val_wass_dist: -7.2914
# Epoch 64/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.2543 - d_loss: -1.1646 - wass_dist: -1.5904 - g_lr: 5.8392e-04 - d_lr: 2.6500e-04 - val_g_loss: 1.5974 - val_d_loss: -1.6274 - val_wass_dist: -4.0773
# Epoch 65/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2803 - d_loss: -1.1845 - wass_dist: -1.9449 - g_lr: 5.7995e-04 - d_lr: 2.6161e-04 - val_g_loss: 1.9360 - val_d_loss: -1.9219 - val_wass_dist: -5.0942
# Epoch 66/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.3246 - d_loss: -1.2037 - wass_dist: -2.1514 - g_lr: 5.7602e-04 - d_lr: 2.5827e-04 - val_g_loss: 2.1727 - val_d_loss: -2.1772 - val_wass_dist: -6.6484
# Epoch 67/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3071 - d_loss: -1.1904 - wass_dist: -2.1003 - g_lr: 5.7210e-04 - d_lr: 2.5497e-04 - val_g_loss: 2.1187 - val_d_loss: -2.1379 - val_wass_dist: -8.4104
# Epoch 68/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3020 - d_loss: -1.1873 - wass_dist: -2.0414 - g_lr: 5.6822e-04 - d_lr: 2.5171e-04 - val_g_loss: 1.9565 - val_d_loss: -1.9855 - val_wass_dist: -4.1120
# Epoch 69/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2859 - d_loss: -1.1835 - wass_dist: -2.0872 - g_lr: 5.6436e-04 - d_lr: 2.4849e-04 - val_g_loss: 2.0879 - val_d_loss: -2.1065 - val_wass_dist: -8.5008
# Epoch 70/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.2872 - d_loss: -1.1925 - wass_dist: -2.0137 - g_lr: 5.6053e-04 - d_lr: 2.4531e-04 - val_g_loss: 2.0660 - val_d_loss: -2.0825 - val_wass_dist: -5.1689
# Epoch 71/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3330 - d_loss: -1.2179 - wass_dist: -2.0524 - g_lr: 5.5672e-04 - d_lr: 2.4217e-04 - val_g_loss: 2.1081 - val_d_loss: -2.0988 - val_wass_dist: -7.2198
# Epoch 72/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3305 - d_loss: -1.2162 - wass_dist: -1.9486 - g_lr: 5.5294e-04 - d_lr: 2.3908e-04 - val_g_loss: 2.0050 - val_d_loss: -2.0139 - val_wass_dist: -7.2238
# Epoch 73/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3472 - d_loss: -1.2258 - wass_dist: -2.0073 - g_lr: 5.4919e-04 - d_lr: 2.3602e-04 - val_g_loss: 2.0378 - val_d_loss: -2.0214 - val_wass_dist: -4.8843
# Epoch 74/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3774 - d_loss: -1.2423 - wass_dist: -1.5267 - g_lr: 5.4546e-04 - d_lr: 2.3300e-04 - val_g_loss: 1.5326 - val_d_loss: -1.5059 - val_wass_dist: -1.2889
# Epoch 75/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.4110 - d_loss: -1.2590 - wass_dist: -1.5727 - g_lr: 5.4176e-04 - d_lr: 2.3002e-04 - val_g_loss: 1.5106 - val_d_loss: -1.5288 - val_wass_dist: -6.7557
# Epoch 76/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3933 - d_loss: -1.2510 - wass_dist: -2.0418 - g_lr: 5.3808e-04 - d_lr: 2.2708e-04 - val_g_loss: 2.0877 - val_d_loss: -2.0871 - val_wass_dist: -8.3695
# Epoch 77/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3515 - d_loss: -1.2280 - wass_dist: -1.8943 - g_lr: 5.3443e-04 - d_lr: 2.2418e-04 - val_g_loss: 1.9096 - val_d_loss: -1.9060 - val_wass_dist: -6.2398
# Epoch 78/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3713 - d_loss: -1.2470 - wass_dist: -2.2087 - g_lr: 5.3080e-04 - d_lr: 2.2131e-04 - val_g_loss: 2.1427 - val_d_loss: -2.1661 - val_wass_dist: -7.1616
# Epoch 79/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3471 - d_loss: -1.2338 - wass_dist: -1.9344 - g_lr: 5.2719e-04 - d_lr: 2.1848e-04 - val_g_loss: 1.8855 - val_d_loss: -1.9252 - val_wass_dist: -8.6269
# Epoch 80/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3131 - d_loss: -1.2092 - wass_dist: -1.9416 - g_lr: 5.2361e-04 - d_lr: 2.1569e-04 - val_g_loss: 1.9747 - val_d_loss: -1.9861 - val_wass_dist: -6.7580
# Epoch 81/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2800 - d_loss: -1.2002 - wass_dist: -1.7977 - g_lr: 5.2006e-04 - d_lr: 2.1293e-04 - val_g_loss: 1.7198 - val_d_loss: -1.7500 - val_wass_dist: -4.7919
# Epoch 82/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3805 - d_loss: -1.2455 - wass_dist: -1.9905 - g_lr: 5.1653e-04 - d_lr: 2.1021e-04 - val_g_loss: 2.0080 - val_d_loss: -2.0190 - val_wass_dist: -6.1737
# Epoch 83/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3454 - d_loss: -1.2328 - wass_dist: -2.0323 - g_lr: 5.1302e-04 - d_lr: 2.0752e-04 - val_g_loss: 1.9970 - val_d_loss: -1.9863 - val_wass_dist: -7.5204
# Epoch 84/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3411 - d_loss: -1.2295 - wass_dist: -1.8288 - g_lr: 5.0954e-04 - d_lr: 2.0487e-04 - val_g_loss: 1.8137 - val_d_loss: -1.7825 - val_wass_dist: -5.9364
# Epoch 85/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3952 - d_loss: -1.2623 - wass_dist: -2.2469 - g_lr: 5.0608e-04 - d_lr: 2.0225e-04 - val_g_loss: 2.2342 - val_d_loss: -2.2273 - val_wass_dist: -8.3196
# Epoch 86/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.4019 - d_loss: -1.2628 - wass_dist: -1.6655 - g_lr: 5.0264e-04 - d_lr: 1.9966e-04 - val_g_loss: 1.6696 - val_d_loss: -1.6300 - val_wass_dist: -6.2393
# Epoch 87/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3885 - d_loss: -1.2446 - wass_dist: -2.2595 - g_lr: 4.9923e-04 - d_lr: 1.9711e-04 - val_g_loss: 2.2507 - val_d_loss: -2.2263 - val_wass_dist: -9.2020
# Epoch 88/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.4004 - d_loss: -1.2582 - wass_dist: -2.0047 - g_lr: 4.9584e-04 - d_lr: 1.9459e-04 - val_g_loss: 1.9768 - val_d_loss: -2.0103 - val_wass_dist: -7.0608
# Epoch 89/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3528 - d_loss: -1.2366 - wass_dist: -2.1148 - g_lr: 4.9247e-04 - d_lr: 1.9210e-04 - val_g_loss: 2.0665 - val_d_loss: -2.0680 - val_wass_dist: -8.6764
# Epoch 90/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4247 - d_loss: -1.2691 - wass_dist: -1.9136 - g_lr: 4.8913e-04 - d_lr: 1.8964e-04 - val_g_loss: 1.8725 - val_d_loss: -1.8457 - val_wass_dist: -3.6659
# Epoch 91/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3862 - d_loss: -1.2484 - wass_dist: -2.1414 - g_lr: 4.8581e-04 - d_lr: 1.8722e-04 - val_g_loss: 2.0999 - val_d_loss: -2.0827 - val_wass_dist: -8.8665
# Epoch 92/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3320 - d_loss: -1.2243 - wass_dist: -2.0428 - g_lr: 4.8251e-04 - d_lr: 1.8482e-04 - val_g_loss: 1.9507 - val_d_loss: -1.9424 - val_wass_dist: -7.4038
# Epoch 93/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4582 - d_loss: -1.2864 - wass_dist: -2.2054 - g_lr: 4.7923e-04 - d_lr: 1.8246e-04 - val_g_loss: 2.1532 - val_d_loss: -2.1584 - val_wass_dist: -8.4509
# Epoch 94/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4004 - d_loss: -1.2632 - wass_dist: -2.0888 - g_lr: 4.7598e-04 - d_lr: 1.8013e-04 - val_g_loss: 2.0410 - val_d_loss: -2.0554 - val_wass_dist: -7.0826
# Epoch 95/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3297 - d_loss: -1.2260 - wass_dist: -1.9973 - g_lr: 4.7275e-04 - d_lr: 1.7783e-04 - val_g_loss: 1.9006 - val_d_loss: -1.9443 - val_wass_dist: -6.0420
# Epoch 96/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3193 - d_loss: -1.2197 - wass_dist: -1.6611 - g_lr: 4.6954e-04 - d_lr: 1.7555e-04 - val_g_loss: 1.6383 - val_d_loss: -1.6187 - val_wass_dist: -7.4426
# Epoch 97/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.3681 - d_loss: -1.2391 - wass_dist: -2.1925 - g_lr: 4.6635e-04 - d_lr: 1.7331e-04 - val_g_loss: 2.0794 - val_d_loss: -2.1012 - val_wass_dist: -6.6263
# Epoch 98/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3801 - d_loss: -1.2450 - wass_dist: -2.1203 - g_lr: 4.6318e-04 - d_lr: 1.7109e-04 - val_g_loss: 2.0548 - val_d_loss: -2.0428 - val_wass_dist: -9.2353
# Epoch 99/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3688 - d_loss: -1.2417 - wass_dist: -2.1626 - g_lr: 4.6004e-04 - d_lr: 1.6890e-04 - val_g_loss: 2.1575 - val_d_loss: -2.1131 - val_wass_dist: -5.8117
# Epoch 100/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2919 - d_loss: -1.2037 - wass_dist: -2.0058 - g_lr: 4.5691e-04 - d_lr: 1.6674e-04 - val_g_loss: 1.9654 - val_d_loss: -1.9375 - val_wass_dist: -6.9588
# Epoch 101/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3302 - d_loss: -1.2216 - wass_dist: -2.1375 - g_lr: 4.5381e-04 - d_lr: 1.6461e-04 - val_g_loss: 2.0812 - val_d_loss: -2.0536 - val_wass_dist: -8.9169
# Epoch 102/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.4025 - d_loss: -1.2543 - wass_dist: -2.1606 - g_lr: 4.5073e-04 - d_lr: 1.6251e-04 - val_g_loss: 2.0988 - val_d_loss: -2.1106 - val_wass_dist: -5.7300
# Epoch 103/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4181 - d_loss: -1.2727 - wass_dist: -2.0569 - g_lr: 4.4767e-04 - d_lr: 1.6043e-04 - val_g_loss: 2.0568 - val_d_loss: -2.0257 - val_wass_dist: -7.0717
# Epoch 104/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.4488 - d_loss: -1.2792 - wass_dist: -2.2698 - g_lr: 4.4463e-04 - d_lr: 1.5838e-04 - val_g_loss: 2.2523 - val_d_loss: -2.2503 - val_wass_dist: -7.5734
# Epoch 105/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4572 - d_loss: -1.2810 - wass_dist: -2.1289 - g_lr: 4.4161e-04 - d_lr: 1.5635e-04 - val_g_loss: 2.1041 - val_d_loss: -2.1081 - val_wass_dist: -6.5965
# Epoch 106/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3351 - d_loss: -1.2304 - wass_dist: -2.2034 - g_lr: 4.3861e-04 - d_lr: 1.5435e-04 - val_g_loss: 2.1806 - val_d_loss: -2.1441 - val_wass_dist: -6.3106
# Epoch 107/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3589 - d_loss: -1.2369 - wass_dist: -1.9641 - g_lr: 4.3563e-04 - d_lr: 1.5238e-04 - val_g_loss: 1.8745 - val_d_loss: -1.9020 - val_wass_dist: -6.6878
# Epoch 108/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3368 - d_loss: -1.2248 - wass_dist: -1.9379 - g_lr: 4.3268e-04 - d_lr: 1.5043e-04 - val_g_loss: 1.8748 - val_d_loss: -1.8678 - val_wass_dist: -2.6995
# Epoch 109/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.3778 - d_loss: -1.2461 - wass_dist: -2.1375 - g_lr: 4.2974e-04 - d_lr: 1.4851e-04 - val_g_loss: 2.0887 - val_d_loss: -2.1486 - val_wass_dist: -5.7590
# Epoch 110/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.4269 - d_loss: -1.2616 - wass_dist: -2.2492 - g_lr: 4.2682e-04 - d_lr: 1.4661e-04 - val_g_loss: 2.1763 - val_d_loss: -2.1904 - val_wass_dist: -7.7401
# Epoch 111/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.4269 - d_loss: -1.2640 - wass_dist: -2.1481 - g_lr: 4.2392e-04 - d_lr: 1.4473e-04 - val_g_loss: 2.1124 - val_d_loss: -2.0839 - val_wass_dist: -7.7167
# Epoch 112/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.4215 - d_loss: -1.2554 - wass_dist: -2.1694 - g_lr: 4.2105e-04 - d_lr: 1.4288e-04 - val_g_loss: 2.1406 - val_d_loss: -2.1285 - val_wass_dist: -6.9212
# Epoch 113/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3929 - d_loss: -1.2459 - wass_dist: -2.0717 - g_lr: 4.1819e-04 - d_lr: 1.4106e-04 - val_g_loss: 2.0091 - val_d_loss: -2.0224 - val_wass_dist: -6.4148
# Epoch 114/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3113 - d_loss: -1.2169 - wass_dist: -1.8539 - g_lr: 4.1535e-04 - d_lr: 1.3925e-04 - val_g_loss: 1.8047 - val_d_loss: -1.7998 - val_wass_dist: -2.5891
# Epoch 115/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3827 - d_loss: -1.2436 - wass_dist: -2.3265 - g_lr: 4.1253e-04 - d_lr: 1.3747e-04 - val_g_loss: 2.2871 - val_d_loss: -2.2899 - val_wass_dist: -6.8805
# Epoch 116/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3615 - d_loss: -1.2424 - wass_dist: -2.0174 - g_lr: 4.0973e-04 - d_lr: 1.3571e-04 - val_g_loss: 1.9952 - val_d_loss: -1.9513 - val_wass_dist: -5.3112
# Epoch 117/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2793 - d_loss: -1.2038 - wass_dist: -2.0958 - g_lr: 4.0694e-04 - d_lr: 1.3398e-04 - val_g_loss: 2.0521 - val_d_loss: -2.0309 - val_wass_dist: -4.6693
# Epoch 118/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3405 - d_loss: -1.2306 - wass_dist: -2.1610 - g_lr: 4.0418e-04 - d_lr: 1.3227e-04 - val_g_loss: 2.1128 - val_d_loss: -2.1087 - val_wass_dist: -8.5472
# Epoch 119/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3760 - d_loss: -1.2402 - wass_dist: -2.0109 - g_lr: 4.0144e-04 - d_lr: 1.3057e-04 - val_g_loss: 1.9608 - val_d_loss: -1.9684 - val_wass_dist: -7.8313
# Epoch 120/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3913 - d_loss: -1.2387 - wass_dist: -2.0588 - g_lr: 3.9871e-04 - d_lr: 1.2891e-04 - val_g_loss: 2.0017 - val_d_loss: -2.0076 - val_wass_dist: -5.9273
# Epoch 121/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3973 - d_loss: -1.2328 - wass_dist: -2.0933 - g_lr: 3.9600e-04 - d_lr: 1.2726e-04 - val_g_loss: 2.0226 - val_d_loss: -2.0289 - val_wass_dist: -6.4277
# Epoch 122/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3008 - d_loss: -1.2028 - wass_dist: -2.1373 - g_lr: 3.9331e-04 - d_lr: 1.2563e-04 - val_g_loss: 2.0920 - val_d_loss: -2.0927 - val_wass_dist: -4.7243
# Epoch 123/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3545 - d_loss: -1.2204 - wass_dist: -2.0607 - g_lr: 3.9064e-04 - d_lr: 1.2402e-04 - val_g_loss: 2.0114 - val_d_loss: -2.0547 - val_wass_dist: -7.1948
# Epoch 124/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3575 - d_loss: -1.2165 - wass_dist: -1.9939 - g_lr: 3.8799e-04 - d_lr: 1.2244e-04 - val_g_loss: 1.9061 - val_d_loss: -1.9347 - val_wass_dist: -5.5940
# Epoch 125/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3715 - d_loss: -1.2346 - wass_dist: -2.1310 - g_lr: 3.8536e-04 - d_lr: 1.2087e-04 - val_g_loss: 2.0790 - val_d_loss: -2.0975 - val_wass_dist: -5.8329
# Epoch 126/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3901 - d_loss: -1.2467 - wass_dist: -2.1120 - g_lr: 3.8274e-04 - d_lr: 1.1933e-04 - val_g_loss: 2.0841 - val_d_loss: -2.0851 - val_wass_dist: -6.8965
# Epoch 127/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3954 - d_loss: -1.2442 - wass_dist: -2.1267 - g_lr: 3.8014e-04 - d_lr: 1.1780e-04 - val_g_loss: 2.0803 - val_d_loss: -2.0568 - val_wass_dist: -5.9020
# Epoch 128/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3307 - d_loss: -1.2199 - wass_dist: -1.8899 - g_lr: 3.7756e-04 - d_lr: 1.1629e-04 - val_g_loss: 1.8126 - val_d_loss: -1.8097 - val_wass_dist: -5.6877
# Epoch 129/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3829 - d_loss: -1.2424 - wass_dist: -2.1487 - g_lr: 3.7500e-04 - d_lr: 1.1481e-04 - val_g_loss: 2.0611 - val_d_loss: -2.0559 - val_wass_dist: -6.1702
# Epoch 130/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.3940 - d_loss: -1.2451 - wass_dist: -2.1624 - g_lr: 3.7245e-04 - d_lr: 1.1334e-04 - val_g_loss: 2.0776 - val_d_loss: -2.0894 - val_wass_dist: -5.0792
# Epoch 131/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3811 - d_loss: -1.2333 - wass_dist: -2.0836 - g_lr: 3.6992e-04 - d_lr: 1.1189e-04 - val_g_loss: 2.0346 - val_d_loss: -2.0424 - val_wass_dist: -3.9369
# Epoch 132/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3899 - d_loss: -1.2353 - wass_dist: -2.1406 - g_lr: 3.6741e-04 - d_lr: 1.1046e-04 - val_g_loss: 2.0719 - val_d_loss: -2.0814 - val_wass_dist: -5.4386
# Epoch 133/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3873 - d_loss: -1.2367 - wass_dist: -2.0642 - g_lr: 3.6492e-04 - d_lr: 1.0905e-04 - val_g_loss: 2.0060 - val_d_loss: -1.9989 - val_wass_dist: -5.3658
# Epoch 134/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2926 - d_loss: -1.1989 - wass_dist: -1.9971 - g_lr: 3.6244e-04 - d_lr: 1.0765e-04 - val_g_loss: 1.9332 - val_d_loss: -1.8996 - val_wass_dist: -4.0251
# Epoch 135/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3671 - d_loss: -1.2263 - wass_dist: -2.0849 - g_lr: 3.5998e-04 - d_lr: 1.0628e-04 - val_g_loss: 2.0196 - val_d_loss: -2.0379 - val_wass_dist: -5.4704
# Epoch 136/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3471 - d_loss: -1.2155 - wass_dist: -2.0662 - g_lr: 3.5753e-04 - d_lr: 1.0492e-04 - val_g_loss: 1.9847 - val_d_loss: -1.9763 - val_wass_dist: -3.8631
# Epoch 137/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3307 - d_loss: -1.2114 - wass_dist: -2.0266 - g_lr: 3.5511e-04 - d_lr: 1.0358e-04 - val_g_loss: 1.9419 - val_d_loss: -1.9707 - val_wass_dist: -4.9668
# Epoch 138/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2361 - d_loss: -1.1809 - wass_dist: -1.8082 - g_lr: 3.5269e-04 - d_lr: 1.0225e-04 - val_g_loss: 1.7390 - val_d_loss: -1.7037 - val_wass_dist: -3.2506
# Epoch 139/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.1854 - d_loss: -1.1590 - wass_dist: -1.9280 - g_lr: 3.5030e-04 - d_lr: 1.0094e-04 - val_g_loss: 1.8895 - val_d_loss: -1.8751 - val_wass_dist: -4.4157
# Epoch 140/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1705 - d_loss: -1.1475 - wass_dist: -1.7735 - g_lr: 3.4792e-04 - d_lr: 9.9654e-05 - val_g_loss: 1.6994 - val_d_loss: -1.6976 - val_wass_dist: -5.9994
# Epoch 141/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.2276 - d_loss: -1.1711 - wass_dist: -2.0663 - g_lr: 3.4556e-04 - d_lr: 9.8379e-05 - val_g_loss: 1.9828 - val_d_loss: -1.9861 - val_wass_dist: -6.4479
# Epoch 142/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3432 - d_loss: -1.2206 - wass_dist: -2.1370 - g_lr: 3.4321e-04 - d_lr: 9.7122e-05 - val_g_loss: 2.0542 - val_d_loss: -2.0445 - val_wass_dist: -4.8113
# Epoch 143/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3073 - d_loss: -1.2038 - wass_dist: -2.0452 - g_lr: 3.4088e-04 - d_lr: 9.5880e-05 - val_g_loss: 1.9285 - val_d_loss: -1.9403 - val_wass_dist: -4.3158
# Epoch 144/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3688 - d_loss: -1.2280 - wass_dist: -2.0571 - g_lr: 3.3857e-04 - d_lr: 9.4654e-05 - val_g_loss: 1.9692 - val_d_loss: -1.9548 - val_wass_dist: -5.9040
# Epoch 145/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3306 - d_loss: -1.2147 - wass_dist: -2.0621 - g_lr: 3.3627e-04 - d_lr: 9.3443e-05 - val_g_loss: 1.9615 - val_d_loss: -1.9520 - val_wass_dist: -3.1802
# Epoch 146/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3187 - d_loss: -1.2082 - wass_dist: -2.0858 - g_lr: 3.3399e-04 - d_lr: 9.2249e-05 - val_g_loss: 1.9970 - val_d_loss: -1.9998 - val_wass_dist: -7.1361
# Epoch 147/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3223 - d_loss: -1.2091 - wass_dist: -2.1019 - g_lr: 3.3172e-04 - d_lr: 9.1069e-05 - val_g_loss: 1.9892 - val_d_loss: -1.9935 - val_wass_dist: -3.9351
# Epoch 148/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3249 - d_loss: -1.2084 - wass_dist: -2.0918 - g_lr: 3.2947e-04 - d_lr: 8.9905e-05 - val_g_loss: 1.9925 - val_d_loss: -1.9931 - val_wass_dist: -5.7335
# Epoch 149/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3384 - d_loss: -1.2128 - wass_dist: -2.1301 - g_lr: 3.2723e-04 - d_lr: 8.8755e-05 - val_g_loss: 2.0522 - val_d_loss: -2.0397 - val_wass_dist: -6.3180
# Epoch 150/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3403 - d_loss: -1.2193 - wass_dist: -1.9822 - g_lr: 3.2501e-04 - d_lr: 8.7620e-05 - val_g_loss: 1.8942 - val_d_loss: -1.8799 - val_wass_dist: -5.1511
# Epoch 151/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3044 - d_loss: -1.2127 - wass_dist: -2.0020 - g_lr: 3.2280e-04 - d_lr: 8.6500e-05 - val_g_loss: 1.9540 - val_d_loss: -1.9532 - val_wass_dist: -5.4164
# Epoch 152/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.2543 - d_loss: -1.1956 - wass_dist: -2.0454 - g_lr: 3.2061e-04 - d_lr: 8.5394e-05 - val_g_loss: 1.9601 - val_d_loss: -1.9619 - val_wass_dist: -4.8282
# Epoch 153/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3334 - d_loss: -1.2227 - wass_dist: -2.0693 - g_lr: 3.1843e-04 - d_lr: 8.4302e-05 - val_g_loss: 1.9719 - val_d_loss: -1.9747 - val_wass_dist: -3.8389
# Epoch 154/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3249 - d_loss: -1.2169 - wass_dist: -2.1496 - g_lr: 3.1627e-04 - d_lr: 8.3224e-05 - val_g_loss: 2.0427 - val_d_loss: -2.0447 - val_wass_dist: -5.1599
# Epoch 155/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3178 - d_loss: -1.2144 - wass_dist: -2.0340 - g_lr: 3.1412e-04 - d_lr: 8.2160e-05 - val_g_loss: 1.9801 - val_d_loss: -1.9704 - val_wass_dist: -5.2597
# Epoch 156/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3208 - d_loss: -1.2105 - wass_dist: -2.0116 - g_lr: 3.1199e-04 - d_lr: 8.1109e-05 - val_g_loss: 1.9224 - val_d_loss: -1.9317 - val_wass_dist: -5.2418
# Epoch 157/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3043 - d_loss: -1.2022 - wass_dist: -2.0641 - g_lr: 3.0987e-04 - d_lr: 8.0072e-05 - val_g_loss: 1.9593 - val_d_loss: -1.9770 - val_wass_dist: -5.0987
# Epoch 158/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2851 - d_loss: -1.1952 - wass_dist: -1.9822 - g_lr: 3.0777e-04 - d_lr: 7.9048e-05 - val_g_loss: 1.8793 - val_d_loss: -1.9062 - val_wass_dist: -4.4910
# Epoch 159/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3033 - d_loss: -1.2001 - wass_dist: -2.1186 - g_lr: 3.0568e-04 - d_lr: 7.8038e-05 - val_g_loss: 2.0424 - val_d_loss: -2.0514 - val_wass_dist: -5.8175
# Epoch 160/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.3002 - d_loss: -1.1988 - wass_dist: -2.0641 - g_lr: 3.0360e-04 - d_lr: 7.7040e-05 - val_g_loss: 1.9714 - val_d_loss: -1.9747 - val_wass_dist: -5.6221
# Epoch 161/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.3027 - d_loss: -1.1996 - wass_dist: -2.0202 - g_lr: 3.0154e-04 - d_lr: 7.6055e-05 - val_g_loss: 1.9560 - val_d_loss: -1.9426 - val_wass_dist: -6.1461
# Epoch 162/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.3041 - d_loss: -1.1967 - wass_dist: -2.0142 - g_lr: 2.9949e-04 - d_lr: 7.5082e-05 - val_g_loss: 1.9243 - val_d_loss: -1.9316 - val_wass_dist: -5.7985
# Epoch 163/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2652 - d_loss: -1.1774 - wass_dist: -1.9410 - g_lr: 2.9746e-04 - d_lr: 7.4122e-05 - val_g_loss: 1.8606 - val_d_loss: -1.8415 - val_wass_dist: -4.8018
# Epoch 164/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.0928 - d_loss: -1.1136 - wass_dist: -1.6764 - g_lr: 2.9544e-04 - d_lr: 7.3175e-05 - val_g_loss: 1.6014 - val_d_loss: -1.6090 - val_wass_dist: -2.9304
# Epoch 165/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.9490 - d_loss: -1.0525 - wass_dist: -1.7793 - g_lr: 2.9343e-04 - d_lr: 7.2239e-05 - val_g_loss: 1.6807 - val_d_loss: -1.6383 - val_wass_dist: -4.1283
# Epoch 166/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.0444 - d_loss: -1.0892 - wass_dist: -1.7714 - g_lr: 2.9144e-04 - d_lr: 7.1315e-05 - val_g_loss: 1.7264 - val_d_loss: -1.6658 - val_wass_dist: -6.4567
# Epoch 167/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.0851 - d_loss: -1.1077 - wass_dist: -1.8941 - g_lr: 2.8946e-04 - d_lr: 7.0403e-05 - val_g_loss: 1.8451 - val_d_loss: -1.8474 - val_wass_dist: -5.7003
# Epoch 168/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.0640 - d_loss: -1.0959 - wass_dist: -1.8203 - g_lr: 2.8750e-04 - d_lr: 6.9503e-05 - val_g_loss: 1.7011 - val_d_loss: -1.6491 - val_wass_dist: -5.5040
# Epoch 169/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0414 - d_loss: -1.0901 - wass_dist: -1.8129 - g_lr: 2.8555e-04 - d_lr: 6.8614e-05 - val_g_loss: 1.7420 - val_d_loss: -1.7219 - val_wass_dist: -6.7946
# Epoch 170/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.0336 - d_loss: -1.0819 - wass_dist: -1.8292 - g_lr: 2.8361e-04 - d_lr: 6.7737e-05 - val_g_loss: 1.7964 - val_d_loss: -1.7659 - val_wass_dist: -7.6994
# Epoch 171/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0588 - d_loss: -1.0951 - wass_dist: -1.8675 - g_lr: 2.8168e-04 - d_lr: 6.6871e-05 - val_g_loss: 1.7856 - val_d_loss: -1.7682 - val_wass_dist: -7.2906
# Epoch 172/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1152 - d_loss: -1.1205 - wass_dist: -1.7760 - g_lr: 2.7977e-04 - d_lr: 6.6016e-05 - val_g_loss: 1.6553 - val_d_loss: -1.6918 - val_wass_dist: -5.1816
# Epoch 173/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0386 - d_loss: -1.0889 - wass_dist: -1.9781 - g_lr: 2.7787e-04 - d_lr: 6.5172e-05 - val_g_loss: 1.9091 - val_d_loss: -1.9063 - val_wass_dist: -5.8459
# Epoch 174/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1976 - d_loss: -1.1564 - wass_dist: -1.7051 - g_lr: 2.7598e-04 - d_lr: 6.4339e-05 - val_g_loss: 1.6122 - val_d_loss: -1.6350 - val_wass_dist: -3.2518
# Epoch 175/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0513 - d_loss: -1.0986 - wass_dist: -1.8513 - g_lr: 2.7411e-04 - d_lr: 6.3516e-05 - val_g_loss: 1.7209 - val_d_loss: -1.7378 - val_wass_dist: -5.1146
# Epoch 176/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.1671 - d_loss: -1.1433 - wass_dist: -1.9278 - g_lr: 2.7225e-04 - d_lr: 6.2704e-05 - val_g_loss: 1.8073 - val_d_loss: -1.8287 - val_wass_dist: -5.9888
# Epoch 177/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1274 - d_loss: -1.1307 - wass_dist: -1.7371 - g_lr: 2.7040e-04 - d_lr: 6.1902e-05 - val_g_loss: 1.5984 - val_d_loss: -1.5751 - val_wass_dist: -5.7702
# Epoch 178/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.1595 - d_loss: -1.1411 - wass_dist: -2.0274 - g_lr: 2.6856e-04 - d_lr: 6.1110e-05 - val_g_loss: 1.9584 - val_d_loss: -1.9505 - val_wass_dist: -7.1840
# Epoch 179/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.2415 - d_loss: -1.1716 - wass_dist: -2.0312 - g_lr: 2.6674e-04 - d_lr: 6.0329e-05 - val_g_loss: 1.9721 - val_d_loss: -1.9601 - val_wass_dist: -6.2994
# Epoch 180/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.2079 - d_loss: -1.1604 - wass_dist: -2.0383 - g_lr: 2.6493e-04 - d_lr: 5.9558e-05 - val_g_loss: 1.9734 - val_d_loss: -1.9703 - val_wass_dist: -6.6825
# Epoch 181/1000
# 503/503 [==============================] - 11s 21ms/step - g_loss: 2.1197 - d_loss: -1.1276 - wass_dist: -1.8406 - g_lr: 2.6313e-04 - d_lr: 5.8796e-05 - val_g_loss: 1.7573 - val_d_loss: -1.7155 - val_wass_dist: -4.0369
# Epoch 182/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1047 - d_loss: -1.1192 - wass_dist: -1.9859 - g_lr: 2.6134e-04 - d_lr: 5.8044e-05 - val_g_loss: 1.8728 - val_d_loss: -1.8774 - val_wass_dist: -6.2800
# Epoch 183/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.2474 - d_loss: -1.1725 - wass_dist: -1.9874 - g_lr: 2.5957e-04 - d_lr: 5.7302e-05 - val_g_loss: 1.9297 - val_d_loss: -1.9266 - val_wass_dist: -7.1855
# Epoch 184/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1959 - d_loss: -1.1513 - wass_dist: -2.0199 - g_lr: 2.5781e-04 - d_lr: 5.6569e-05 - val_g_loss: 1.8901 - val_d_loss: -1.9308 - val_wass_dist: -4.9086
# Epoch 185/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.1284 - d_loss: -1.1271 - wass_dist: -2.0147 - g_lr: 2.5606e-04 - d_lr: 5.5846e-05 - val_g_loss: 1.9076 - val_d_loss: -1.9204 - val_wass_dist: -5.0858
# Epoch 186/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0642 - d_loss: -1.1010 - wass_dist: -1.9558 - g_lr: 2.5432e-04 - d_lr: 5.5132e-05 - val_g_loss: 1.8215 - val_d_loss: -1.8624 - val_wass_dist: -5.9326
# Epoch 187/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1464 - d_loss: -1.1316 - wass_dist: -1.8739 - g_lr: 2.5259e-04 - d_lr: 5.4427e-05 - val_g_loss: 1.7871 - val_d_loss: -1.7868 - val_wass_dist: -3.6548
# Epoch 188/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1866 - d_loss: -1.1458 - wass_dist: -1.9689 - g_lr: 2.5088e-04 - d_lr: 5.3731e-05 - val_g_loss: 1.8827 - val_d_loss: -1.8728 - val_wass_dist: -5.6381
# Epoch 189/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0419 - d_loss: -1.0896 - wass_dist: -1.6529 - g_lr: 2.4917e-04 - d_lr: 5.3044e-05 - val_g_loss: 1.5509 - val_d_loss: -1.5554 - val_wass_dist: -4.2673
# Epoch 190/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.0208 - d_loss: -1.0807 - wass_dist: -1.9839 - g_lr: 2.4748e-04 - d_lr: 5.2366e-05 - val_g_loss: 1.8588 - val_d_loss: -1.8441 - val_wass_dist: -6.5954
# Epoch 191/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 2.2176 - d_loss: -1.1569 - wass_dist: -2.0765 - g_lr: 2.4580e-04 - d_lr: 5.1696e-05 - val_g_loss: 1.9376 - val_d_loss: -1.9386 - val_wass_dist: -5.7011
# Epoch 192/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.2362 - d_loss: -1.1653 - wass_dist: -2.0679 - g_lr: 2.4413e-04 - d_lr: 5.1035e-05 - val_g_loss: 1.9941 - val_d_loss: -1.9795 - val_wass_dist: -6.8141
# Epoch 193/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 2.1980 - d_loss: -1.1506 - wass_dist: -1.8789 - g_lr: 2.4247e-04 - d_lr: 5.0383e-05 - val_g_loss: 1.7287 - val_d_loss: -1.7268 - val_wass_dist: -4.5463
# Epoch 194/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 2.1188 - d_loss: -1.1199 - wass_dist: -1.9829 - g_lr: 2.4083e-04 - d_lr: 4.9739e-05 - val_g_loss: 1.9035 - val_d_loss: -1.9012 - val_wass_dist: -6.6182
# Epoch 195/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.1248 - d_loss: -1.1205 - wass_dist: -1.8593 - g_lr: 2.3919e-04 - d_lr: 4.9103e-05 - val_g_loss: 1.7788 - val_d_loss: -1.7597 - val_wass_dist: -5.7273
# Epoch 196/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.1202 - d_loss: -1.1208 - wass_dist: -1.8426 - g_lr: 2.3757e-04 - d_lr: 4.8475e-05 - val_g_loss: 1.7176 - val_d_loss: -1.7261 - val_wass_dist: -4.0638
# Epoch 197/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.9799 - d_loss: -1.0677 - wass_dist: -1.8241 - g_lr: 2.3595e-04 - d_lr: 4.7855e-05 - val_g_loss: 1.7128 - val_d_loss: -1.7019 - val_wass_dist: -5.4071
# Epoch 198/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 2.1336 - d_loss: -1.1260 - wass_dist: -1.9828 - g_lr: 2.3435e-04 - d_lr: 4.7243e-05 - val_g_loss: 1.8857 - val_d_loss: -1.8814 - val_wass_dist: -6.2660
# Epoch 199/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.1295 - d_loss: -1.1230 - wass_dist: -1.7826 - g_lr: 2.3276e-04 - d_lr: 4.6639e-05 - val_g_loss: 1.6530 - val_d_loss: -1.6543 - val_wass_dist: -4.4875
# Epoch 200/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 1.9785 - d_loss: -1.0651 - wass_dist: -1.7250 - g_lr: 2.3118e-04 - d_lr: 4.6043e-05 - val_g_loss: 1.6155 - val_d_loss: -1.5523 - val_wass_dist: -4.0074
# Epoch 201/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.9862 - d_loss: -1.0649 - wass_dist: -1.7463 - g_lr: 2.2961e-04 - d_lr: 4.5454e-05 - val_g_loss: 1.5385 - val_d_loss: -1.5660 - val_wass_dist: -3.8246
# Epoch 202/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 2.0488 - d_loss: -1.0899 - wass_dist: -1.7033 - g_lr: 2.2805e-04 - d_lr: 4.4873e-05 - val_g_loss: 1.6162 - val_d_loss: -1.5784 - val_wass_dist: -4.7248
# Epoch 203/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 1.9321 - d_loss: -1.0385 - wass_dist: -1.6714 - g_lr: 2.2650e-04 - d_lr: 4.4299e-05 - val_g_loss: 1.6745 - val_d_loss: -1.6198 - val_wass_dist: -5.7581
# Epoch 204/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 1.8653 - d_loss: -1.0119 - wass_dist: -1.7225 - g_lr: 2.2497e-04 - d_lr: 4.3732e-05 - val_g_loss: 1.6725 - val_d_loss: -1.7116 - val_wass_dist: -6.9096
# Epoch 205/1000
# ...
# Epoch 933/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2076 - d_loss: -0.1454 - wass_dist: -0.1437 - g_lr: 1.5672e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0706 - val_d_loss: -0.1400 - val_wass_dist: 0.1123
# Epoch 934/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2088 - d_loss: -0.1495 - wass_dist: -0.1594 - g_lr: 1.5566e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1428 - val_d_loss: -0.0754 - val_wass_dist: -0.6673
# Epoch 935/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2106 - d_loss: -0.1490 - wass_dist: -0.1618 - g_lr: 1.5460e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1075 - val_d_loss: -0.1478 - val_wass_dist: 0.0907
# Epoch 936/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2109 - d_loss: -0.1474 - wass_dist: -0.1461 - g_lr: 1.5355e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1230 - val_d_loss: -0.1140 - val_wass_dist: -0.2066
# Epoch 937/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2108 - d_loss: -0.1476 - wass_dist: -0.1560 - g_lr: 1.5251e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0890 - val_d_loss: -0.1439 - val_wass_dist: 0.0891
# Epoch 938/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2090 - d_loss: -0.1477 - wass_dist: -0.1689 - g_lr: 1.5147e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1117 - val_d_loss: -0.1166 - val_wass_dist: -0.2092
# Epoch 939/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2062 - d_loss: -0.1458 - wass_dist: -0.1565 - g_lr: 1.5045e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0922 - val_d_loss: -0.0976 - val_wass_dist: -0.0178
# Epoch 940/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2067 - d_loss: -0.1483 - wass_dist: -0.1566 - g_lr: 1.4942e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1059 - val_d_loss: -0.1104 - val_wass_dist: 0.1073
# Epoch 941/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2065 - d_loss: -0.1467 - wass_dist: -0.1588 - g_lr: 1.4841e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0633 - val_d_loss: -0.1181 - val_wass_dist: -0.1862
# Epoch 942/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2100 - d_loss: -0.1483 - wass_dist: -0.1868 - g_lr: 1.4740e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1160 - val_d_loss: -0.1287 - val_wass_dist: -0.1788
# Epoch 943/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2106 - d_loss: -0.1487 - wass_dist: -0.1281 - g_lr: 1.4640e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1087 - val_d_loss: -0.1502 - val_wass_dist: -0.3293
# Epoch 944/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2094 - d_loss: -0.1488 - wass_dist: -0.1406 - g_lr: 1.4541e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1277 - val_d_loss: -0.1035 - val_wass_dist: 0.2064
# Epoch 945/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2074 - d_loss: -0.1504 - wass_dist: -0.1554 - g_lr: 1.4442e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1118 - val_d_loss: -0.1241 - val_wass_dist: -0.2450
# Epoch 946/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2092 - d_loss: -0.1493 - wass_dist: -0.1458 - g_lr: 1.4344e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1384 - val_d_loss: -0.0604 - val_wass_dist: -0.4920
# Epoch 947/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2092 - d_loss: -0.1464 - wass_dist: -0.1499 - g_lr: 1.4247e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1352 - val_d_loss: -0.0825 - val_wass_dist: -0.0280
# Epoch 948/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2073 - d_loss: -0.1467 - wass_dist: -0.1678 - g_lr: 1.4150e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1242 - val_d_loss: -0.1427 - val_wass_dist: 0.2790
# Epoch 949/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2062 - d_loss: -0.1485 - wass_dist: -0.1562 - g_lr: 1.4054e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1266 - val_d_loss: -0.0873 - val_wass_dist: 0.4568
# Epoch 950/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2078 - d_loss: -0.1469 - wass_dist: -0.1607 - g_lr: 1.3958e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1081 - val_d_loss: -0.1312 - val_wass_dist: 0.2109
# Epoch 951/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2067 - d_loss: -0.1489 - wass_dist: -0.1959 - g_lr: 1.3864e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1330 - val_d_loss: -0.1323 - val_wass_dist: -0.1043
# Epoch 952/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2131 - d_loss: -0.1500 - wass_dist: -0.1925 - g_lr: 1.3769e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0779 - val_d_loss: -0.0893 - val_wass_dist: -0.0365
# Epoch 953/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2103 - d_loss: -0.1472 - wass_dist: -0.1751 - g_lr: 1.3676e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1276 - val_d_loss: -0.1391 - val_wass_dist: 0.2703
# Epoch 954/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2080 - d_loss: -0.1494 - wass_dist: -0.1552 - g_lr: 1.3583e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1048 - val_d_loss: -0.0565 - val_wass_dist: 0.2870
# Epoch 955/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2092 - d_loss: -0.1503 - wass_dist: -0.1613 - g_lr: 1.3491e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1513 - val_d_loss: -0.0564 - val_wass_dist: 0.1048
# Epoch 956/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2089 - d_loss: -0.1495 - wass_dist: -0.1545 - g_lr: 1.3399e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0700 - val_d_loss: -0.1329 - val_wass_dist: -0.0022
# Epoch 957/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2090 - d_loss: -0.1503 - wass_dist: -0.1711 - g_lr: 1.3308e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0972 - val_d_loss: -0.1109 - val_wass_dist: 0.1616
# Epoch 958/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2068 - d_loss: -0.1489 - wass_dist: -0.1571 - g_lr: 1.3218e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0942 - val_d_loss: -0.1170 - val_wass_dist: -0.2594
# Epoch 959/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2123 - d_loss: -0.1511 - wass_dist: -0.1772 - g_lr: 1.3128e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1212 - val_d_loss: -0.0917 - val_wass_dist: -0.2763
# Epoch 960/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2076 - d_loss: -0.1474 - wass_dist: -0.1548 - g_lr: 1.3039e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1158 - val_d_loss: -0.1237 - val_wass_dist: -0.1021
# Epoch 961/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2117 - d_loss: -0.1514 - wass_dist: -0.1579 - g_lr: 1.2951e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1171 - val_d_loss: -0.0692 - val_wass_dist: 0.5179
# Epoch 962/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2132 - d_loss: -0.1523 - wass_dist: -0.1849 - g_lr: 1.2863e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0975 - val_d_loss: -0.1290 - val_wass_dist: -0.2065
# Epoch 963/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2096 - d_loss: -0.1522 - wass_dist: -0.1545 - g_lr: 1.2775e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0728 - val_d_loss: -0.1424 - val_wass_dist: -0.1290
# Epoch 964/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2127 - d_loss: -0.1516 - wass_dist: -0.1882 - g_lr: 1.2689e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1097 - val_d_loss: -0.0843 - val_wass_dist: -0.2698
# Epoch 965/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2150 - d_loss: -0.1546 - wass_dist: -0.1811 - g_lr: 1.2602e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1438 - val_d_loss: -0.1045 - val_wass_dist: -0.2519
# Epoch 966/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2162 - d_loss: -0.1528 - wass_dist: -0.1911 - g_lr: 1.2517e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1277 - val_d_loss: -0.1470 - val_wass_dist: -0.1736
# Epoch 967/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2147 - d_loss: -0.1559 - wass_dist: -0.1337 - g_lr: 1.2432e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0988 - val_d_loss: -0.1144 - val_wass_dist: 0.4501
# Epoch 968/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2145 - d_loss: -0.1544 - wass_dist: -0.1658 - g_lr: 1.2347e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1191 - val_d_loss: -0.1254 - val_wass_dist: 0.0363
# Epoch 969/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 0.2158 - d_loss: -0.1551 - wass_dist: -0.1839 - g_lr: 1.2264e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1323 - val_d_loss: -0.1617 - val_wass_dist: -0.2787
# Epoch 970/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2174 - d_loss: -0.1537 - wass_dist: -0.1641 - g_lr: 1.2180e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1250 - val_d_loss: -0.0985 - val_wass_dist: 0.1043
# Epoch 971/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2174 - d_loss: -0.1559 - wass_dist: -0.1842 - g_lr: 1.2098e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0997 - val_d_loss: -0.1199 - val_wass_dist: 0.3314
# Epoch 972/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2167 - d_loss: -0.1531 - wass_dist: -0.1749 - g_lr: 1.2015e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0952 - val_d_loss: -0.1137 - val_wass_dist: -0.2314
# Epoch 973/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2157 - d_loss: -0.1551 - wass_dist: -0.1781 - g_lr: 1.1934e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1511 - val_d_loss: -0.0843 - val_wass_dist: 0.0772
# Epoch 974/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2175 - d_loss: -0.1559 - wass_dist: -0.1842 - g_lr: 1.1853e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0874 - val_d_loss: -0.0945 - val_wass_dist: 0.1748
# Epoch 975/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2162 - d_loss: -0.1560 - wass_dist: -0.2118 - g_lr: 1.1772e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1412 - val_d_loss: -0.1120 - val_wass_dist: -0.2300
# Epoch 976/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2172 - d_loss: -0.1540 - wass_dist: -0.1826 - g_lr: 1.1692e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1025 - val_d_loss: -0.0978 - val_wass_dist: -0.0160
# Epoch 977/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2188 - d_loss: -0.1568 - wass_dist: -0.1741 - g_lr: 1.1613e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0886 - val_d_loss: -0.1374 - val_wass_dist: -0.2016
# Epoch 978/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2165 - d_loss: -0.1552 - wass_dist: -0.1565 - g_lr: 1.1534e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0921 - val_d_loss: -0.0688 - val_wass_dist: -0.1067
# Epoch 979/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2203 - d_loss: -0.1562 - wass_dist: -0.1795 - g_lr: 1.1456e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1573 - val_d_loss: -0.0909 - val_wass_dist: 0.0420
# Epoch 980/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2202 - d_loss: -0.1577 - wass_dist: -0.1841 - g_lr: 1.1378e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1496 - val_d_loss: -0.1384 - val_wass_dist: 0.0068
# Epoch 981/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2237 - d_loss: -0.1564 - wass_dist: -0.1748 - g_lr: 1.1301e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1114 - val_d_loss: -0.0849 - val_wass_dist: 0.1609
# Epoch 982/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2239 - d_loss: -0.1592 - wass_dist: -0.1929 - g_lr: 1.1224e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0909 - val_d_loss: -0.1128 - val_wass_dist: 0.1556
# Epoch 983/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2246 - d_loss: -0.1605 - wass_dist: -0.1748 - g_lr: 1.1148e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1214 - val_d_loss: -0.1050 - val_wass_dist: -0.0245
# Epoch 984/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2232 - d_loss: -0.1593 - wass_dist: -0.1848 - g_lr: 1.1072e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0885 - val_d_loss: -0.1492 - val_wass_dist: -0.4904
# Epoch 985/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2240 - d_loss: -0.1584 - wass_dist: -0.1776 - g_lr: 1.0997e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1038 - val_d_loss: -0.1739 - val_wass_dist: -0.4579
# Epoch 986/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2229 - d_loss: -0.1586 - wass_dist: -0.1525 - g_lr: 1.0922e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1281 - val_d_loss: -0.1216 - val_wass_dist: -0.3608
# Epoch 987/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2258 - d_loss: -0.1582 - wass_dist: -0.1687 - g_lr: 1.0848e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1291 - val_d_loss: -0.1133 - val_wass_dist: -0.1491
# Epoch 988/1000
# 503/503 [==============================] - 9s 18ms/step - g_loss: 0.2248 - d_loss: -0.1613 - wass_dist: -0.1804 - g_lr: 1.0775e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1374 - val_d_loss: -0.1605 - val_wass_dist: -0.1314
# Epoch 989/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2233 - d_loss: -0.1592 - wass_dist: -0.1790 - g_lr: 1.0701e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0969 - val_d_loss: -0.0884 - val_wass_dist: 0.2451
# Epoch 990/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2246 - d_loss: -0.1597 - wass_dist: -0.1953 - g_lr: 1.0629e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1279 - val_d_loss: -0.1570 - val_wass_dist: -0.1938
# Epoch 991/1000
# 503/503 [==============================] - 10s 18ms/step - g_loss: 0.2260 - d_loss: -0.1595 - wass_dist: -0.1843 - g_lr: 1.0557e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1195 - val_d_loss: -0.0437 - val_wass_dist: 0.1256
# Epoch 992/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2259 - d_loss: -0.1602 - wass_dist: -0.1961 - g_lr: 1.0485e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1511 - val_d_loss: -0.1335 - val_wass_dist: -0.3678
# Epoch 993/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2252 - d_loss: -0.1610 - wass_dist: -0.1918 - g_lr: 1.0414e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1447 - val_d_loss: -0.1017 - val_wass_dist: -1.5987
# Epoch 994/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2234 - d_loss: -0.1604 - wass_dist: -0.1981 - g_lr: 1.0343e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1457 - val_d_loss: -0.1446 - val_wass_dist: -0.3468
# Epoch 995/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2291 - d_loss: -0.1612 - wass_dist: -0.1734 - g_lr: 1.0273e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1174 - val_d_loss: -0.1269 - val_wass_dist: 0.0776
# Epoch 996/1000
# 503/503 [==============================] - 10s 19ms/step - g_loss: 0.2271 - d_loss: -0.1613 - wass_dist: -0.1695 - g_lr: 1.0203e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1328 - val_d_loss: -0.1053 - val_wass_dist: -0.4948
# Epoch 997/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2298 - d_loss: -0.1624 - wass_dist: -0.1836 - g_lr: 1.0134e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.0862 - val_d_loss: -0.0797 - val_wass_dist: 0.0933
# Epoch 998/1000
# 503/503 [==============================] - 11s 20ms/step - g_loss: 0.2326 - d_loss: -0.1650 - wass_dist: -0.2028 - g_lr: 1.0065e-06 - d_lr: 6.0000e-07 - val_g_loss: 0.1317 - val_d_loss: -0.1294 - val_wass_dist: -0.1331
# Epoch 999/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2295 - d_loss: -0.1640 - wass_dist: -0.1616 - g_lr: 9.9966e-07 - d_lr: 6.0000e-07 - val_g_loss: 0.1493 - val_d_loss: -0.1464 - val_wass_dist: -0.0093
# Epoch 1000/1000
# 503/503 [==============================] - 10s 20ms/step - g_loss: 0.2295 - d_loss: -0.1632 - wass_dist: -0.2008 - g_lr: 9.9287e-07 - d_lr: 6.0000e-07 - val_g_loss: 0.1024 - val_d_loss: -0.0843 - val_wass_dist: -0.0760

# %%
plt.figure(figsize=(16, 5), dpi=100)

start_epoch = 1

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#3288bd", label="generator")
plt.plot(train.history["d_loss"][start_epoch:], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_loss"], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Learning rate scheduling", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Learning rate", fontsize=12)
plt.plot(train.history["g_lr"], color="#3288bd", label="generator")
plt.plot(train.history["d_lr"], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_lr"], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.show()

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Generator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_g_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Discriminator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["d_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_d_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.show()

# %%
plt.figure(figsize=(24, 5), dpi=100)

# plt.subplot(1, 3, 1)
# plt.title("Metric curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Accuracy", fontsize=12)
# plt.plot(train.history["accuracy"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_accuracy"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 3, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Wasserstein distance", fontsize=12)
plt.plot(train.history["wass_dist"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_wass_dist"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)
# plt.yscale("log")

# plt.subplot(1, 3, 3)
# plt.title("Referee learning curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Binary cross-entropy", fontsize=12)
# plt.plot(train.history["r_loss"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_r_loss"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="center right", fontsize=10)

plt.show()

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-GlobalPID-nm-kaon-train.csv")

# %% [markdown]
# ## A first, rough validation
#
# TBA

# %%
reader_test = FeatherReader(environ.get("GLOBALPID_NM_KAON_TEST_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-test"), max_files=50)
head = reader_test.as_dask_dataframe().head(20_000_000, npartitions=-1)

# %%
X_test = head[reader_test.features].values
y_test = head[reader_test.labels].values
preds = gan.generator.predict(X_test, batch_size=50_000)
# Out:
# 400/400 [==============================] - 1s 3ms/step

# %%
X_test.shape, y_test.shape, preds.shape
# Out:
# ((20000000, 8), (20000000, 8), (20000000, 8))

# %%
# referee_true = gan.referee.predict((X_test, y_test), batch_size=50_000)
# referee_pred = gan.referee.predict((X_test, preds), batch_size=50_000)

# %%
# plt.figure(figsize=(8, 5), dpi=100)
# plt.xlabel("Referee score", fontsize=12)
# plt.ylabel("Candidates", fontsize=12)
# 
# bins = np.linspace(0.0, 1.0, 101)
# plt.hist(referee_true, bins=bins, label="Detailed Simulation")
# plt.hist(referee_pred, bins=bins, histtype="step", lw=2, label="GAN-based model")
# plt.legend(fontsize=10)
# 
# plt.show()

# %%
# from pidgan.optimization.scores import KSDistance
# 
# ks_dist = KSDistance()
# ks_score = ks_dist(referee_true, referee_pred, bins=100, range=[0.0, 1.0])
# 
# print(f"K-S distance (referee): {ks_score:.3f}")

# %%
# chunk_size = 5_000_000
# 
# np.savez_compressed(
#     f"./exports/{prefix}-Rich-kaon-referee.npz",
#     referee_true=referee_true[:chunk_size],
#     referee_pred=referee_pred[:chunk_size],
#     ks_score=ks_score,
# )

# %%
import pickle

models_dir = "/home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models"

with open(f"{models_dir}/tX_{SAMPLE}.pkl", "rb") as file:
    X_scaler = pickle.load(file)

with open(f"{models_dir}/tY_{SAMPLE}.pkl", "rb") as file:
    y_scaler = pickle.load(file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer
    
X_post = invertColumnTransformer(X_scaler, X_test)
y_post = invertColumnTransformer(y_scaler, y_test)
preds_post = invertColumnTransformer(y_scaler, preds)

# %%
plt.figure(figsize=(32, 15), dpi=100)

# PIDe
plt.subplot(3, 4, 1)
bins = np.linspace(-20.0, 10.0, 101)
plt.xlabel("$\mathtt{PIDe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDK
plt.subplot(3, 4, 2)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDp
plt.subplot(3, 4, 3)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDpK
plt.subplot(3, 4, 4)
bins = np.linspace(-100.0, 50.0, 101)
plt.xlabel("$\mathtt{PIDpK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000] - y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000] - preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNe
plt.subplot(3, 4, 5)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNe")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNpi
plt.subplot(3, 4, 6)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNpi}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNpi")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNpi")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# ProbNNk
plt.subplot(3, 4, 7)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNk}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNk")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNk")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNp
plt.subplot(3, 4, 8)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNp")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# PIDmu
plt.subplot(3, 4, 9)
bins = np.linspace(-15.0, 25.0, 101)
plt.xlabel("$\mathtt{PIDmu}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDmue
plt.subplot(3, 4, 10)
bins = np.linspace(-20.0, 30.0, 101)
plt.xlabel("$\mathtt{PIDmue}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000] - y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000] - preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
np.savez_compressed(
    f"./exports/{prefix}-GlobalPID-nm-kaon-results.npz",
    feat_vars=np.array(x_vars[:3] + [x_vars[-1]]),
    label_vars=np.array(y_vars),
    results=np.c_[X_post[:, :3], X_post[:, -1], y_post, preds_post][:750_000],
)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_GlobalPID-nm_kaon_{SAMPLE}_gan"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    generator.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models/20240118-00h35m09s_GlobalPID-nm_kaon_2016MU_gan/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models/20240118-00h35m09s_GlobalPID-nm_kaon_2016MU_gan/assets
