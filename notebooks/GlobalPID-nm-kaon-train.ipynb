# %% [markdown]
# # Training of the _GlobalPID_ model for _kaons_ not passing the isMuon criterion
#
# In this notebook we setup the training for the GlobalPID model for _kaons_ that don't pass the isMuon criterion, based on Generative Adversarial Networks (GAN).
#
# This notebook is part of a pipeline and requires the data preprocessed with the notebook [GlobalPID-preprocessing.ipynb](./GlobalPID-preprocessing.ipynb).

# %%
LOCAL = True
SAMPLE = "2016MU"
TEST = False

# %% [markdown]
# ## Enviornment setup and libraries
#
# In this notebooks we will use the standard software stack for TensorFlow machine learning applications.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import environ

## Remove annoying warnings 
environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %% [markdown]
# To ensure a GPU is found and properly loaded in the notebook kernel to the benefit of TensorFlow, the output of the following block should be similar to `'/device:GPU:0'`.
# If a GPU is not found, the string will be empty.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Load datasets
#
# Preprocessed datasets were stored in *Apache feather* format and can be reloaded with our custom `FeatherReader` designed to stream the datasets into TensorFlow or Dask format.
#
# We are loading in particular:
#  * the **training** dataset to train the network
#  * the **validation** dataset to evaluate the network performance at each epoch and identify overtraining effects

# %%
DATA_PATH = "/home/mabarbet/PythonFastSim/data" if LOCAL else "/workarea/cloud-storage/mabarbet/data"

# %%
from feather_io import FeatherReader    

reader_train = FeatherReader(environ.get("GLOBALPID_NM_KAON_TRAIN_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-train"), max_files=4)
ds_train = reader_train.as_tf_dataset()

reader_val = FeatherReader(environ.get("GLOBALPID_NM_KAON_VAL_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-validation"), max_files=1)
ds_val = reader_val.as_tf_dataset()

# %% [markdown]
# We load a small batch of data to identify the shape of features and labels, and automate the definition of the neural network architecture.

# %%
x_vars = reader_train.features
y_vars = reader_train.labels

x_vars, y_vars
# Out:
# (['p_GeV',
#   'eta',
#   'nTracks_f',
#   'RichDLLe',
#   'RichDLLmu',
#   'RichDLLk',
#   'RichDLLp',
#   'charge'],
#  ['PIDe',
#   'PIDK',
#   'PIDp',
#   'ProbNNe',
#   'ProbNNpi',
#   'ProbNNk',
#   'ProbNNp',
#   'PIDmu'])

# %%
X, y = next(iter(ds_train.batch(500_000)))
X.shape, y.shape
# Out:
# (TensorShape([500000, 8]), TensorShape([500000, 8]))

# %% [markdown]
# ## Model definition
#
# TBA

# %% [markdown]
# ### Generator architecture
#
# TBA

# %%
from pidgan.players.generators import ResGenerator

generator = ResGenerator(
    output_dim=y.shape[1],
    latent_dim=64,
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    output_activation=None,
    name="generator",
)

# %%
generator(X[:256])
generator.summary()
# Out:
# Model: "generator_func"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 72)]                 0         []
#
#  dense_0 (Dense)             (None, 128)                  9344      ['input_1[0][0]']
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)                  0         ['dense_0[0][0]']
#
#  dropout_0 (Dropout)         (None, 128)                  0         ['leaky_relu_0[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_0[0][0]']
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)                  0         ['dense_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['leaky_relu_1[0][0]']
#
#  add_0-1 (Add)               (None, 128)                  0         ['dropout_0[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['add_0-1[0][0]']
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)                  0         ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['leaky_relu_2[0][0]']
#
#  add_1-2 (Add)               (None, 128)                  0         ['add_0-1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['add_1-2[0][0]']
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)                  0         ['dense_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['leaky_relu_3[0][0]']
#
#  add_2-3 (Add)               (None, 128)                  0         ['add_1-2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['add_2-3[0][0]']
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)                  0         ['dense_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['leaky_relu_4[0][0]']
#
#  add_3-4 (Add)               (None, 128)                  0         ['add_2-3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  dense_out (Dense)           (None, 8)                    1032      ['add_3-4[0][0]']
#
# ==================================================================================================
# Total params: 76424 (298.53 KB)
# Trainable params: 76424 (298.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    generator.export_model,
    to_file="./images/GlobalPID-nm-kaon-generator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Discriminator architecture
#
# TBA

# %%
from pidgan.players.discriminators import AuxDiscriminator

discriminator = AuxDiscriminator(
    output_dim=1,
    aux_features=["3 - 0", "2 - 1"],  # ["PIDmu - PIDe", "PIDK - PIDp"]
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    enable_residual_blocks=False,
    output_activation=None,
    name="discriminator",
)

# %%
discriminator((X[:256], y[:256]))
discriminator.summary()
# Out:
# Model: "discriminator_func"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 18)]              0
#
#  dense_0 (Dense)             (None, 128)               2432
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)               0
#
#  dropout_0 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_out (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 68609 (268.00 KB)
# Trainable params: 68609 (268.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    discriminator.export_model,
    to_file="./images/GlobalPID-nm-kaon-discriminator.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Referee architecture

# %%
from pidgan.players.classifiers import Classifier

referee = Classifier(
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_hidden_activation="relu",
    mlp_hidden_kernel_regularizer=None,
    mlp_dropout_rates=0.0,
    name="referee",
)

# %%
referee((X[:256], y[:256]))
referee.summary()
# Out:
# Model: "referee_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             (256, 128)                2176
#
#  dropout_0 (Dropout)         (256, 128)                0
#
#  dense_1 (Dense)             (256, 128)                16512
#
#  dropout_1 (Dropout)         (256, 128)                0
#
#  dense_2 (Dense)             (256, 128)                16512
#
#  dropout_2 (Dropout)         (256, 128)                0
#
#  dense_3 (Dense)             (256, 128)                16512
#
#  dropout_3 (Dropout)         (256, 128)                0
#
#  dense_4 (Dense)             (256, 128)                16512
#
#  dropout_4 (Dropout)         (256, 128)                0
#
#  dense_out (Dense)           (256, 1)                  129
#
# =================================================================
# Total params: 68353 (267.00 KB)
# Trainable params: 68353 (267.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    referee.export_model,
    to_file="./images/GlobalPID-nm-kaon-referee.png",
    show_shapes=True,
    show_layer_names=False,
    show_layer_activations=True,
    rankdir="TB",
    dpi=100,
)

# %% [markdown]
# ### Training setup
#
# TBA

# %%
from pidgan.algorithms import WGAN_ALP

gan = WGAN_ALP(
    generator=generator,
    discriminator=discriminator,
    lipschitz_penalty=1.0,
    lipschitz_penalty_strategy="one-sided",
    feature_matching_penalty=0.0,
    # referee=referee,
)

# %%
from tensorflow.keras.optimizers import RMSprop, Adam

g_lr0 = 9e-4
d_lr0 = 6e-4

gan.compile(
    metrics=["wass_dist"],
    generator_optimizer=RMSprop(g_lr0),
    discriminator_optimizer=RMSprop(d_lr0),
    generator_upds_per_batch=1,
    discriminator_upds_per_batch=1,
    # referee_optimizer=Adam(1e-3),
    # referee_upds_per_batch=1,
)

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

callbacks = list()

g_lr_sched = LearnRateExpDecay(
    gan.generator_optimizer,
    decay_rate=0.1,
    decay_steps=170_000,
    min_learning_rate=g_lr0/1e3,
    verbose=True,
    key="g_lr",
)
callbacks.append(g_lr_sched)

d_lr_sched = LearnRateExpDecay(
    gan.discriminator_optimizer,
    decay_rate=0.1,
    decay_steps=90_000,
    min_learning_rate=d_lr0/1e3,
    verbose=True,
    key="d_lr",
)
callbacks.append(d_lr_sched)

# r_lr_sched = LearnRateExpDecay(
#     gan.referee_optimizer,
#     decay_rate=0.1,
#     decay_steps=150_000,
#     verbose=True,
#     key="r_lr",
# )
# callbacks.append(r_lr_sched)

# %%
from datetime import datetime

batch_size = 12_000
num_epochs = 1000 if not TEST else 150

data_train = ds_train.batch(batch_size, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
data_val = next(iter(ds_val.batch(batch_size)))

train = gan.fit(data_train, epochs=num_epochs, validation_data=data_val, callbacks=callbacks)

if not TEST:
    prefix = ""
    timestamp = str(datetime.now())
    timestamp = timestamp.split(".")[0].replace("-", "").replace(" ", "-")
    for time, unit in zip(timestamp.split(":"), ["h", "m", "s"]):
        prefix += time + unit  # YYYYMMDD-HHhMMmSSs
else:
    prefix = "test"
# Out:
# Epoch 1/500
#       4/Unknown - 10s 17ms/step - g_loss: 0.8147 - d_loss: -0.1262 - wass_dist: -0.2976 - g_lr: 8.9998e-04 - d_lr: 5.9998e-04WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0129s vs `on_train_batch_begin` time: 0.1684s). Check your callbacks.
# 453/453 [==============================] - 23s 29ms/step - g_loss: 0.6962 - d_loss: -0.4034 - wass_dist: -0.5152 - g_lr: 8.9724e-04 - d_lr: 5.9654e-04 - val_g_loss: 0.5211 - val_d_loss: -0.5229 - val_wass_dist: -0.5098
# Epoch 2/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.1148 - d_loss: -0.5448 - wass_dist: -0.8836 - g_lr: 8.9174e-04 - d_lr: 5.8965e-04 - val_g_loss: 0.9001 - val_d_loss: -0.8597 - val_wass_dist: -1.0916
# Epoch 3/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4220 - d_loss: -0.4985 - wass_dist: -0.5756 - g_lr: 8.8629e-04 - d_lr: 5.8285e-04 - val_g_loss: 0.5640 - val_d_loss: -0.5564 - val_wass_dist: -0.9937
# Epoch 4/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.4120 - d_loss: -0.4058 - wass_dist: -0.1493 - g_lr: 8.8087e-04 - d_lr: 5.7614e-04 - val_g_loss: 0.1107 - val_d_loss: -0.1086 - val_wass_dist: -0.0404
# Epoch 5/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.3633 - d_loss: -0.3239 - wass_dist: -0.3390 - g_lr: 8.7548e-04 - d_lr: 5.6950e-04 - val_g_loss: 0.3610 - val_d_loss: -0.3971 - val_wass_dist: -0.9020
# Epoch 6/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.2666 - d_loss: -0.2509 - wass_dist: -0.4692 - g_lr: 8.7012e-04 - d_lr: 5.6294e-04 - val_g_loss: 0.4694 - val_d_loss: -0.4734 - val_wass_dist: -0.3575
# Epoch 7/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.1814 - d_loss: -0.1974 - wass_dist: -0.2842 - g_lr: 8.6480e-04 - d_lr: 5.5645e-04 - val_g_loss: 0.2519 - val_d_loss: -0.2492 - val_wass_dist: 0.1485
# Epoch 8/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.0927 - d_loss: -0.1988 - wass_dist: -0.2815 - g_lr: 8.5951e-04 - d_lr: 5.5004e-04 - val_g_loss: 0.2557 - val_d_loss: -0.2713 - val_wass_dist: -0.3608
# Epoch 9/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.0994 - d_loss: -0.2513 - wass_dist: -0.3818 - g_lr: 8.5425e-04 - d_lr: 5.4370e-04 - val_g_loss: 0.3839 - val_d_loss: -0.3638 - val_wass_dist: -0.6297
# Epoch 10/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.1752 - d_loss: -0.3447 - wass_dist: -0.4871 - g_lr: 8.4903e-04 - d_lr: 5.3744e-04 - val_g_loss: 0.5039 - val_d_loss: -0.5151 - val_wass_dist: -1.5478
# Epoch 11/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.2871 - d_loss: -0.4443 - wass_dist: -0.7132 - g_lr: 8.4384e-04 - d_lr: 5.3124e-04 - val_g_loss: 0.6895 - val_d_loss: -0.7103 - val_wass_dist: -2.0108
# Epoch 12/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4168 - d_loss: -0.5257 - wass_dist: -0.8426 - g_lr: 8.3867e-04 - d_lr: 5.2512e-04 - val_g_loss: 0.8837 - val_d_loss: -0.8886 - val_wass_dist: -0.9451
# Epoch 13/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.5332 - d_loss: -0.5919 - wass_dist: -0.9983 - g_lr: 8.3354e-04 - d_lr: 5.1907e-04 - val_g_loss: 1.0365 - val_d_loss: -1.0415 - val_wass_dist: -1.7788
# Epoch 14/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6122 - d_loss: -0.6169 - wass_dist: -1.0848 - g_lr: 8.2845e-04 - d_lr: 5.1309e-04 - val_g_loss: 1.1238 - val_d_loss: -1.0776 - val_wass_dist: -1.1128
# Epoch 15/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.6575 - d_loss: -0.6309 - wass_dist: -1.0118 - g_lr: 8.2338e-04 - d_lr: 5.0718e-04 - val_g_loss: 0.9983 - val_d_loss: -0.9886 - val_wass_dist: -0.8216
# Epoch 16/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.7082 - d_loss: -0.6399 - wass_dist: -1.0646 - g_lr: 8.1834e-04 - d_lr: 5.0133e-04 - val_g_loss: 0.9970 - val_d_loss: -1.0419 - val_wass_dist: -0.0270
# Epoch 17/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7363 - d_loss: -0.6484 - wass_dist: -0.8328 - g_lr: 8.1334e-04 - d_lr: 4.9556e-04 - val_g_loss: 0.8728 - val_d_loss: -0.8561 - val_wass_dist: -1.3405
# Epoch 18/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7568 - d_loss: -0.6489 - wass_dist: -1.0058 - g_lr: 8.0836e-04 - d_lr: 4.8985e-04 - val_g_loss: 0.9939 - val_d_loss: -0.9778 - val_wass_dist: -2.7056
# Epoch 19/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7695 - d_loss: -0.6496 - wass_dist: -0.6702 - g_lr: 8.0342e-04 - d_lr: 4.8420e-04 - val_g_loss: 0.6681 - val_d_loss: -0.7239 - val_wass_dist: -1.3563
# Epoch 20/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7764 - d_loss: -0.6420 - wass_dist: -1.0292 - g_lr: 7.9850e-04 - d_lr: 4.7862e-04 - val_g_loss: 1.0604 - val_d_loss: -0.9794 - val_wass_dist: -0.6871
# Epoch 21/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7571 - d_loss: -0.6328 - wass_dist: -1.0010 - g_lr: 7.9362e-04 - d_lr: 4.7311e-04 - val_g_loss: 1.0676 - val_d_loss: -1.0154 - val_wass_dist: -1.8142
# Epoch 22/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6890 - d_loss: -0.6052 - wass_dist: -0.9967 - g_lr: 7.8876e-04 - d_lr: 4.6766e-04 - val_g_loss: 0.9275 - val_d_loss: -0.9995 - val_wass_dist: -0.1725
# Epoch 23/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6660 - d_loss: -0.6025 - wass_dist: -1.0019 - g_lr: 7.8394e-04 - d_lr: 4.6227e-04 - val_g_loss: 0.9699 - val_d_loss: -0.9453 - val_wass_dist: -1.5168
# Epoch 24/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.6655 - d_loss: -0.6189 - wass_dist: -0.8003 - g_lr: 7.7914e-04 - d_lr: 4.5694e-04 - val_g_loss: 0.8042 - val_d_loss: -0.8129 - val_wass_dist: -1.5434
# Epoch 25/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6408 - d_loss: -0.6196 - wass_dist: -0.8999 - g_lr: 7.7438e-04 - d_lr: 4.5167e-04 - val_g_loss: 0.9225 - val_d_loss: -0.9122 - val_wass_dist: 0.0645
# Epoch 26/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 1.5869 - d_loss: -0.6129 - wass_dist: -1.2094 - g_lr: 7.6964e-04 - d_lr: 4.4647e-04 - val_g_loss: 1.3019 - val_d_loss: -1.3608 - val_wass_dist: -1.0477
# Epoch 27/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.5328 - d_loss: -0.6037 - wass_dist: -0.9877 - g_lr: 7.6493e-04 - d_lr: 4.4133e-04 - val_g_loss: 0.9985 - val_d_loss: -0.9311 - val_wass_dist: -1.3000
# Epoch 28/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.5074 - d_loss: -0.5897 - wass_dist: -0.6818 - g_lr: 7.6025e-04 - d_lr: 4.3624e-04 - val_g_loss: 0.7312 - val_d_loss: -0.6759 - val_wass_dist: -0.0789
# Epoch 29/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.5028 - d_loss: -0.5850 - wass_dist: -0.9601 - g_lr: 7.5560e-04 - d_lr: 4.3121e-04 - val_g_loss: 1.0092 - val_d_loss: -1.0159 - val_wass_dist: -2.5372
# Epoch 30/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4926 - d_loss: -0.5901 - wass_dist: -1.1454 - g_lr: 7.5098e-04 - d_lr: 4.2624e-04 - val_g_loss: 1.1945 - val_d_loss: -1.1747 - val_wass_dist: -1.7635
# Epoch 31/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4802 - d_loss: -0.5875 - wass_dist: -0.7521 - g_lr: 7.4639e-04 - d_lr: 4.2133e-04 - val_g_loss: 0.7261 - val_d_loss: -0.8243 - val_wass_dist: -0.9993
# Epoch 32/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4351 - d_loss: -0.5622 - wass_dist: -1.0518 - g_lr: 7.4182e-04 - d_lr: 4.1648e-04 - val_g_loss: 1.1107 - val_d_loss: -1.1021 - val_wass_dist: -2.5716
# Epoch 33/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4202 - d_loss: -0.5585 - wass_dist: -0.6974 - g_lr: 7.3728e-04 - d_lr: 4.1168e-04 - val_g_loss: 0.7538 - val_d_loss: -0.7111 - val_wass_dist: -0.8017
# Epoch 34/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4185 - d_loss: -0.5627 - wass_dist: -0.6953 - g_lr: 7.3277e-04 - d_lr: 4.0694e-04 - val_g_loss: 0.7375 - val_d_loss: -0.6799 - val_wass_dist: -1.0297
# Epoch 35/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4199 - d_loss: -0.5472 - wass_dist: -0.6852 - g_lr: 7.2829e-04 - d_lr: 4.0225e-04 - val_g_loss: 0.7365 - val_d_loss: -0.7155 - val_wass_dist: -0.1535
# Epoch 36/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4109 - d_loss: -0.5392 - wass_dist: -0.8942 - g_lr: 7.2384e-04 - d_lr: 3.9761e-04 - val_g_loss: 0.9379 - val_d_loss: -0.9188 - val_wass_dist: -0.0438
# Epoch 37/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4320 - d_loss: -0.5501 - wass_dist: -0.9204 - g_lr: 7.1941e-04 - d_lr: 3.9303e-04 - val_g_loss: 0.9359 - val_d_loss: -0.9108 - val_wass_dist: -0.8142
# Epoch 38/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4257 - d_loss: -0.5432 - wass_dist: -0.7771 - g_lr: 7.1501e-04 - d_lr: 3.8850e-04 - val_g_loss: 0.7877 - val_d_loss: -0.8597 - val_wass_dist: -1.2951
# Epoch 39/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4238 - d_loss: -0.5346 - wass_dist: -0.9732 - g_lr: 7.1063e-04 - d_lr: 3.8402e-04 - val_g_loss: 1.0225 - val_d_loss: -0.9790 - val_wass_dist: -1.2475
# Epoch 40/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.4281 - d_loss: -0.5348 - wass_dist: -0.8472 - g_lr: 7.0629e-04 - d_lr: 3.7960e-04 - val_g_loss: 0.9282 - val_d_loss: -0.8889 - val_wass_dist: -0.8527
# Epoch 41/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4341 - d_loss: -0.5412 - wass_dist: -1.0103 - g_lr: 7.0197e-04 - d_lr: 3.7523e-04 - val_g_loss: 1.0384 - val_d_loss: -1.0380 - val_wass_dist: 0.1146
# Epoch 42/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4359 - d_loss: -0.5388 - wass_dist: -0.6562 - g_lr: 6.9767e-04 - d_lr: 3.7090e-04 - val_g_loss: 0.7149 - val_d_loss: -0.7691 - val_wass_dist: -0.4086
# Epoch 43/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4618 - d_loss: -0.5486 - wass_dist: -0.8584 - g_lr: 6.9341e-04 - d_lr: 3.6663e-04 - val_g_loss: 0.8995 - val_d_loss: -0.9133 - val_wass_dist: -1.1515
# Epoch 44/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4608 - d_loss: -0.5585 - wass_dist: -0.6292 - g_lr: 6.8916e-04 - d_lr: 3.6240e-04 - val_g_loss: 0.6321 - val_d_loss: -0.6595 - val_wass_dist: -0.1109
# Epoch 45/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4565 - d_loss: -0.5510 - wass_dist: -0.7437 - g_lr: 6.8495e-04 - d_lr: 3.5823e-04 - val_g_loss: 0.7608 - val_d_loss: -0.8093 - val_wass_dist: -0.3665
# Epoch 46/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4617 - d_loss: -0.5440 - wass_dist: -0.7888 - g_lr: 6.8076e-04 - d_lr: 3.5410e-04 - val_g_loss: 0.8291 - val_d_loss: -0.8569 - val_wass_dist: -1.1824
# Epoch 47/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4427 - d_loss: -0.5466 - wass_dist: -0.8736 - g_lr: 6.7659e-04 - d_lr: 3.5002e-04 - val_g_loss: 0.8596 - val_d_loss: -0.8726 - val_wass_dist: -0.5717
# Epoch 48/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4361 - d_loss: -0.5448 - wass_dist: -0.7862 - g_lr: 6.7246e-04 - d_lr: 3.4599e-04 - val_g_loss: 0.8971 - val_d_loss: -0.8444 - val_wass_dist: -0.9740
# Epoch 49/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4268 - d_loss: -0.5477 - wass_dist: -0.7225 - g_lr: 6.6834e-04 - d_lr: 3.4200e-04 - val_g_loss: 0.7440 - val_d_loss: -0.7386 - val_wass_dist: -0.5554
# Epoch 50/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.4108 - d_loss: -0.5367 - wass_dist: -0.8079 - g_lr: 6.6425e-04 - d_lr: 3.3806e-04 - val_g_loss: 0.8334 - val_d_loss: -0.8488 - val_wass_dist: -0.4866
# Epoch 51/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4217 - d_loss: -0.5398 - wass_dist: -0.5647 - g_lr: 6.6019e-04 - d_lr: 3.3416e-04 - val_g_loss: 0.6236 - val_d_loss: -0.6170 - val_wass_dist: -0.3325
# Epoch 52/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4093 - d_loss: -0.5285 - wass_dist: -0.6694 - g_lr: 6.5615e-04 - d_lr: 3.3031e-04 - val_g_loss: 0.7433 - val_d_loss: -0.7221 - val_wass_dist: -0.2373
# Epoch 53/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4073 - d_loss: -0.5210 - wass_dist: -0.5678 - g_lr: 6.5214e-04 - d_lr: 3.2651e-04 - val_g_loss: 0.5122 - val_d_loss: -0.5774 - val_wass_dist: 0.1407
# Epoch 54/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 1.4137 - d_loss: -0.5420 - wass_dist: -0.8745 - g_lr: 6.4815e-04 - d_lr: 3.2274e-04 - val_g_loss: 0.9626 - val_d_loss: -0.9025 - val_wass_dist: -0.3228
# Epoch 55/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4089 - d_loss: -0.5358 - wass_dist: -0.7091 - g_lr: 6.4419e-04 - d_lr: 3.1903e-04 - val_g_loss: 0.7302 - val_d_loss: -0.7047 - val_wass_dist: -0.2683
# Epoch 56/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4054 - d_loss: -0.5307 - wass_dist: -0.7951 - g_lr: 6.4024e-04 - d_lr: 3.1535e-04 - val_g_loss: 0.8834 - val_d_loss: -0.9114 - val_wass_dist: -0.6632
# Epoch 57/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4103 - d_loss: -0.5447 - wass_dist: -0.7205 - g_lr: 6.3633e-04 - d_lr: 3.1172e-04 - val_g_loss: 0.7486 - val_d_loss: -0.7783 - val_wass_dist: -0.8671
# Epoch 58/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4109 - d_loss: -0.5397 - wass_dist: -0.9838 - g_lr: 6.3244e-04 - d_lr: 3.0812e-04 - val_g_loss: 1.0119 - val_d_loss: -0.9928 - val_wass_dist: -0.6923
# Epoch 59/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.3958 - d_loss: -0.5389 - wass_dist: -0.8566 - g_lr: 6.2857e-04 - d_lr: 3.0457e-04 - val_g_loss: 0.9302 - val_d_loss: -0.8866 - val_wass_dist: -0.6039
# Epoch 60/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4064 - d_loss: -0.5443 - wass_dist: -0.8286 - g_lr: 6.2472e-04 - d_lr: 3.0106e-04 - val_g_loss: 0.8834 - val_d_loss: -0.9351 - val_wass_dist: -0.0404
# Epoch 61/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.4049 - d_loss: -0.5469 - wass_dist: -0.9345 - g_lr: 6.2090e-04 - d_lr: 2.9760e-04 - val_g_loss: 0.9941 - val_d_loss: -0.9654 - val_wass_dist: -0.5603
# Epoch 62/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4087 - d_loss: -0.5456 - wass_dist: -0.9829 - g_lr: 6.1710e-04 - d_lr: 2.9417e-04 - val_g_loss: 1.0477 - val_d_loss: -1.0645 - val_wass_dist: -0.5966
# Epoch 63/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4057 - d_loss: -0.5530 - wass_dist: -0.6488 - g_lr: 6.1333e-04 - d_lr: 2.9078e-04 - val_g_loss: 0.7831 - val_d_loss: -0.7823 - val_wass_dist: -0.9145
# Epoch 64/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.3933 - d_loss: -0.5590 - wass_dist: -0.9013 - g_lr: 6.0958e-04 - d_lr: 2.8743e-04 - val_g_loss: 0.9464 - val_d_loss: -0.9342 - val_wass_dist: -0.1201
# Epoch 65/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.3909 - d_loss: -0.5640 - wass_dist: -0.8094 - g_lr: 6.0585e-04 - d_lr: 2.8411e-04 - val_g_loss: 0.8905 - val_d_loss: -0.8721 - val_wass_dist: -0.4588
# Epoch 66/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4123 - d_loss: -0.5787 - wass_dist: -0.7550 - g_lr: 6.0214e-04 - d_lr: 2.8084e-04 - val_g_loss: 0.8063 - val_d_loss: -0.8799 - val_wass_dist: -0.2954
# Epoch 67/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4362 - d_loss: -0.5940 - wass_dist: -0.8063 - g_lr: 5.9846e-04 - d_lr: 2.7760e-04 - val_g_loss: 0.8554 - val_d_loss: -0.9046 - val_wass_dist: -0.2235
# Epoch 68/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4305 - d_loss: -0.5904 - wass_dist: -0.7485 - g_lr: 5.9480e-04 - d_lr: 2.7441e-04 - val_g_loss: 0.7932 - val_d_loss: -0.7927 - val_wass_dist: -0.0944
# Epoch 69/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.4443 - d_loss: -0.6004 - wass_dist: -0.7816 - g_lr: 5.9116e-04 - d_lr: 2.7124e-04 - val_g_loss: 0.8707 - val_d_loss: -0.8758 - val_wass_dist: -0.2579
# Epoch 70/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.4640 - d_loss: -0.6108 - wass_dist: -0.9745 - g_lr: 5.8754e-04 - d_lr: 2.6812e-04 - val_g_loss: 1.0527 - val_d_loss: -1.0265 - val_wass_dist: 0.1465
# Epoch 71/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 1.4782 - d_loss: -0.6178 - wass_dist: -1.0450 - g_lr: 5.8395e-04 - d_lr: 2.6503e-04 - val_g_loss: 1.0804 - val_d_loss: -1.1102 - val_wass_dist: -0.7182
# Epoch 72/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.4891 - d_loss: -0.6402 - wass_dist: -1.2129 - g_lr: 5.8038e-04 - d_lr: 2.6197e-04 - val_g_loss: 1.3095 - val_d_loss: -1.2994 - val_wass_dist: -0.0715
# Epoch 73/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.5154 - d_loss: -0.6498 - wass_dist: -1.0225 - g_lr: 5.7683e-04 - d_lr: 2.5896e-04 - val_g_loss: 1.0718 - val_d_loss: -1.0895 - val_wass_dist: -0.6077
# Epoch 74/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.5403 - d_loss: -0.6739 - wass_dist: -1.2545 - g_lr: 5.7330e-04 - d_lr: 2.5597e-04 - val_g_loss: 1.3711 - val_d_loss: -1.3886 - val_wass_dist: -0.3101
# Epoch 75/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.5596 - d_loss: -0.6864 - wass_dist: -0.9861 - g_lr: 5.6979e-04 - d_lr: 2.5302e-04 - val_g_loss: 1.0416 - val_d_loss: -1.0187 - val_wass_dist: -0.6865
# Epoch 76/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.5728 - d_loss: -0.7005 - wass_dist: -1.0960 - g_lr: 5.6631e-04 - d_lr: 2.5011e-04 - val_g_loss: 1.1762 - val_d_loss: -1.1655 - val_wass_dist: -0.3713
# Epoch 77/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.5570 - d_loss: -0.6894 - wass_dist: -1.1939 - g_lr: 5.6284e-04 - d_lr: 2.4723e-04 - val_g_loss: 1.3144 - val_d_loss: -1.2436 - val_wass_dist: -0.8094
# Epoch 78/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.5754 - d_loss: -0.6911 - wass_dist: -1.1342 - g_lr: 5.5940e-04 - d_lr: 2.4438e-04 - val_g_loss: 1.2773 - val_d_loss: -1.2541 - val_wass_dist: -0.5477
# Epoch 79/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.5925 - d_loss: -0.7053 - wass_dist: -1.1720 - g_lr: 5.5598e-04 - d_lr: 2.4156e-04 - val_g_loss: 1.2387 - val_d_loss: -1.2203 - val_wass_dist: -0.3617
# Epoch 80/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6350 - d_loss: -0.7341 - wass_dist: -1.2387 - g_lr: 5.5258e-04 - d_lr: 2.3878e-04 - val_g_loss: 1.2612 - val_d_loss: -1.3081 - val_wass_dist: -0.3229
# Epoch 81/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6698 - d_loss: -0.7566 - wass_dist: -1.3892 - g_lr: 5.4920e-04 - d_lr: 2.3603e-04 - val_g_loss: 1.4499 - val_d_loss: -1.4146 - val_wass_dist: -0.4783
# Epoch 82/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.6565 - d_loss: -0.7551 - wass_dist: -1.3779 - g_lr: 5.4584e-04 - d_lr: 2.3331e-04 - val_g_loss: 1.5200 - val_d_loss: -1.4310 - val_wass_dist: -0.6596
# Epoch 83/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.6587 - d_loss: -0.7654 - wass_dist: -1.2914 - g_lr: 5.4250e-04 - d_lr: 2.3062e-04 - val_g_loss: 1.3380 - val_d_loss: -1.3431 - val_wass_dist: -0.6453
# Epoch 84/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.6681 - d_loss: -0.7629 - wass_dist: -1.4738 - g_lr: 5.3918e-04 - d_lr: 2.2796e-04 - val_g_loss: 1.5583 - val_d_loss: -1.5522 - val_wass_dist: -0.9172
# Epoch 85/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7552 - d_loss: -0.8117 - wass_dist: -1.2391 - g_lr: 5.3588e-04 - d_lr: 2.2533e-04 - val_g_loss: 1.3531 - val_d_loss: -1.3430 - val_wass_dist: -0.2585
# Epoch 86/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7019 - d_loss: -0.7864 - wass_dist: -1.3323 - g_lr: 5.3260e-04 - d_lr: 2.2274e-04 - val_g_loss: 1.4437 - val_d_loss: -1.5090 - val_wass_dist: -0.5110
# Epoch 87/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7090 - d_loss: -0.7904 - wass_dist: -1.2329 - g_lr: 5.2935e-04 - d_lr: 2.2017e-04 - val_g_loss: 1.3292 - val_d_loss: -1.3251 - val_wass_dist: 0.1913
# Epoch 88/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7147 - d_loss: -0.7854 - wass_dist: -1.4277 - g_lr: 5.2611e-04 - d_lr: 2.1763e-04 - val_g_loss: 1.5065 - val_d_loss: -1.4892 - val_wass_dist: -0.5193
# Epoch 89/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7409 - d_loss: -0.8061 - wass_dist: -1.5455 - g_lr: 5.2289e-04 - d_lr: 2.1513e-04 - val_g_loss: 1.6784 - val_d_loss: -1.6982 - val_wass_dist: -0.7605
# Epoch 90/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7463 - d_loss: -0.8209 - wass_dist: -1.8458 - g_lr: 5.1969e-04 - d_lr: 2.1265e-04 - val_g_loss: 1.8818 - val_d_loss: -1.9412 - val_wass_dist: -0.7251
# Epoch 91/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7740 - d_loss: -0.8319 - wass_dist: -1.6331 - g_lr: 5.1651e-04 - d_lr: 2.1020e-04 - val_g_loss: 1.6780 - val_d_loss: -1.6965 - val_wass_dist: -0.8519
# Epoch 92/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7671 - d_loss: -0.8307 - wass_dist: -1.4894 - g_lr: 5.1335e-04 - d_lr: 2.0777e-04 - val_g_loss: 1.5543 - val_d_loss: -1.6538 - val_wass_dist: -0.2913
# Epoch 93/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7499 - d_loss: -0.8222 - wass_dist: -1.7658 - g_lr: 5.1021e-04 - d_lr: 2.0538e-04 - val_g_loss: 1.8326 - val_d_loss: -1.7762 - val_wass_dist: -0.5795
# Epoch 94/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8101 - d_loss: -0.8622 - wass_dist: -1.2660 - g_lr: 5.0709e-04 - d_lr: 2.0301e-04 - val_g_loss: 1.2978 - val_d_loss: -1.2950 - val_wass_dist: -0.2407
# Epoch 95/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8386 - d_loss: -0.8700 - wass_dist: -1.0256 - g_lr: 5.0399e-04 - d_lr: 2.0067e-04 - val_g_loss: 1.0892 - val_d_loss: -1.0869 - val_wass_dist: -0.2599
# Epoch 96/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8493 - d_loss: -0.8844 - wass_dist: -1.4400 - g_lr: 5.0091e-04 - d_lr: 1.9836e-04 - val_g_loss: 1.5777 - val_d_loss: -1.5366 - val_wass_dist: -0.4893
# Epoch 97/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8401 - d_loss: -0.8798 - wass_dist: -1.3362 - g_lr: 4.9784e-04 - d_lr: 1.9608e-04 - val_g_loss: 1.3784 - val_d_loss: -1.3197 - val_wass_dist: -0.3490
# Epoch 98/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8336 - d_loss: -0.8839 - wass_dist: -1.5753 - g_lr: 4.9480e-04 - d_lr: 1.9382e-04 - val_g_loss: 1.6068 - val_d_loss: -1.6198 - val_wass_dist: -0.7102
# Epoch 99/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8764 - d_loss: -0.9066 - wass_dist: -1.5887 - g_lr: 4.9177e-04 - d_lr: 1.9158e-04 - val_g_loss: 1.7316 - val_d_loss: -1.6968 - val_wass_dist: -0.7838
# Epoch 100/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9042 - d_loss: -0.9202 - wass_dist: -1.5715 - g_lr: 4.8876e-04 - d_lr: 1.8938e-04 - val_g_loss: 1.6122 - val_d_loss: -1.6487 - val_wass_dist: -0.3642
# Epoch 101/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8967 - d_loss: -0.9228 - wass_dist: -1.4630 - g_lr: 4.8577e-04 - d_lr: 1.8719e-04 - val_g_loss: 1.5273 - val_d_loss: -1.5143 - val_wass_dist: -0.2345
# Epoch 102/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.9380 - d_loss: -0.9422 - wass_dist: -1.7211 - g_lr: 4.8280e-04 - d_lr: 1.8504e-04 - val_g_loss: 1.8196 - val_d_loss: -1.8063 - val_wass_dist: -0.7452
# Epoch 103/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9108 - d_loss: -0.9285 - wass_dist: -1.6603 - g_lr: 4.7985e-04 - d_lr: 1.8291e-04 - val_g_loss: 1.7125 - val_d_loss: -1.6964 - val_wass_dist: -0.6684
# Epoch 104/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9183 - d_loss: -0.9340 - wass_dist: -1.6257 - g_lr: 4.7691e-04 - d_lr: 1.8080e-04 - val_g_loss: 1.7143 - val_d_loss: -1.6860 - val_wass_dist: -0.5154
# Epoch 105/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8930 - d_loss: -0.9311 - wass_dist: -1.3061 - g_lr: 4.7400e-04 - d_lr: 1.7871e-04 - val_g_loss: 1.2940 - val_d_loss: -1.3380 - val_wass_dist: -0.1659
# Epoch 106/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 1.8916 - d_loss: -0.9233 - wass_dist: -1.4992 - g_lr: 4.7110e-04 - d_lr: 1.7666e-04 - val_g_loss: 1.5926 - val_d_loss: -1.5908 - val_wass_dist: -0.6884
# Epoch 107/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.9485 - d_loss: -0.9537 - wass_dist: -1.9123 - g_lr: 4.6822e-04 - d_lr: 1.7462e-04 - val_g_loss: 2.0324 - val_d_loss: -1.9815 - val_wass_dist: -0.8331
# Epoch 108/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9157 - d_loss: -0.9340 - wass_dist: -1.7433 - g_lr: 4.6535e-04 - d_lr: 1.7261e-04 - val_g_loss: 1.7731 - val_d_loss: -1.8196 - val_wass_dist: -0.7777
# Epoch 109/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9194 - d_loss: -0.9290 - wass_dist: -1.7281 - g_lr: 4.6251e-04 - d_lr: 1.7062e-04 - val_g_loss: 1.7939 - val_d_loss: -1.8018 - val_wass_dist: -0.5708
# Epoch 110/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.8857 - d_loss: -0.9100 - wass_dist: -1.5724 - g_lr: 4.5968e-04 - d_lr: 1.6865e-04 - val_g_loss: 1.6852 - val_d_loss: -1.7124 - val_wass_dist: -0.2061
# Epoch 111/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8699 - d_loss: -0.9089 - wass_dist: -1.7406 - g_lr: 4.5686e-04 - d_lr: 1.6671e-04 - val_g_loss: 1.8443 - val_d_loss: -1.8101 - val_wass_dist: -0.7013
# Epoch 112/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9202 - d_loss: -0.9410 - wass_dist: -1.6582 - g_lr: 4.5407e-04 - d_lr: 1.6479e-04 - val_g_loss: 1.7378 - val_d_loss: -1.7587 - val_wass_dist: -0.6253
# Epoch 113/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9842 - d_loss: -0.9796 - wass_dist: -1.5753 - g_lr: 4.5129e-04 - d_lr: 1.6289e-04 - val_g_loss: 1.6262 - val_d_loss: -1.6311 - val_wass_dist: -0.5300
# Epoch 114/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9269 - d_loss: -0.9563 - wass_dist: -1.4710 - g_lr: 4.4853e-04 - d_lr: 1.6101e-04 - val_g_loss: 1.6057 - val_d_loss: -1.6338 - val_wass_dist: -0.1772
# Epoch 115/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9405 - d_loss: -0.9531 - wass_dist: -1.7455 - g_lr: 4.4579e-04 - d_lr: 1.5916e-04 - val_g_loss: 1.8204 - val_d_loss: -1.7868 - val_wass_dist: -0.8199
# Epoch 116/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9137 - d_loss: -0.9351 - wass_dist: -1.4157 - g_lr: 4.4306e-04 - d_lr: 1.5732e-04 - val_g_loss: 1.4996 - val_d_loss: -1.4593 - val_wass_dist: -0.2975
# Epoch 117/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8946 - d_loss: -0.9298 - wass_dist: -1.5826 - g_lr: 4.4035e-04 - d_lr: 1.5551e-04 - val_g_loss: 1.7229 - val_d_loss: -1.7342 - val_wass_dist: -0.6575
# Epoch 118/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9426 - d_loss: -0.9599 - wass_dist: -1.8909 - g_lr: 4.3766e-04 - d_lr: 1.5372e-04 - val_g_loss: 1.9016 - val_d_loss: -2.0001 - val_wass_dist: -0.5777
# Epoch 119/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9959 - d_loss: -1.0036 - wass_dist: -1.9411 - g_lr: 4.3498e-04 - d_lr: 1.5195e-04 - val_g_loss: 2.0571 - val_d_loss: -1.9852 - val_wass_dist: -0.6096
# Epoch 120/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9593 - d_loss: -0.9764 - wass_dist: -1.7490 - g_lr: 4.3232e-04 - d_lr: 1.5020e-04 - val_g_loss: 1.8042 - val_d_loss: -1.8795 - val_wass_dist: -0.5403
# Epoch 121/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9781 - d_loss: -0.9808 - wass_dist: -1.5309 - g_lr: 4.2968e-04 - d_lr: 1.4847e-04 - val_g_loss: 1.5555 - val_d_loss: -1.5566 - val_wass_dist: -0.7104
# Epoch 122/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9321 - d_loss: -0.9595 - wass_dist: -1.4414 - g_lr: 4.2705e-04 - d_lr: 1.4675e-04 - val_g_loss: 1.5142 - val_d_loss: -1.4985 - val_wass_dist: -0.0666
# Epoch 123/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9576 - d_loss: -0.9749 - wass_dist: -1.7194 - g_lr: 4.2443e-04 - d_lr: 1.4506e-04 - val_g_loss: 1.8064 - val_d_loss: -1.7809 - val_wass_dist: -0.4339
# Epoch 124/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9050 - d_loss: -0.9385 - wass_dist: -1.2880 - g_lr: 4.2184e-04 - d_lr: 1.4339e-04 - val_g_loss: 1.2971 - val_d_loss: -1.3089 - val_wass_dist: -0.3952
# Epoch 125/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9098 - d_loss: -0.9427 - wass_dist: -1.8033 - g_lr: 4.1926e-04 - d_lr: 1.4174e-04 - val_g_loss: 1.9535 - val_d_loss: -1.9353 - val_wass_dist: -0.2563
# Epoch 126/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0355 - d_loss: -1.0085 - wass_dist: -1.8798 - g_lr: 4.1669e-04 - d_lr: 1.4011e-04 - val_g_loss: 1.9900 - val_d_loss: -1.9672 - val_wass_dist: -0.5967
# Epoch 127/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0645 - d_loss: -1.0282 - wass_dist: -1.8684 - g_lr: 4.1414e-04 - d_lr: 1.3849e-04 - val_g_loss: 1.8855 - val_d_loss: -1.9531 - val_wass_dist: -0.4621
# Epoch 128/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9525 - d_loss: -0.9712 - wass_dist: -1.5931 - g_lr: 4.1161e-04 - d_lr: 1.3690e-04 - val_g_loss: 1.7327 - val_d_loss: -1.7225 - val_wass_dist: -0.4646
# Epoch 129/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9522 - d_loss: -0.9686 - wass_dist: -1.4170 - g_lr: 4.0909e-04 - d_lr: 1.3532e-04 - val_g_loss: 1.4116 - val_d_loss: -1.4134 - val_wass_dist: -0.3159
# Epoch 130/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9142 - d_loss: -0.9566 - wass_dist: -1.6515 - g_lr: 4.0659e-04 - d_lr: 1.3376e-04 - val_g_loss: 1.7449 - val_d_loss: -1.7059 - val_wass_dist: -0.5786
# Epoch 131/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9289 - d_loss: -0.9655 - wass_dist: -1.7482 - g_lr: 4.0410e-04 - d_lr: 1.3222e-04 - val_g_loss: 1.7611 - val_d_loss: -1.8522 - val_wass_dist: -0.5573
# Epoch 132/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9274 - d_loss: -0.9582 - wass_dist: -1.4929 - g_lr: 4.0163e-04 - d_lr: 1.3070e-04 - val_g_loss: 1.4918 - val_d_loss: -1.5093 - val_wass_dist: -0.7391
# Epoch 133/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.8971 - d_loss: -0.9421 - wass_dist: -1.6997 - g_lr: 3.9918e-04 - d_lr: 1.2919e-04 - val_g_loss: 1.8988 - val_d_loss: -1.8772 - val_wass_dist: -0.4614
# Epoch 134/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0384 - d_loss: -1.0112 - wass_dist: -2.0764 - g_lr: 3.9673e-04 - d_lr: 1.2770e-04 - val_g_loss: 2.2342 - val_d_loss: -2.1959 - val_wass_dist: -0.3577
# Epoch 135/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9913 - d_loss: -0.9894 - wass_dist: -1.4775 - g_lr: 3.9431e-04 - d_lr: 1.2623e-04 - val_g_loss: 1.5360 - val_d_loss: -1.5267 - val_wass_dist: -0.1236
# Epoch 136/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9361 - d_loss: -0.9605 - wass_dist: -1.6809 - g_lr: 3.9189e-04 - d_lr: 1.2477e-04 - val_g_loss: 1.7388 - val_d_loss: -1.7456 - val_wass_dist: -0.3503
# Epoch 137/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9938 - d_loss: -0.9923 - wass_dist: -1.6185 - g_lr: 3.8950e-04 - d_lr: 1.2334e-04 - val_g_loss: 1.7328 - val_d_loss: -1.7189 - val_wass_dist: -0.2236
# Epoch 138/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9686 - d_loss: -0.9854 - wass_dist: -1.7280 - g_lr: 3.8712e-04 - d_lr: 1.2192e-04 - val_g_loss: 1.8266 - val_d_loss: -1.7810 - val_wass_dist: -0.3069
# Epoch 139/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9689 - d_loss: -0.9893 - wass_dist: -1.7185 - g_lr: 3.8475e-04 - d_lr: 1.2051e-04 - val_g_loss: 1.7736 - val_d_loss: -1.7634 - val_wass_dist: -0.4769
# Epoch 140/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9284 - d_loss: -0.9653 - wass_dist: -1.5529 - g_lr: 3.8239e-04 - d_lr: 1.1912e-04 - val_g_loss: 1.5456 - val_d_loss: -1.5343 - val_wass_dist: -0.3943
# Epoch 141/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9741 - d_loss: -0.9861 - wass_dist: -1.5213 - g_lr: 3.8005e-04 - d_lr: 1.1775e-04 - val_g_loss: 1.5002 - val_d_loss: -1.5139 - val_wass_dist: -0.3378
# Epoch 142/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9485 - d_loss: -0.9774 - wass_dist: -1.7202 - g_lr: 3.7773e-04 - d_lr: 1.1639e-04 - val_g_loss: 1.6914 - val_d_loss: -1.7242 - val_wass_dist: -0.2283
# Epoch 143/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0056 - d_loss: -1.0032 - wass_dist: -2.1408 - g_lr: 3.7542e-04 - d_lr: 1.1505e-04 - val_g_loss: 2.2027 - val_d_loss: -2.2076 - val_wass_dist: -0.5507
# Epoch 144/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0166 - d_loss: -1.0108 - wass_dist: -1.8559 - g_lr: 3.7312e-04 - d_lr: 1.1373e-04 - val_g_loss: 1.8898 - val_d_loss: -1.9072 - val_wass_dist: -0.5059
# Epoch 145/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9957 - d_loss: -1.0053 - wass_dist: -1.8834 - g_lr: 3.7084e-04 - d_lr: 1.1242e-04 - val_g_loss: 1.9357 - val_d_loss: -1.9225 - val_wass_dist: -0.4334
# Epoch 146/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.9239 - d_loss: -0.9618 - wass_dist: -1.4202 - g_lr: 3.6857e-04 - d_lr: 1.1112e-04 - val_g_loss: 1.4606 - val_d_loss: -1.4457 - val_wass_dist: -0.0591
# Epoch 147/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9498 - d_loss: -0.9732 - wass_dist: -1.3558 - g_lr: 3.6632e-04 - d_lr: 1.0984e-04 - val_g_loss: 1.3824 - val_d_loss: -1.3970 - val_wass_dist: -0.8015
# Epoch 148/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9315 - d_loss: -0.9632 - wass_dist: -1.5384 - g_lr: 3.6408e-04 - d_lr: 1.0857e-04 - val_g_loss: 1.5549 - val_d_loss: -1.6027 - val_wass_dist: -0.1809
# Epoch 149/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9468 - d_loss: -0.9706 - wass_dist: -1.7535 - g_lr: 3.6185e-04 - d_lr: 1.0732e-04 - val_g_loss: 1.7988 - val_d_loss: -1.7919 - val_wass_dist: 0.2123
# Epoch 150/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9434 - d_loss: -0.9743 - wass_dist: -1.7818 - g_lr: 3.5964e-04 - d_lr: 1.0609e-04 - val_g_loss: 1.8629 - val_d_loss: -1.8171 - val_wass_dist: -0.7733
# Epoch 151/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 2.0289 - d_loss: -1.0207 - wass_dist: -1.8027 - g_lr: 3.5744e-04 - d_lr: 1.0486e-04 - val_g_loss: 1.9299 - val_d_loss: -1.8583 - val_wass_dist: -0.4725
# Epoch 152/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.9360 - d_loss: -0.9777 - wass_dist: -1.4787 - g_lr: 3.5525e-04 - d_lr: 1.0366e-04 - val_g_loss: 1.4832 - val_d_loss: -1.5426 - val_wass_dist: -0.3031
# Epoch 153/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9613 - d_loss: -0.9845 - wass_dist: -1.7911 - g_lr: 3.5308e-04 - d_lr: 1.0246e-04 - val_g_loss: 1.7875 - val_d_loss: -1.8559 - val_wass_dist: -0.2338
# Epoch 154/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8961 - d_loss: -0.9601 - wass_dist: -1.7682 - g_lr: 3.5092e-04 - d_lr: 1.0128e-04 - val_g_loss: 1.7786 - val_d_loss: -1.7783 - val_wass_dist: -0.2526
# Epoch 155/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9927 - d_loss: -1.0058 - wass_dist: -1.8789 - g_lr: 3.4877e-04 - d_lr: 1.0011e-04 - val_g_loss: 1.9699 - val_d_loss: -2.0264 - val_wass_dist: -0.5175
# Epoch 156/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 2.0074 - d_loss: -1.0183 - wass_dist: -1.6864 - g_lr: 3.4664e-04 - d_lr: 9.8960e-05 - val_g_loss: 1.7678 - val_d_loss: -1.7870 - val_wass_dist: -0.1412
# Epoch 157/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.9820 - d_loss: -1.0056 - wass_dist: -1.6386 - g_lr: 3.4452e-04 - d_lr: 9.7820e-05 - val_g_loss: 1.7824 - val_d_loss: -1.7913 - val_wass_dist: -0.1377
# Epoch 158/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9864 - d_loss: -1.0056 - wass_dist: -1.6717 - g_lr: 3.4241e-04 - d_lr: 9.6692e-05 - val_g_loss: 1.7833 - val_d_loss: -1.7711 - val_wass_dist: -0.2393
# Epoch 159/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.9407 - d_loss: -0.9807 - wass_dist: -1.6956 - g_lr: 3.4032e-04 - d_lr: 9.5578e-05 - val_g_loss: 1.7704 - val_d_loss: -1.7547 - val_wass_dist: -0.5617
# Epoch 160/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 2.0410 - d_loss: -1.0279 - wass_dist: -1.7066 - g_lr: 3.3823e-04 - d_lr: 9.4477e-05 - val_g_loss: 1.7957 - val_d_loss: -1.7599 - val_wass_dist: -0.2122
# Epoch 161/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 2.0943 - d_loss: -1.0538 - wass_dist: -1.9882 - g_lr: 3.3616e-04 - d_lr: 9.3388e-05 - val_g_loss: 2.0012 - val_d_loss: -2.0675 - val_wass_dist: -0.3118
# Epoch 162/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 2.0452 - d_loss: -1.0297 - wass_dist: -1.7580 - g_lr: 3.3411e-04 - d_lr: 9.2312e-05 - val_g_loss: 1.8598 - val_d_loss: -1.8080 - val_wass_dist: -0.1809
# Epoch 163/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9801 - d_loss: -0.9986 - wass_dist: -1.8452 - g_lr: 3.3206e-04 - d_lr: 9.1249e-05 - val_g_loss: 1.8672 - val_d_loss: -1.9332 - val_wass_dist: -0.4651
# Epoch 164/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0322 - d_loss: -1.0270 - wass_dist: -1.9354 - g_lr: 3.3003e-04 - d_lr: 9.0197e-05 - val_g_loss: 1.9809 - val_d_loss: -1.9994 - val_wass_dist: -0.3476
# Epoch 165/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9457 - d_loss: -0.9896 - wass_dist: -1.2320 - g_lr: 3.2801e-04 - d_lr: 8.9158e-05 - val_g_loss: 1.2546 - val_d_loss: -1.2255 - val_wass_dist: -0.1657
# Epoch 166/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9687 - d_loss: -1.0016 - wass_dist: -1.8050 - g_lr: 3.2601e-04 - d_lr: 8.8130e-05 - val_g_loss: 1.8591 - val_d_loss: -1.8293 - val_wass_dist: -0.2857
# Epoch 167/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9066 - d_loss: -0.9779 - wass_dist: -1.5786 - g_lr: 3.2401e-04 - d_lr: 8.7115e-05 - val_g_loss: 1.5968 - val_d_loss: -1.6512 - val_wass_dist: -0.4803
# Epoch 168/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8939 - d_loss: -0.9713 - wass_dist: -1.7562 - g_lr: 3.2203e-04 - d_lr: 8.6111e-05 - val_g_loss: 1.6956 - val_d_loss: -1.7650 - val_wass_dist: -0.2408
# Epoch 169/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8723 - d_loss: -0.9588 - wass_dist: -1.6337 - g_lr: 3.2006e-04 - d_lr: 8.5119e-05 - val_g_loss: 1.7122 - val_d_loss: -1.7414 - val_wass_dist: -0.0249
# Epoch 170/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9171 - d_loss: -0.9823 - wass_dist: -1.7491 - g_lr: 3.1810e-04 - d_lr: 8.4138e-05 - val_g_loss: 1.8299 - val_d_loss: -1.8052 - val_wass_dist: -0.4385
# Epoch 171/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.9253 - d_loss: -0.9868 - wass_dist: -1.6649 - g_lr: 3.1616e-04 - d_lr: 8.3169e-05 - val_g_loss: 1.6584 - val_d_loss: -1.7470 - val_wass_dist: -0.2562
# Epoch 172/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.9470 - d_loss: -0.9942 - wass_dist: -1.8142 - g_lr: 3.1422e-04 - d_lr: 8.2210e-05 - val_g_loss: 1.8490 - val_d_loss: -1.8896 - val_wass_dist: -0.3850
# Epoch 173/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8142 - d_loss: -0.9301 - wass_dist: -1.3736 - g_lr: 3.1230e-04 - d_lr: 8.1263e-05 - val_g_loss: 1.4113 - val_d_loss: -1.4145 - val_wass_dist: -0.1692
# Epoch 174/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9290 - d_loss: -0.9867 - wass_dist: -1.9647 - g_lr: 3.1039e-04 - d_lr: 8.0327e-05 - val_g_loss: 2.0162 - val_d_loss: -2.0399 - val_wass_dist: -0.4067
# Epoch 175/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0110 - d_loss: -1.0242 - wass_dist: -1.3702 - g_lr: 3.0849e-04 - d_lr: 7.9401e-05 - val_g_loss: 1.5394 - val_d_loss: -1.4534 - val_wass_dist: -0.4361
# Epoch 176/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9335 - d_loss: -0.9916 - wass_dist: -1.7381 - g_lr: 3.0661e-04 - d_lr: 7.8486e-05 - val_g_loss: 1.7893 - val_d_loss: -1.8000 - val_wass_dist: -0.5921
# Epoch 177/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8595 - d_loss: -0.9557 - wass_dist: -1.6211 - g_lr: 3.0473e-04 - d_lr: 7.7582e-05 - val_g_loss: 1.5746 - val_d_loss: -1.6453 - val_wass_dist: -0.1589
# Epoch 178/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.9043 - d_loss: -0.9768 - wass_dist: -1.9015 - g_lr: 3.0287e-04 - d_lr: 7.6688e-05 - val_g_loss: 1.9933 - val_d_loss: -1.9494 - val_wass_dist: -0.3203
# Epoch 179/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0067 - d_loss: -1.0260 - wass_dist: -1.7101 - g_lr: 3.0101e-04 - d_lr: 7.5804e-05 - val_g_loss: 1.7712 - val_d_loss: -1.7509 - val_wass_dist: -0.6499
# Epoch 180/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.1087 - d_loss: -1.0695 - wass_dist: -1.8280 - g_lr: 2.9917e-04 - d_lr: 7.4931e-05 - val_g_loss: 1.9021 - val_d_loss: -1.9176 - val_wass_dist: -0.3719
# Epoch 181/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 2.0329 - d_loss: -1.0383 - wass_dist: -1.6619 - g_lr: 2.9734e-04 - d_lr: 7.4067e-05 - val_g_loss: 1.7799 - val_d_loss: -1.7530 - val_wass_dist: 0.0192
# Epoch 182/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.8349 - d_loss: -0.9533 - wass_dist: -1.5576 - g_lr: 2.9552e-04 - d_lr: 7.3214e-05 - val_g_loss: 1.5494 - val_d_loss: -1.5560 - val_wass_dist: 0.0914
# Epoch 183/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8859 - d_loss: -0.9698 - wass_dist: -1.7736 - g_lr: 2.9372e-04 - d_lr: 7.2370e-05 - val_g_loss: 1.8681 - val_d_loss: -1.9191 - val_wass_dist: -0.5516
# Epoch 184/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.8924 - d_loss: -0.9777 - wass_dist: -1.6653 - g_lr: 2.9192e-04 - d_lr: 7.1536e-05 - val_g_loss: 1.7704 - val_d_loss: -1.7772 - val_wass_dist: -0.1847
# Epoch 185/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.8274 - d_loss: -0.9453 - wass_dist: -1.8313 - g_lr: 2.9013e-04 - d_lr: 7.0712e-05 - val_g_loss: 1.8416 - val_d_loss: -1.9383 - val_wass_dist: -0.1119
# Epoch 186/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.8221 - d_loss: -0.9407 - wass_dist: -1.8194 - g_lr: 2.8836e-04 - d_lr: 6.9897e-05 - val_g_loss: 1.8372 - val_d_loss: -1.8892 - val_wass_dist: -0.2090
# Epoch 187/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.8271 - d_loss: -0.9425 - wass_dist: -1.5852 - g_lr: 2.8660e-04 - d_lr: 6.9092e-05 - val_g_loss: 1.6208 - val_d_loss: -1.6334 - val_wass_dist: -0.3014
# Epoch 188/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8711 - d_loss: -0.9655 - wass_dist: -1.4891 - g_lr: 2.8484e-04 - d_lr: 6.8296e-05 - val_g_loss: 1.6180 - val_d_loss: -1.5050 - val_wass_dist: -0.3438
# Epoch 189/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.8628 - d_loss: -0.9631 - wass_dist: -1.4695 - g_lr: 2.8310e-04 - d_lr: 6.7509e-05 - val_g_loss: 1.5312 - val_d_loss: -1.4856 - val_wass_dist: -0.3551
# Epoch 190/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9107 - d_loss: -0.9844 - wass_dist: -1.6775 - g_lr: 2.8137e-04 - d_lr: 6.6731e-05 - val_g_loss: 1.7561 - val_d_loss: -1.7590 - val_wass_dist: -0.1669
# Epoch 191/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 1.8592 - d_loss: -0.9608 - wass_dist: -1.7264 - g_lr: 2.7965e-04 - d_lr: 6.5962e-05 - val_g_loss: 1.7973 - val_d_loss: -1.8106 - val_wass_dist: -0.0629
# Epoch 192/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9052 - d_loss: -0.9840 - wass_dist: -1.7406 - g_lr: 2.7794e-04 - d_lr: 6.5202e-05 - val_g_loss: 1.7555 - val_d_loss: -1.8264 - val_wass_dist: -0.2797
# Epoch 193/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8169 - d_loss: -0.9406 - wass_dist: -1.7051 - g_lr: 2.7624e-04 - d_lr: 6.4450e-05 - val_g_loss: 1.7892 - val_d_loss: -1.7899 - val_wass_dist: -0.3703
# Epoch 194/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.8011 - d_loss: -0.9380 - wass_dist: -1.7579 - g_lr: 2.7455e-04 - d_lr: 6.3708e-05 - val_g_loss: 1.7248 - val_d_loss: -1.7682 - val_wass_dist: -0.3082
# Epoch 195/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.7977 - d_loss: -0.9382 - wass_dist: -1.6901 - g_lr: 2.7287e-04 - d_lr: 6.2974e-05 - val_g_loss: 1.7078 - val_d_loss: -1.7412 - val_wass_dist: -0.2673
# Epoch 196/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8470 - d_loss: -0.9604 - wass_dist: -1.7454 - g_lr: 2.7120e-04 - d_lr: 6.2248e-05 - val_g_loss: 1.7642 - val_d_loss: -1.7811 - val_wass_dist: -0.2375
# Epoch 197/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8897 - d_loss: -0.9819 - wass_dist: -1.5392 - g_lr: 2.6954e-04 - d_lr: 6.1531e-05 - val_g_loss: 1.6416 - val_d_loss: -1.6134 - val_wass_dist: -0.1840
# Epoch 198/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8945 - d_loss: -0.9807 - wass_dist: -1.6769 - g_lr: 2.6789e-04 - d_lr: 6.0822e-05 - val_g_loss: 1.7785 - val_d_loss: -1.8120 - val_wass_dist: -0.5043
# Epoch 199/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 1.9202 - d_loss: -0.9939 - wass_dist: -1.8267 - g_lr: 2.6625e-04 - d_lr: 6.0121e-05 - val_g_loss: 1.8706 - val_d_loss: -1.8754 - val_wass_dist: -0.0589
# Epoch 200/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8618 - d_loss: -0.9701 - wass_dist: -1.6357 - g_lr: 2.6462e-04 - d_lr: 5.9428e-05 - val_g_loss: 1.7376 - val_d_loss: -1.7279 - val_wass_dist: -0.2065
# Epoch 201/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8508 - d_loss: -0.9674 - wass_dist: -1.8528 - g_lr: 2.6300e-04 - d_lr: 5.8743e-05 - val_g_loss: 1.9255 - val_d_loss: -1.8901 - val_wass_dist: -0.1226
# Epoch 202/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.9050 - d_loss: -0.9887 - wass_dist: -1.7503 - g_lr: 2.6140e-04 - d_lr: 5.8067e-05 - val_g_loss: 1.8459 - val_d_loss: -1.8146 - val_wass_dist: -0.1179
# Epoch 203/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8967 - d_loss: -0.9868 - wass_dist: -1.8119 - g_lr: 2.5980e-04 - d_lr: 5.7397e-05 - val_g_loss: 1.8821 - val_d_loss: -1.8467 - val_wass_dist: -0.2440
# Epoch 204/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 1.8941 - d_loss: -0.9829 - wass_dist: -1.5988 - g_lr: 2.5821e-04 - d_lr: 5.6736e-05 - val_g_loss: 1.6586 - val_d_loss: -1.6602 - val_wass_dist: -0.4076
# Epoch 205/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 1.7786 - d_loss: -0.9314 - wass_dist: -1.5084 - g_lr: 2.5663e-04 - d_lr: 5.6082e-05 - val_g_loss: 1.5976 - val_d_loss: -1.5831 - val_wass_dist: -0.1301
# Epoch 206/500
# ...
# Epoch 433/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.7894 - d_loss: -0.4680 - wass_dist: -0.6935 - g_lr: 6.3351e-05 - d_lr: 3.9923e-06 - val_g_loss: 0.7219 - val_d_loss: -0.7475 - val_wass_dist: -0.0825
# Epoch 434/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 0.7188 - d_loss: -0.4296 - wass_dist: -0.5921 - g_lr: 6.2963e-05 - d_lr: 3.9463e-06 - val_g_loss: 0.5842 - val_d_loss: -0.6175 - val_wass_dist: -0.1290
# Epoch 435/500
# 453/453 [==============================] - 9s 20ms/step - g_loss: 0.7055 - d_loss: -0.4226 - wass_dist: -0.5548 - g_lr: 6.2578e-05 - d_lr: 3.9009e-06 - val_g_loss: 0.4945 - val_d_loss: -0.5335 - val_wass_dist: -0.3921
# Epoch 436/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6874 - d_loss: -0.4116 - wass_dist: -0.5958 - g_lr: 6.2195e-05 - d_lr: 3.8559e-06 - val_g_loss: 0.5993 - val_d_loss: -0.5854 - val_wass_dist: -0.1112
# Epoch 437/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6725 - d_loss: -0.4025 - wass_dist: -0.4592 - g_lr: 6.1815e-05 - d_lr: 3.8115e-06 - val_g_loss: 0.4348 - val_d_loss: -0.5031 - val_wass_dist: -0.1929
# Epoch 438/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.6734 - d_loss: -0.4081 - wass_dist: -0.6512 - g_lr: 6.1437e-05 - d_lr: 3.7676e-06 - val_g_loss: 0.5659 - val_d_loss: -0.6110 - val_wass_dist: -0.0073
# Epoch 439/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.6973 - d_loss: -0.4208 - wass_dist: -0.6705 - g_lr: 6.1061e-05 - d_lr: 3.7241e-06 - val_g_loss: 0.6475 - val_d_loss: -0.6468 - val_wass_dist: 0.1581
# Epoch 440/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.7077 - d_loss: -0.4243 - wass_dist: -0.5730 - g_lr: 6.0687e-05 - d_lr: 3.6812e-06 - val_g_loss: 0.5499 - val_d_loss: -0.5342 - val_wass_dist: 0.0037
# Epoch 441/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.7593 - d_loss: -0.4535 - wass_dist: -0.6552 - g_lr: 6.0316e-05 - d_lr: 3.6388e-06 - val_g_loss: 0.6983 - val_d_loss: -0.7725 - val_wass_dist: -0.2471
# Epoch 442/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.7189 - d_loss: -0.4273 - wass_dist: -0.6333 - g_lr: 5.9947e-05 - d_lr: 3.5969e-06 - val_g_loss: 0.7602 - val_d_loss: -0.7030 - val_wass_dist: -0.1705
# Epoch 443/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6963 - d_loss: -0.4176 - wass_dist: -0.7151 - g_lr: 5.9581e-05 - d_lr: 3.5554e-06 - val_g_loss: 0.7172 - val_d_loss: -0.6140 - val_wass_dist: -0.4150
# Epoch 444/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6636 - d_loss: -0.3953 - wass_dist: -0.5599 - g_lr: 5.9216e-05 - d_lr: 3.5145e-06 - val_g_loss: 0.4696 - val_d_loss: -0.5595 - val_wass_dist: -0.1786
# Epoch 445/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.6938 - d_loss: -0.4168 - wass_dist: -0.6226 - g_lr: 5.8854e-05 - d_lr: 3.4740e-06 - val_g_loss: 0.6127 - val_d_loss: -0.5748 - val_wass_dist: -0.2343
# Epoch 446/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6648 - d_loss: -0.4011 - wass_dist: -0.6573 - g_lr: 5.8494e-05 - d_lr: 3.4339e-06 - val_g_loss: 0.5923 - val_d_loss: -0.5907 - val_wass_dist: 0.0224
# Epoch 447/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6421 - d_loss: -0.3849 - wass_dist: -0.5716 - g_lr: 5.8136e-05 - d_lr: 3.3944e-06 - val_g_loss: 0.5095 - val_d_loss: -0.5570 - val_wass_dist: -0.2465
# Epoch 448/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6640 - d_loss: -0.3957 - wass_dist: -0.6256 - g_lr: 5.7781e-05 - d_lr: 3.3553e-06 - val_g_loss: 0.6678 - val_d_loss: -0.6499 - val_wass_dist: 0.0054
# Epoch 449/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6659 - d_loss: -0.4030 - wass_dist: -0.4787 - g_lr: 5.7427e-05 - d_lr: 3.3166e-06 - val_g_loss: 0.5436 - val_d_loss: -0.5014 - val_wass_dist: -0.2115
# Epoch 450/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6179 - d_loss: -0.3744 - wass_dist: -0.5031 - g_lr: 5.7076e-05 - d_lr: 3.2784e-06 - val_g_loss: 0.5592 - val_d_loss: -0.5455 - val_wass_dist: -0.0102
# Epoch 451/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6549 - d_loss: -0.3948 - wass_dist: -0.5394 - g_lr: 5.6727e-05 - d_lr: 3.2406e-06 - val_g_loss: 0.5390 - val_d_loss: -0.5037 - val_wass_dist: -0.1465
# Epoch 452/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6510 - d_loss: -0.3919 - wass_dist: -0.4940 - g_lr: 5.6380e-05 - d_lr: 3.2033e-06 - val_g_loss: 0.5852 - val_d_loss: -0.5695 - val_wass_dist: -0.4598
# Epoch 453/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.6039 - d_loss: -0.3661 - wass_dist: -0.5811 - g_lr: 5.6035e-05 - d_lr: 3.1664e-06 - val_g_loss: 0.4811 - val_d_loss: -0.6088 - val_wass_dist: -0.1824
# Epoch 454/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.5946 - d_loss: -0.3622 - wass_dist: -0.6289 - g_lr: 5.5692e-05 - d_lr: 3.1299e-06 - val_g_loss: 0.5645 - val_d_loss: -0.6073 - val_wass_dist: -0.1767
# Epoch 455/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6034 - d_loss: -0.3681 - wass_dist: -0.5261 - g_lr: 5.5351e-05 - d_lr: 3.0938e-06 - val_g_loss: 0.4980 - val_d_loss: -0.4267 - val_wass_dist: 0.1030
# Epoch 456/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6298 - d_loss: -0.3810 - wass_dist: -0.6035 - g_lr: 5.5013e-05 - d_lr: 3.0582e-06 - val_g_loss: 0.5675 - val_d_loss: -0.6015 - val_wass_dist: -0.0803
# Epoch 457/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6683 - d_loss: -0.4024 - wass_dist: -0.6045 - g_lr: 5.4676e-05 - d_lr: 3.0229e-06 - val_g_loss: 0.6485 - val_d_loss: -0.6425 - val_wass_dist: 0.1331
# Epoch 458/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.7339 - d_loss: -0.4357 - wass_dist: -0.5028 - g_lr: 5.4342e-05 - d_lr: 2.9881e-06 - val_g_loss: 0.5815 - val_d_loss: -0.5315 - val_wass_dist: -0.2085
# Epoch 459/500
# 453/453 [==============================] - 11s 22ms/step - g_loss: 0.6736 - d_loss: -0.4006 - wass_dist: -0.5810 - g_lr: 5.4009e-05 - d_lr: 2.9537e-06 - val_g_loss: 0.5836 - val_d_loss: -0.6003 - val_wass_dist: 0.0575
# Epoch 460/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.6737 - d_loss: -0.4046 - wass_dist: -0.6047 - g_lr: 5.3679e-05 - d_lr: 2.9196e-06 - val_g_loss: 0.6893 - val_d_loss: -0.6293 - val_wass_dist: -0.2186
# Epoch 461/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6545 - d_loss: -0.3930 - wass_dist: -0.5756 - g_lr: 5.3351e-05 - d_lr: 2.8860e-06 - val_g_loss: 0.6080 - val_d_loss: -0.5586 - val_wass_dist: 0.0073
# Epoch 462/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6541 - d_loss: -0.3921 - wass_dist: -0.5950 - g_lr: 5.3024e-05 - d_lr: 2.8527e-06 - val_g_loss: 0.6138 - val_d_loss: -0.5636 - val_wass_dist: -0.1344
# Epoch 463/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6363 - d_loss: -0.3795 - wass_dist: -0.5752 - g_lr: 5.2700e-05 - d_lr: 2.8198e-06 - val_g_loss: 0.5887 - val_d_loss: -0.5954 - val_wass_dist: -0.3896
# Epoch 464/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.6063 - d_loss: -0.3664 - wass_dist: -0.5290 - g_lr: 5.2378e-05 - d_lr: 2.7874e-06 - val_g_loss: 0.5179 - val_d_loss: -0.5290 - val_wass_dist: -0.0290
# Epoch 465/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5628 - d_loss: -0.3422 - wass_dist: -0.5115 - g_lr: 5.2057e-05 - d_lr: 2.7552e-06 - val_g_loss: 0.4868 - val_d_loss: -0.4389 - val_wass_dist: -0.1362
# Epoch 466/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5442 - d_loss: -0.3330 - wass_dist: -0.3682 - g_lr: 5.1739e-05 - d_lr: 2.7235e-06 - val_g_loss: 0.3499 - val_d_loss: -0.3404 - val_wass_dist: -0.1446
# Epoch 467/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5240 - d_loss: -0.3221 - wass_dist: -0.4668 - g_lr: 5.1422e-05 - d_lr: 2.6921e-06 - val_g_loss: 0.4000 - val_d_loss: -0.4554 - val_wass_dist: -0.1474
# Epoch 468/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.5153 - d_loss: -0.3157 - wass_dist: -0.5383 - g_lr: 5.1108e-05 - d_lr: 2.6611e-06 - val_g_loss: 0.4832 - val_d_loss: -0.5062 - val_wass_dist: -0.5089
# Epoch 469/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.5009 - d_loss: -0.3135 - wass_dist: -0.4822 - g_lr: 5.0795e-05 - d_lr: 2.6304e-06 - val_g_loss: 0.4530 - val_d_loss: -0.4717 - val_wass_dist: -0.5981
# Epoch 470/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5269 - d_loss: -0.3245 - wass_dist: -0.5686 - g_lr: 5.0484e-05 - d_lr: 2.6001e-06 - val_g_loss: 0.5867 - val_d_loss: -0.5442 - val_wass_dist: -0.1159
# Epoch 471/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.5628 - d_loss: -0.3440 - wass_dist: -0.4348 - g_lr: 5.0176e-05 - d_lr: 2.5702e-06 - val_g_loss: 0.4887 - val_d_loss: -0.4803 - val_wass_dist: 0.0873
# Epoch 472/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5823 - d_loss: -0.3558 - wass_dist: -0.4475 - g_lr: 4.9869e-05 - d_lr: 2.5405e-06 - val_g_loss: 0.5299 - val_d_loss: -0.4604 - val_wass_dist: -0.1657
# Epoch 473/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.5909 - d_loss: -0.3560 - wass_dist: -0.5765 - g_lr: 4.9564e-05 - d_lr: 2.5113e-06 - val_g_loss: 0.5357 - val_d_loss: -0.5391 - val_wass_dist: 0.0948
# Epoch 474/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5426 - d_loss: -0.3337 - wass_dist: -0.5436 - g_lr: 4.9261e-05 - d_lr: 2.4823e-06 - val_g_loss: 0.5471 - val_d_loss: -0.5824 - val_wass_dist: -0.1431
# Epoch 475/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5332 - d_loss: -0.3261 - wass_dist: -0.4033 - g_lr: 4.8959e-05 - d_lr: 2.4537e-06 - val_g_loss: 0.3606 - val_d_loss: -0.3883 - val_wass_dist: -0.1991
# Epoch 476/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5096 - d_loss: -0.3146 - wass_dist: -0.4384 - g_lr: 4.8660e-05 - d_lr: 2.4255e-06 - val_g_loss: 0.3582 - val_d_loss: -0.4181 - val_wass_dist: -0.3096
# Epoch 477/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5050 - d_loss: -0.3141 - wass_dist: -0.3826 - g_lr: 4.8362e-05 - d_lr: 2.3975e-06 - val_g_loss: 0.3780 - val_d_loss: -0.4763 - val_wass_dist: -0.3062
# Epoch 478/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5186 - d_loss: -0.3218 - wass_dist: -0.4555 - g_lr: 4.8066e-05 - d_lr: 2.3699e-06 - val_g_loss: 0.4537 - val_d_loss: -0.3708 - val_wass_dist: -0.2404
# Epoch 479/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5246 - d_loss: -0.3211 - wass_dist: -0.6170 - g_lr: 4.7772e-05 - d_lr: 2.3426e-06 - val_g_loss: 0.5381 - val_d_loss: -0.5556 - val_wass_dist: -0.1361
# Epoch 480/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5109 - d_loss: -0.3159 - wass_dist: -0.5675 - g_lr: 4.7480e-05 - d_lr: 2.3156e-06 - val_g_loss: 0.5881 - val_d_loss: -0.5803 - val_wass_dist: -0.2567
# Epoch 481/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5182 - d_loss: -0.3200 - wass_dist: -0.4453 - g_lr: 4.7190e-05 - d_lr: 2.2889e-06 - val_g_loss: 0.5054 - val_d_loss: -0.4728 - val_wass_dist: -0.1479
# Epoch 482/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5493 - d_loss: -0.3375 - wass_dist: -0.4631 - g_lr: 4.6901e-05 - d_lr: 2.2625e-06 - val_g_loss: 0.5350 - val_d_loss: -0.4697 - val_wass_dist: -0.2223
# Epoch 483/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5503 - d_loss: -0.3364 - wass_dist: -0.4735 - g_lr: 4.6614e-05 - d_lr: 2.2365e-06 - val_g_loss: 0.5094 - val_d_loss: -0.4579 - val_wass_dist: 0.0985
# Epoch 484/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5302 - d_loss: -0.3253 - wass_dist: -0.4115 - g_lr: 4.6329e-05 - d_lr: 2.2107e-06 - val_g_loss: 0.4679 - val_d_loss: -0.3909 - val_wass_dist: -0.2818
# Epoch 485/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5112 - d_loss: -0.3164 - wass_dist: -0.4979 - g_lr: 4.6046e-05 - d_lr: 2.1852e-06 - val_g_loss: 0.4672 - val_d_loss: -0.4069 - val_wass_dist: 0.0601
# Epoch 486/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4965 - d_loss: -0.3055 - wass_dist: -0.5092 - g_lr: 4.5764e-05 - d_lr: 2.1600e-06 - val_g_loss: 0.5116 - val_d_loss: -0.4840 - val_wass_dist: -0.1023
# Epoch 487/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5222 - d_loss: -0.3165 - wass_dist: -0.4769 - g_lr: 4.5484e-05 - d_lr: 2.1351e-06 - val_g_loss: 0.4632 - val_d_loss: -0.4196 - val_wass_dist: -0.0921
# Epoch 488/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5134 - d_loss: -0.3136 - wass_dist: -0.5143 - g_lr: 4.5206e-05 - d_lr: 2.1105e-06 - val_g_loss: 0.5044 - val_d_loss: -0.5657 - val_wass_dist: 0.0382
# Epoch 489/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4829 - d_loss: -0.2940 - wass_dist: -0.3531 - g_lr: 4.4929e-05 - d_lr: 2.0862e-06 - val_g_loss: 0.3055 - val_d_loss: -0.3949 - val_wass_dist: -0.0292
# Epoch 490/500
# 453/453 [==============================] - 10s 22ms/step - g_loss: 0.4881 - d_loss: -0.2993 - wass_dist: -0.4114 - g_lr: 4.4654e-05 - d_lr: 2.0622e-06 - val_g_loss: 0.4851 - val_d_loss: -0.3390 - val_wass_dist: -0.0540
# Epoch 491/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.5249 - d_loss: -0.3229 - wass_dist: -0.4750 - g_lr: 4.4381e-05 - d_lr: 2.0384e-06 - val_g_loss: 0.4040 - val_d_loss: -0.4563 - val_wass_dist: 0.0482
# Epoch 492/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.5111 - d_loss: -0.3146 - wass_dist: -0.4108 - g_lr: 4.4110e-05 - d_lr: 2.0149e-06 - val_g_loss: 0.3778 - val_d_loss: -0.4219 - val_wass_dist: -0.1633
# Epoch 493/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4731 - d_loss: -0.2957 - wass_dist: -0.4350 - g_lr: 4.3840e-05 - d_lr: 1.9917e-06 - val_g_loss: 0.4302 - val_d_loss: -0.3475 - val_wass_dist: -0.2107
# Epoch 494/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4858 - d_loss: -0.2998 - wass_dist: -0.4341 - g_lr: 4.3572e-05 - d_lr: 1.9688e-06 - val_g_loss: 0.4403 - val_d_loss: -0.4207 - val_wass_dist: -0.2434
# Epoch 495/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4935 - d_loss: -0.3008 - wass_dist: -0.3903 - g_lr: 4.3305e-05 - d_lr: 1.9461e-06 - val_g_loss: 0.3644 - val_d_loss: -0.4080 - val_wass_dist: -0.1796
# Epoch 496/500
# 453/453 [==============================] - 10s 20ms/step - g_loss: 0.4823 - d_loss: -0.2988 - wass_dist: -0.4488 - g_lr: 4.3040e-05 - d_lr: 1.9236e-06 - val_g_loss: 0.4893 - val_d_loss: -0.4911 - val_wass_dist: -0.2700
# Epoch 497/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.5065 - d_loss: -0.3112 - wass_dist: -0.3676 - g_lr: 4.2777e-05 - d_lr: 1.9015e-06 - val_g_loss: 0.3994 - val_d_loss: -0.3280 - val_wass_dist: -0.0857
# Epoch 498/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4833 - d_loss: -0.2932 - wass_dist: -0.4444 - g_lr: 4.2515e-05 - d_lr: 1.8796e-06 - val_g_loss: 0.4530 - val_d_loss: -0.4468 - val_wass_dist: -0.2648
# Epoch 499/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4722 - d_loss: -0.2937 - wass_dist: -0.4207 - g_lr: 4.2255e-05 - d_lr: 1.8579e-06 - val_g_loss: 0.3895 - val_d_loss: -0.4012 - val_wass_dist: -0.0648
# Epoch 500/500
# 453/453 [==============================] - 10s 21ms/step - g_loss: 0.4414 - d_loss: -0.2743 - wass_dist: -0.3363 - g_lr: 4.1997e-05 - d_lr: 1.8365e-06 - val_g_loss: 0.3225 - val_d_loss: -0.3452 - val_wass_dist: -0.3203

# %%
plt.figure(figsize=(16, 5), dpi=100)

start_epoch = 1

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#3288bd", label="generator")
plt.plot(train.history["d_loss"][start_epoch:], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_loss"], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Learning rate scheduling", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Learning rate", fontsize=12)
plt.plot(train.history["g_lr"], color="#3288bd", label="generator")
plt.plot(train.history["d_lr"], color="#fc8d59", label="discriminator")
# plt.plot(train.history["r_lr"], color="#4dac26", label="referee")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.show()

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Generator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["g_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_g_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Discriminator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["d_loss"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_d_loss"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.show()

# %%
plt.figure(figsize=(24, 5), dpi=100)

# plt.subplot(1, 3, 1)
# plt.title("Metric curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Accuracy", fontsize=12)
# plt.plot(train.history["accuracy"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_accuracy"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 3, 2)
plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Wasserstein distance", fontsize=12)
plt.plot(train.history["wass_dist"][start_epoch:], color="#d01c8b", label="training set")
plt.plot(train.history["val_wass_dist"][start_epoch:], color="#4dac26", label="validation set")
plt.legend(loc="lower right", fontsize=10)
# plt.yscale("log")

# plt.subplot(1, 3, 3)
# plt.title("Referee learning curves", fontsize=14)
# plt.xlabel("Training epochs", fontsize=12)
# plt.ylabel("Binary cross-entropy", fontsize=12)
# plt.plot(train.history["r_loss"][start_epoch:], color="#d01c8b", label="training set")
# plt.plot(train.history["val_r_loss"][start_epoch:], color="#4dac26", label="validation set")
# plt.legend(loc="center right", fontsize=10)

plt.show()
# Out:
# Si è verificato un arresto anomalo del kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente. Esaminare il codice nelle celle per identificare una possibile causa dell'errore. Per altre informazioni, fare clic su <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a>. Per altri dettagli, vedere Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
train_history = train.history.copy()
pd.DataFrame(train_history).to_csv(f"./exports/{prefix}-GlobalPID-nm-kaon-train.csv")

# %% [markdown]
# ## A first, rough validation
#
# TBA

# %%
reader_test = FeatherReader(environ.get("GLOBALPID_NM_KAON_TEST_DATA", f"{DATA_PATH}/GlobalPID-nm-kaon-{SAMPLE}-test"), max_files=50)
head = reader_test.as_dask_dataframe().head(20_000_000, npartitions=-1)

# %%
X_test = head[reader_test.features].values
y_test = head[reader_test.labels].values
preds = gan.generator.predict(X_test, batch_size=50_000)
# Out:
# 400/400 [==============================] - 1s 3ms/step

# %%
X_test.shape, y_test.shape, preds.shape
# Out:
# ((20000000, 8), (20000000, 8), (20000000, 8))

# %%
# referee_true = gan.referee.predict((X_test, y_test), batch_size=50_000)
# referee_pred = gan.referee.predict((X_test, preds), batch_size=50_000)

# %%
# plt.figure(figsize=(8, 5), dpi=100)
# plt.xlabel("Referee score", fontsize=12)
# plt.ylabel("Candidates", fontsize=12)
# 
# bins = np.linspace(0.0, 1.0, 101)
# plt.hist(referee_true, bins=bins, label="Detailed Simulation")
# plt.hist(referee_pred, bins=bins, histtype="step", lw=2, label="GAN-based model")
# plt.legend(fontsize=10)
# 
# plt.show()

# %%
# from pidgan.optimization.scores import KSDistance
# 
# ks_dist = KSDistance()
# ks_score = ks_dist(referee_true, referee_pred, bins=100, range=[0.0, 1.0])
# 
# print(f"K-S distance (referee): {ks_score:.3f}")

# %%
# chunk_size = 5_000_000
# 
# np.savez_compressed(
#     f"./exports/{prefix}-Rich-kaon-referee.npz",
#     referee_true=referee_true[:chunk_size],
#     referee_pred=referee_pred[:chunk_size],
#     ks_score=ks_score,
# )

# %%
import pickle

models_dir = "/home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models"

with open(f"{models_dir}/tX_{SAMPLE}.pkl", "rb") as file:
    X_scaler = pickle.load(file)

with open(f"{models_dir}/tY_{SAMPLE}.pkl", "rb") as file:
    y_scaler = pickle.load(file)

# %%
from pidgan.utils.preprocessing import invertColumnTransformer
    
X_post = invertColumnTransformer(X_scaler, X_test)
y_post = invertColumnTransformer(y_scaler, y_test)
preds_post = invertColumnTransformer(y_scaler, preds)

# %%
plt.figure(figsize=(32, 15), dpi=100)

# PIDe
plt.subplot(3, 4, 1)
bins = np.linspace(-20.0, 10.0, 101)
plt.xlabel("$\mathtt{PIDe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDK
plt.subplot(3, 4, 2)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDp
plt.subplot(3, 4, 3)
bins = np.linspace(-125.0, 75.0, 101)
plt.xlabel("$\mathtt{PIDp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDpK
plt.subplot(3, 4, 4)
bins = np.linspace(-100.0, 50.0, 101)
plt.xlabel("$\mathtt{PIDpK}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDp")][:500000] - y_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDp")][:500000] - preds_post[:, y_vars.index("PIDK")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNe
plt.subplot(3, 4, 5)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNe}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNe")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNpi
plt.subplot(3, 4, 6)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNpi}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNpi")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNpi")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# ProbNNk
plt.subplot(3, 4, 7)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNk}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNk")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNk")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# ProbNNp
plt.subplot(3, 4, 8)
bins = np.linspace(0.0, 1.0, 101)
plt.xlabel("$\mathtt{ProbNNp}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("ProbNNp")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    np.clip(preds_post[:, y_vars.index("ProbNNp")][:500000], 0.0, 1.0),
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
plt.yscale("log")

# PIDmu
plt.subplot(3, 4, 9)
bins = np.linspace(-15.0, 25.0, 101)
plt.xlabel("$\mathtt{PIDmu}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)

# PIDmue
plt.subplot(3, 4, 10)
bins = np.linspace(-20.0, 30.0, 101)
plt.xlabel("$\mathtt{PIDmue}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(
    y_post[:, y_vars.index("PIDmu")][:500000] - y_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    label="Detailed Simulation",
)
plt.hist(
    preds_post[:, y_vars.index("PIDmu")][:500000] - preds_post[:, y_vars.index("PIDe")][:500000],
    bins=bins,
    histtype="step",
    lw=2, 
    label="GAN-based model",
)
plt.legend(fontsize=10)
# plt.yscale("log")

plt.show()

# %% [markdown]
# ## Data and model export
#
# To simplify the preparation of LHCb figures and freeze the results obtained, the output of the trained model is exported and NumPy file and then uploaded to GitLab.

# %%
np.savez_compressed(
    f"./exports/{prefix}-GlobalPID-nm-kaon-results.npz",
    feat_vars=np.array(x_vars[:3] + [x_vars[-1]]),
    label_vars=np.array(y_vars),
    results=np.c_[X_post[:, :3], X_post[:, -1], y_post, preds_post][:750_000],
)

# %% [markdown]
# Finally, we export the Keras model to the same folder where the preprocessing step was stored.

# %%
import os

default_output_model = f"{models_dir}/{prefix}_GlobalPID-nm_kaon_{SAMPLE}_gan"
output_model = os.path.dirname(environ['OUTPUT_MODEL']) if 'OUTPUT_MODEL' in environ else default_output_model

base_dir = os.path.dirname(output_model)
if not os.path.exists(base_dir):
    os.mkdir(base_dir)

tf.keras.models.save_model(
    generator.export_model,
    filepath=output_model,
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models/20240109-19h43m43s_GlobalPID-nm_kaon_2016MU_gan/assets
# INFO:tensorflow:Assets written to: /home/mabarbet/PythonFastSim/models/GlobalPID-nm_kaon_models/20240109-19h43m43s_GlobalPID-nm_kaon_2016MU_gan/assets
